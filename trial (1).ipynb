# %%
GLOVE_PATH = "/Users/anoushkanahata/Desktop/SC4002/SC4002_NLP/glove.6B.100d.txt" # change to your path
EMBED_DIM = 100 # No need to change

# %%
from transformers import get_cosine_schedule_with_warmup
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.utils.data import DataLoader, Dataset 
import matplotlib as mpl
import matplotlib.pyplot as plt
from tensorflow import keras
import sys
sys.path.append('/Users/anoushkanahata/Desktop/SC4002/SC4002_NLP')
import pandas as pd
import numpy as np
import random
from sklearn.metrics import confusion_matrix, f1_score, f1_score, roc_curve, auc, precision_recall_curve, average_precision_score
import seaborn as sns
from Embeddings import GloveEmbedding, GloveTokenizerNoSub
import itertools
import torch
from torch.utils.data import DataLoader
from typing import Any
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import copy

# %%
# set seeds
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
set_seed(114514)

# %%
# import tokenizer
tokenizer_no_sub = GloveTokenizerNoSub(glove_file_path=GLOVE_PATH)
embedding = GloveEmbedding(
    glove_file_path = GLOVE_PATH, 
    trainable = False # False for part 2 to disable the Embedding training
)

# %%
class SentimentRNN(nn.Module):
    def __init__(self, embedding, hidden_size, embed_size, bidirectional, num_rnn_layer, dropout_rate, layer_norm):
        super(SentimentRNN, self).__init__()
        self.embedding = embedding  # pass pretrained embedding in
        self.bidirectional = bidirectional
        self.rnn = nn.RNN(embed_size, hidden_size, batch_first=True, num_layers = num_rnn_layer, bidirectional=bidirectional, dropout = dropout_rate if num_rnn_layer > 1 else 0)
        
        # if bidirectional, the output hidden size is double
        self.hidden_size = hidden_size * 2 if bidirectional else hidden_size
        
        # MLP
        if not layer_norm:
            self.output_layer = nn.Sequential(
                nn.Dropout(dropout_rate),
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.GELU(),
                nn.Linear(self.hidden_size, 1),  # output dimension is 1 (sigmoid is in BCELossWithLogits, so no sigmoid here. This will get better result)
            )
        else:
            self.output_layer = nn.Sequential(
                nn.LayerNorm(self.hidden_size),
                nn.Dropout(dropout_rate),
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.LayerNorm(self.hidden_size),
                nn.GELU(),
                nn.Linear(self.hidden_size, 1), 
            )
        
    def forward(self, input_ids, attention_mask):
        '''
        This method is designed for biLSTM/GRU/RNN. For LSTM/GRU/RNN for only one direction, just take hidden as the rnn output.
        RNN - hidden -> MLP --> outcome
        '''
        # embed the input
        embedded = self.embedding(input_ids)  # [batch_size, seq_length, embedding_dim]
        
        # feed forward
        output, hidden = self.rnn(embedded) # we don't need encoder so we only keep the output

        # make attention mask from [batch_size, seq_length] to [batch_size, seq_length, 1] as the same dimension as rnn
        attention_mask = attention_mask.unsqueeze(-1)  # [batch_size, seq_length, 1]

        # use attention mask to mask the output, ignore the padding embedding vector, only add the valid embedding vector 
        masked_output = output * attention_mask

        # sum up all the valid output
        summed_output = masked_output.sum(dim=1)  # [batch_size, hidden_size]

        logits = self.output_layer(summed_output)
        
        return logits  # The output is [batch_size, 1]

# %%
# import datasets

train_df = pd.read_csv("./preprocessed_dataset/train.csv").iloc[:,1:]
validation_df = pd.read_csv("./preprocessed_dataset/validation.csv").iloc[:,1:]
test_df = pd.read_csv("./preprocessed_dataset/test.csv").iloc[:,1:]

# %%
# try to use tokenizer api
tokenizer_no_sub.encode(["hello world", "how are you"], return_tensors = "pt") # insist to return pytorch
# Out:
# {'input_ids': tensor([[13077,    87,     0],
#          [  199,    34,    83]]),
#  'attention_mask': tensor([[1, 1, 0],
#          [1, 1, 1]])}

# %%
# Hyper paramaters
dropout_rate = 0.1
num_rnn_layer = 1
hidden_dim = 256

val_steps = 100 # compute validation error every n step

num_train_epochs = 3

batch_size = 32
lr = 8e-5
weight_decay = 1e-5


warmup_ratio=0.1
max_grad_norm = 2.0

# %%
# define dataset and data loader
class CustomizeDataset(Dataset):
    def __init__(
            self,
            df : pd.DataFrame
        ) -> None:
        super().__init__()
        self.df = df
        
    def __len__(self) -> int:
        return len(self.df)
    
    def __getitem__(
            self, 
            index : int
        ) -> dict:
        
        inputs = self.df.iloc[index,0] # 0 is text
        label = self.df.iloc[index, 1] # 1 is label
        
        return {
            "input_str" : inputs, # output a string
            "label" : label # output a label
        }
        
# collater function (used for dynamic padding to save memory)
class Collater:
    def __init__(
            self,
            tokenizer_no_sub : GloveTokenizerNoSub
        ) -> None:
        self.tokenizer_no_sub = tokenizer_no_sub 
    
    def __call__(
            self,
            instances : list # a list of string
        ) -> Any:
        # __call__ is for function-like object
        input_str_list = [instance["input_str"] for instance in instances]
        input_dict = tokenizer_no_sub.encode(input_str_list, return_tensors = "pt") # return pytorch tensor
        input_ids = input_dict["input_ids"]
        attention_mask = input_dict["attention_mask"]
        label = [torch.tensor(instance["label"], dtype = torch.int64) for instance in instances]

        return {
            "input_ids": input_ids,
            "label": torch.tensor(label),
            "attention_mask": attention_mask # mask the pad position
        }

# %%
# create dataset and data loader
collate_fn = Collater(tokenizer_no_sub)



train_ds = CustomizeDataset(
    df = train_df
)

train_loader = DataLoader(
    dataset = train_ds,
    batch_size = batch_size,
    collate_fn = collate_fn,
    shuffle = True
)

val_ds = CustomizeDataset(
    df = validation_df
)

val_loader = DataLoader(
    dataset = val_ds,
    batch_size = batch_size,
    collate_fn = collate_fn
)

test_ds = CustomizeDataset(
    df = test_df
)

test_loader = DataLoader(
    dataset = test_ds,
    batch_size = batch_size,
    collate_fn = collate_fn
)

# %%
# compute warmup status
num_training_steps = num_train_epochs * len(train_loader)
num_warmup_steps = int(num_training_steps * warmup_ratio)
print(f"train:{num_training_steps}, warm up: {num_warmup_steps}")
# Out:
# train:801, warm up: 80

# %%
# Set optimizer, loss_fn and so on

cls_model = SentimentRNN(
    embedding = embedding, 
    hidden_size = hidden_dim, 
    embed_size = EMBED_DIM, 
    bidirectional = False, #  False for part 2
    num_rnn_layer = num_rnn_layer,
    dropout_rate = dropout_rate,
    layer_norm = True # set if you need layer norm
)

loss_fn = nn.BCEWithLogitsLoss()

optimizer = AdamW(
    params = cls_model.parameters(),
    lr = lr,
    weight_decay = weight_decay
)

scheduler  = get_cosine_schedule_with_warmup(
    optimizer = optimizer,
    num_warmup_steps = num_warmup_steps,
    num_training_steps = num_training_steps
)

# %%
# compute accuracy for wach data loader

def compute_accuracy(data_loader: DataLoader) -> float:
    
    cls_model.eval()
    
    correct = 0
    total = 0
    
    with torch.no_grad():
        for data in data_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)
            
            logits = cls_model(input_ids, attention_mask=attention_mask)
     
            predictions = (logits > 0).long()
            
            correct += (predictions == labels).sum().item()
            total += labels.size(0)
    
    accuracy = correct / total
    return accuracy

def compute_loss(data_loader: DataLoader) -> float:
    total_loss = 0
    cls_model.eval()
    with torch.no_grad():
        for data in data_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)
            
            logits = cls_model.forward(input_ids, attention_mask)
            loss = loss_fn.forward(
                input = logits,
                target = labels
            )
            
            total_loss += loss.detach().cpu()
            
        total_loss /= len(val_loader)
        
        return total_loss

# %%
def early_stopping(train_loss, validation_loss, min_delta, tolerance, counter):
    positive_diff = abs(validation_loss - train_loss)

    # Increment counter if no significant improvement
    if positive_diff >= min_delta:
        counter += 1
        if counter >= tolerance:
            return True, counter
    # Ensure the function always returns both values
    return False, counter

# %%
# Training loop

cls_model.to(device)

optimizer.zero_grad()

step = 0

train_losses = []

val_accs = []

val_losses = []

counter = 0

for epoch in range(num_train_epochs):
    
    # train loop
    for data in train_loader:
        cls_model.train()
        input_ids = data["input_ids"].to(device)
        attention_mask = data["attention_mask"].to(device)
        label = data["label"].view(-1, 1).float().to(device)
        
        logits = cls_model.forward(input_ids, attention_mask)
        
        
        loss = loss_fn.forward(
            input = logits,
            target = label
        )
        
        loss.backward()

        # Gradient clip (important for RNN, not necessary for LSTM/GRU/conv1d)
        torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)
        
        optimizer.step() # update paramater
        scheduler.step() 
        optimizer.zero_grad() # clear gradient
        
        vis_loss = loss.detach().cpu()
        
        print(f"[{step + 1}/{num_training_steps}] train loss: [{vis_loss:.4f}] (epoch [{epoch + 1}/{num_train_epochs}])")
        
        
        train_losses.append(vis_loss)
        i =0 

        if (step + 1) % val_steps == 0 or step == 0:
            # compute validation every "val_steps"
           
            cls_model.eval()
            val_loss = compute_loss(val_loader)
            val_acc = compute_accuracy(val_loader)
            val_accs.append(val_acc)
            val_losses.append(val_loss)
            
            print(f"[{step + 1}/{num_training_steps}] validation loss: [{val_loss:.4f}] validation accuracy: [{val_acc:.4f}]")
            # Apply early stopping
            should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.01, tolerance=2, counter=counter)
            if should_stop:
                print("Early stopping triggered.")
                break
        
        step += 1
        
    if should_stop:
        break  # Exit e
# Out:
# [1/801] train loss: [0.7298] (epoch [1/3])
# [1/801] validation loss: [0.7138] validation accuracy: [0.4812]
# [2/801] train loss: [0.6627] (epoch [1/3])
# [3/801] train loss: [0.6749] (epoch [1/3])
# [4/801] train loss: [0.6800] (epoch [1/3])
# [5/801] train loss: [0.6946] (epoch [1/3])
# [6/801] train loss: [0.6443] (epoch [1/3])
# [7/801] train loss: [0.7529] (epoch [1/3])
# [8/801] train loss: [0.6820] (epoch [1/3])
# [9/801] train loss: [0.6910] (epoch [1/3])
# [10/801] train loss: [0.6811] (epoch [1/3])
# [11/801] train loss: [0.7150] (epoch [1/3])
# [12/801] train loss: [0.6712] (epoch [1/3])
# [13/801] train loss: [0.7084] (epoch [1/3])
# [14/801] train loss: [0.7331] (epoch [1/3])
# [15/801] train loss: [0.7546] (epoch [1/3])
# [16/801] train loss: [0.6899] (epoch [1/3])
# [17/801] train loss: [0.6976] (epoch [1/3])
# [18/801] train loss: [0.7150] (epoch [1/3])
# [19/801] train loss: [0.7286] (epoch [1/3])
# [20/801] train loss: [0.6914] (epoch [1/3])
# [21/801] train loss: [0.6839] (epoch [1/3])
# [22/801] train loss: [0.6939] (epoch [1/3])
# [23/801] train loss: [0.6994] (epoch [1/3])
# [24/801] train loss: [0.7097] (epoch [1/3])
# [25/801] train loss: [0.6964] (epoch [1/3])
# [26/801] train loss: [0.6941] (epoch [1/3])
# [27/801] train loss: [0.6853] (epoch [1/3])
# [28/801] train loss: [0.7068] (epoch [1/3])
# [29/801] train loss: [0.6725] (epoch [1/3])
# [30/801] train loss: [0.6776] (epoch [1/3])
# [31/801] train loss: [0.7117] (epoch [1/3])
# [32/801] train loss: [0.6851] (epoch [1/3])
# [33/801] train loss: [0.7327] (epoch [1/3])
# [34/801] train loss: [0.7101] (epoch [1/3])
# [35/801] train loss: [0.6952] (epoch [1/3])
# [36/801] train loss: [0.6954] (epoch [1/3])
# [37/801] train loss: [0.6892] (epoch [1/3])
# [38/801] train loss: [0.6605] (epoch [1/3])
# [39/801] train loss: [0.6785] (epoch [1/3])
# [40/801] train loss: [0.6910] (epoch [1/3])
# [41/801] train loss: [0.6646] (epoch [1/3])
# [42/801] train loss: [0.7029] (epoch [1/3])
# [43/801] train loss: [0.6414] (epoch [1/3])
# [44/801] train loss: [0.6705] (epoch [1/3])
# [45/801] train loss: [0.7042] (epoch [1/3])
# [46/801] train loss: [0.6676] (epoch [1/3])
# [47/801] train loss: [0.6834] (epoch [1/3])
# [48/801] train loss: [0.6926] (epoch [1/3])
# [49/801] train loss: [0.6872] (epoch [1/3])
# [50/801] train loss: [0.7066] (epoch [1/3])
# [51/801] train loss: [0.6597] (epoch [1/3])
# [52/801] train loss: [0.6829] (epoch [1/3])
# [53/801] train loss: [0.6675] (epoch [1/3])
# [54/801] train loss: [0.6884] (epoch [1/3])
# [55/801] train loss: [0.6757] (epoch [1/3])
# [56/801] train loss: [0.6451] (epoch [1/3])
# [57/801] train loss: [0.6765] (epoch [1/3])
# [58/801] train loss: [0.6886] (epoch [1/3])
# [59/801] train loss: [0.6480] (epoch [1/3])
# [60/801] train loss: [0.6707] (epoch [1/3])
# [61/801] train loss: [0.6872] (epoch [1/3])
# [62/801] train loss: [0.6703] (epoch [1/3])
# [63/801] train loss: [0.6289] (epoch [1/3])
# [64/801] train loss: [0.6692] (epoch [1/3])
# [65/801] train loss: [0.6873] (epoch [1/3])
# [66/801] train loss: [0.6760] (epoch [1/3])
# [67/801] train loss: [0.6526] (epoch [1/3])
# [68/801] train loss: [0.6532] (epoch [1/3])
# [69/801] train loss: [0.6722] (epoch [1/3])
# [70/801] train loss: [0.6492] (epoch [1/3])
# [71/801] train loss: [0.6459] (epoch [1/3])
# [72/801] train loss: [0.6750] (epoch [1/3])
# [73/801] train loss: [0.6575] (epoch [1/3])
# [74/801] train loss: [0.6326] (epoch [1/3])
# [75/801] train loss: [0.6662] (epoch [1/3])
# [76/801] train loss: [0.6360] (epoch [1/3])
# [77/801] train loss: [0.7138] (epoch [1/3])
# [78/801] train loss: [0.6812] (epoch [1/3])
# [79/801] train loss: [0.6633] (epoch [1/3])
# [80/801] train loss: [0.6831] (epoch [1/3])
# [81/801] train loss: [0.6314] (epoch [1/3])
# [82/801] train loss: [0.6701] (epoch [1/3])
# [83/801] train loss: [0.6187] (epoch [1/3])
# [84/801] train loss: [0.7288] (epoch [1/3])
# [85/801] train loss: [0.6103] (epoch [1/3])
# [86/801] train loss: [0.6584] (epoch [1/3])
# [87/801] train loss: [0.6751] (epoch [1/3])
# [88/801] train loss: [0.6394] (epoch [1/3])
# [89/801] train loss: [0.6508] (epoch [1/3])
# [90/801] train loss: [0.5938] (epoch [1/3])
# [91/801] train loss: [0.6705] (epoch [1/3])
# [92/801] train loss: [0.6511] (epoch [1/3])
# [93/801] train loss: [0.6700] (epoch [1/3])
# [94/801] train loss: [0.6120] (epoch [1/3])
# [95/801] train loss: [0.6655] (epoch [1/3])
# [96/801] train loss: [0.6004] (epoch [1/3])
# [97/801] train loss: [0.6215] (epoch [1/3])
# [98/801] train loss: [0.6167] (epoch [1/3])
# [99/801] train loss: [0.6435] (epoch [1/3])
# [100/801] train loss: [0.6029] (epoch [1/3])
# [100/801] validation loss: [0.6365] validation accuracy: [0.6576]
# Early stopping triggered.

# %%
# Test the model
# Define hyperparameter ranges
param_grid = {
    "num_rnn_layer": range(1, 2),  # Integer range for number of RNN layers
    "hidden_dim": [128, 256],  # Integer range for hidden dimension size
    "dropout_rate": [0.1, 0.2],  # Continuous range for dropout rate
    "learning_rate": [1e-4, 1e-3],  # Continuous range for learning rate
    "batch_size": [128, 256],  # Integer range for batch size
    "max_grad_norm": [1.0, 2.0],  # Continuous range for gradient clipping
    "num_train_epochs": [1,2,3]  # Integer range for number of training epochs
}

# Track the best configuration
best_val_loss = float('inf')
best_val_accuracy = 0.0
best_params = None

# Generate all combinations of hyperparameters
for params in itertools.product(
    param_grid["num_rnn_layer"],
    param_grid["hidden_dim"],
    param_grid["dropout_rate"],
    param_grid["learning_rate"],
    param_grid["batch_size"],
    param_grid["max_grad_norm"],
    param_grid["num_train_epochs"]
):
    # Unpack hyperparameters
    num_rnn_layer, hidden_dim, dropout_rate, learning_rate, batch_size, max_grad_norm, num_train_epochs = params
    
    # Initialize model with current parameters
    cls_model = SentimentRNN(
        embedding=embedding,
        hidden_size=hidden_dim,
        embed_size=EMBED_DIM,
        bidirectional=False,
        num_rnn_layer=num_rnn_layer,
        dropout_rate=dropout_rate,
        layer_norm=True
    ).to(device)
    
    # Set up optimizer and scheduler
    optimizer = torch.optim.Adam(cls_model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)
    
    # DataLoader for selected batch size
    train_loader = DataLoader(
        dataset=train_ds,
        batch_size=batch_size,
        collate_fn=collate_fn,
        shuffle=True
    )
    
    # Early stopping and metrics tracking variables
    counter = 0
    step = 0
    train_losses = []
    val_losses = []
    val_accs = []
    should_stop = False
    early_stopped = False  # Flag to indicate early stopping for this trial
    
    for epoch in range(num_train_epochs):
        # Training loop
        for data in train_loader:
            cls_model.train()
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            label = data["label"].view(-1, 1).float().to(device)
            
            logits = cls_model(input_ids, attention_mask)
            
            loss = loss_fn(input=logits, target=label)
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)
            
            optimizer.step()
            scheduler.step()
            optimizer.zero_grad()
            
            vis_loss = loss.detach().cpu().item()
            train_losses.append(vis_loss)
            
            # Validation step every `val_steps`
            if (step + 1) % val_steps == 0 or step == 0:
                cls_model.eval()
                val_loss = compute_loss(val_loader)
                val_acc = compute_accuracy(val_loader)
                val_losses.append(val_loss)
                val_accs.append(val_acc)
                
                # Early stopping check
                should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.5, tolerance=2, counter=counter)
                if should_stop:
                    print("Early stopping triggered.")
                    early_stopped = True  # Mark this trial as early stopped
                    break

            step += 1
        
        if should_stop:
            break  # Exit epoch loop if early stopping is triggered

    # Track the best parameters and validation loss
    current_val_loss = val_losses[-1] if val_losses else float('inf')
    current_val_accuracy = val_accs[-1] if val_accs else 0.0
    if current_val_accuracy > best_val_accuracy and early_stopped==False:
        best_val_loss = current_val_loss
        best_val_accuracy = current_val_accuracy
        best_params = params
    
    # Print the trial's results, including early stopping info
    print(f"Trial with params: {params}")
    print(f"  Validation Loss: {current_val_loss}")
    print(f"  Validation Accuracy: {current_val_accuracy}")
    if early_stopped:
        print("  Early stopped")
    

# Print the best result
print("Best result:")
print(f"  Validation Loss: {best_val_loss}")
print(f"  Validation Accuracy: {best_val_accuracy}")
print("  Best hyperparameters:", best_params)
# Out:
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.6925958395004272
#   Validation Accuracy: 0.5046904315196998
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6784826517105103
#   Validation Accuracy: 0.5900562851782364
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6857515573501587
#   Validation Accuracy: 0.5675422138836773
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.7007457613945007
#   Validation Accuracy: 0.4709193245778612
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6874362230300903
#   Validation Accuracy: 0.550656660412758
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.688939094543457
#   Validation Accuracy: 0.5544090056285178
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6975371837615967
#   Validation Accuracy: 0.4896810506566604
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.7062239050865173
#   Validation Accuracy: 0.48592870544090055
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.691674530506134
#   Validation Accuracy: 0.5290806754221389
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.6977198123931885
#   Validation Accuracy: 0.5065666041275797
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.7053276300430298
#   Validation Accuracy: 0.5093808630393997
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6847879886627197
#   Validation Accuracy: 0.5694183864915572
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.6872004866600037
#   Validation Accuracy: 0.5290806754221389
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6335350871086121
#   Validation Accuracy: 0.6538461538461539
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6450968980789185
#   Validation Accuracy: 0.6632270168855535
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.7194091081619263
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.6790183186531067
#   Validation Accuracy: 0.624765478424015
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6540776491165161
#   Validation Accuracy: 0.6575984990619137
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.7205711007118225
#   Validation Accuracy: 0.4971857410881801
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.7049029469490051
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6579214334487915
#   Validation Accuracy: 0.6669793621013134
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.6888605356216431
#   Validation Accuracy: 0.5347091932457786
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.7070816159248352
#   Validation Accuracy: 0.5037523452157598
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6584582328796387
#   Validation Accuracy: 0.651031894934334
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.6987436413764954
#   Validation Accuracy: 0.49624765478424016
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6847017407417297
#   Validation Accuracy: 0.5553470919324578
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6932674646377563
#   Validation Accuracy: 0.5103189493433395
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.7033668756484985
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6818042397499084
#   Validation Accuracy: 0.5881801125703565
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6890047788619995
#   Validation Accuracy: 0.5196998123827392
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.7123439311981201
#   Validation Accuracy: 0.49343339587242024
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6980354189872742
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6851515769958496
#   Validation Accuracy: 0.5581613508442776
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.7005782127380371
#   Validation Accuracy: 0.5084427767354597
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6923361420631409
#   Validation Accuracy: 0.5075046904315197
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6953949332237244
#   Validation Accuracy: 0.49437148217636023
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.7422094345092773
#   Validation Accuracy: 0.5028142589118199
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6642907857894897
#   Validation Accuracy: 0.6622889305816135
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6103742122650146
#   Validation Accuracy: 0.6754221388367729
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.6870136260986328
#   Validation Accuracy: 0.575046904315197
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.6659255027770996
#   Validation Accuracy: 0.6454033771106942
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6545583605766296
#   Validation Accuracy: 0.6538461538461539
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.7556242346763611
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.6969946026802063
#   Validation Accuracy: 0.5028142589118199
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6450369358062744
#   Validation Accuracy: 0.6575984990619137
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.70291668176651
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.7943383455276489
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6707901954650879
#   Validation Accuracy: 0.6641651031894934
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.7070655226707458
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6763821244239807
#   Validation Accuracy: 0.6275797373358349
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.671567440032959
#   Validation Accuracy: 0.6210131332082551
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.7096956968307495
#   Validation Accuracy: 0.5037523452157598
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6813860535621643
#   Validation Accuracy: 0.5816135084427767
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6791258454322815
#   Validation Accuracy: 0.599437148217636
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.693881094455719
#   Validation Accuracy: 0.5178236397748592
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6886627078056335
#   Validation Accuracy: 0.5544090056285178
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6740089654922485
#   Validation Accuracy: 0.6210131332082551
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.6945363879203796
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6961629986763
#   Validation Accuracy: 0.49343339587242024
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6874690055847168
#   Validation Accuracy: 0.5769230769230769
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.981220006942749
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6793573498725891
#   Validation Accuracy: 0.650093808630394
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6750329732894897
#   Validation Accuracy: 0.6369606003752345
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 1)
#   Validation Loss: 1.2294706106185913
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.6539140939712524
#   Validation Accuracy: 0.6397748592870544
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6690074801445007
#   Validation Accuracy: 0.6341463414634146
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 1)
#   Validation Loss: 1.1698251962661743
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 2)
#   Validation Loss: 1.0056747198104858
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6727753281593323
#   Validation Accuracy: 0.6641651031894934
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 1)
#   Validation Loss: 1.0466623306274414
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 2)
#   Validation Loss: 1.2622835636138916
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6376971006393433
#   Validation Accuracy: 0.6660412757973734
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.7130718231201172
#   Validation Accuracy: 0.49530956848030017
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6830692291259766
#   Validation Accuracy: 0.549718574108818
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6703783869743347
#   Validation Accuracy: 0.6238273921200751
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.7189730405807495
#   Validation Accuracy: 0.4981238273921201
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6685088872909546
#   Validation Accuracy: 0.6557223264540337
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6787354946136475
#   Validation Accuracy: 0.5797373358348968
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6912851333618164
#   Validation Accuracy: 0.5469043151969981
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6924390196800232
#   Validation Accuracy: 0.5046904315196998
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6753331422805786
#   Validation Accuracy: 0.6303939962476548
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.6896725296974182
#   Validation Accuracy: 0.5225140712945591
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6949666738510132
#   Validation Accuracy: 0.5028142589118199
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6719062328338623
#   Validation Accuracy: 0.6275797373358349
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 1)
#   Validation Loss: 1.0267293453216553
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6647083163261414
#   Validation Accuracy: 0.649155722326454
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6730126142501831
#   Validation Accuracy: 0.6669793621013134
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 1)
#   Validation Loss: 1.2138835191726685
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.676645040512085
#   Validation Accuracy: 0.6454033771106942
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6488291025161743
#   Validation Accuracy: 0.6782363977485929
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.6783792972564697
#   Validation Accuracy: 0.550656660412758
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.6827078461647034
#   Validation Accuracy: 0.5196998123827392
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6441660523414612
#   Validation Accuracy: 0.6575984990619137
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 1)
#   Validation Loss: 1.236864686012268
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 2)
#   Validation Loss: 1.1920485496520996
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6532204151153564
#   Validation Accuracy: 0.6726078799249531
# Best result:
#   Validation Loss: 0.6488291025161743
#   Validation Accuracy: 0.6782363977485929
#   Best hyperparameters: (1, 256, 0.2, 0.001, 128, 2.0, 3)

# %%
## (1, 256, 0.2, 0.001, 128, 2.0, 3)--> higest accuracy
print(best_params)
# Out:
# (1, 256, 0.2, 0.001, 128, 2.0, 3)

# %%
val_steps = 100
batch_size = 128
dropout_rate = 0.2
hidden_dim = 258
learning_rate = 0.001
num_rnn_layer = 1
max_grad_norm = 2.0
num_train_epochs = 3

num_training_steps = num_train_epochs * len(train_loader)
num_warmup_steps = int(num_training_steps * warmup_ratio)
print(f"train:{num_training_steps}, warm up: {num_warmup_steps}")
# Out:
# train:201, warm up: 20

# %%
cls_model = SentimentRNN(
    embedding=embedding,
    hidden_size=hidden_dim,
    embed_size=EMBED_DIM,
    bidirectional=False,  # False for part 2
    num_rnn_layer=num_rnn_layer,
    dropout_rate=dropout_rate,
    layer_norm=True
).to(device)
# Set up optimizer and scheduler
optimizer = torch.optim.Adam(cls_model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

train_loader = DataLoader(
    dataset=train_ds,
    batch_size=batch_size,
    collate_fn=collate_fn,
    shuffle=True
)

optimizer.zero_grad()

step = 0

train_losses = []

val_accs = []

val_losses = []

counter = 0

for epoch in range(num_train_epochs):
    
    # train loop
    for data in train_loader:
        cls_model.train()
        input_ids = data["input_ids"].to(device)
        attention_mask = data["attention_mask"].to(device)
        label = data["label"].view(-1, 1).float().to(device)
        
        logits = cls_model.forward(input_ids, attention_mask)
        
        
        loss = loss_fn.forward(
            input = logits,
            target = label
        )
        
        loss.backward()

        # Gradient clip (important for RNN, not necessary for LSTM/GRU/conv1d)
        torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)
        
        optimizer.step() # update paramater
        scheduler.step() 
        optimizer.zero_grad() # clear gradient
        
        vis_loss = loss.detach().cpu()
        
        print(f"[{step + 1}/{num_training_steps}] train loss: [{vis_loss:.4f}] (epoch [{epoch + 1}/{num_train_epochs}])")
        
        
        train_losses.append(vis_loss)
        i =0 

        if (step + 1) % val_steps == 0 or step == 0:
            # compute validation every "val_steps"
           
            cls_model.eval()
            val_loss = compute_loss(val_loader)
            val_acc = compute_accuracy(val_loader)
            val_accs.append(val_acc)
            val_losses.append(val_loss)
            
            print(f"[{step + 1}/{num_training_steps}] validation loss: [{val_loss:.4f}] validation accuracy: [{val_acc:.4f}]")
            # Apply early stopping
            should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.5, tolerance=2, counter=counter)
            if should_stop:
                print("Early stopping triggered.")
                break
        
        step += 1
        
    if should_stop:
        break  # Exit e
# Out:
# [1/201] train loss: [0.6857] (epoch [1/3])
# [1/201] validation loss: [0.9436] validation accuracy: [0.5009]
# [2/201] train loss: [0.8810] (epoch [1/3])
# [3/201] train loss: [0.6580] (epoch [1/3])
# [4/201] train loss: [0.8396] (epoch [1/3])
# [5/201] train loss: [0.7854] (epoch [1/3])
# [6/201] train loss: [0.6866] (epoch [1/3])
# [7/201] train loss: [0.6737] (epoch [1/3])
# [8/201] train loss: [0.6832] (epoch [1/3])
# [9/201] train loss: [0.7420] (epoch [1/3])
# [10/201] train loss: [0.7135] (epoch [1/3])
# [11/201] train loss: [0.6447] (epoch [1/3])
# [12/201] train loss: [0.6745] (epoch [1/3])
# [13/201] train loss: [0.6793] (epoch [1/3])
# [14/201] train loss: [0.6671] (epoch [1/3])
# [15/201] train loss: [0.6931] (epoch [1/3])
# [16/201] train loss: [0.6842] (epoch [1/3])
# [17/201] train loss: [0.6741] (epoch [1/3])
# [18/201] train loss: [0.6754] (epoch [1/3])
# [19/201] train loss: [0.6598] (epoch [1/3])
# [20/201] train loss: [0.6611] (epoch [1/3])
# [21/201] train loss: [0.6594] (epoch [1/3])
# [22/201] train loss: [0.6485] (epoch [1/3])
# [23/201] train loss: [0.6764] (epoch [1/3])
# [24/201] train loss: [0.6734] (epoch [1/3])
# [25/201] train loss: [0.6652] (epoch [1/3])
# [26/201] train loss: [0.6668] (epoch [1/3])
# [27/201] train loss: [0.6734] (epoch [1/3])
# [28/201] train loss: [0.6660] (epoch [1/3])
# [29/201] train loss: [0.6614] (epoch [1/3])
# [30/201] train loss: [0.6653] (epoch [1/3])
# [31/201] train loss: [0.6506] (epoch [1/3])
# [32/201] train loss: [0.6863] (epoch [1/3])
# [33/201] train loss: [0.6555] (epoch [1/3])
# [34/201] train loss: [0.6794] (epoch [1/3])
# [35/201] train loss: [0.6716] (epoch [1/3])
# [36/201] train loss: [0.6582] (epoch [1/3])
# [37/201] train loss: [0.6633] (epoch [1/3])
# [38/201] train loss: [0.6582] (epoch [1/3])
# [39/201] train loss: [0.6564] (epoch [1/3])
# [40/201] train loss: [0.6679] (epoch [1/3])
# [41/201] train loss: [0.6523] (epoch [1/3])
# [42/201] train loss: [0.6549] (epoch [1/3])
# [43/201] train loss: [0.6623] (epoch [1/3])
# [44/201] train loss: [0.6745] (epoch [1/3])
# [45/201] train loss: [0.6832] (epoch [1/3])
# [46/201] train loss: [0.6381] (epoch [1/3])
# [47/201] train loss: [0.6633] (epoch [1/3])
# [48/201] train loss: [0.6551] (epoch [1/3])
# [49/201] train loss: [0.6556] (epoch [1/3])
# [50/201] train loss: [0.6609] (epoch [1/3])
# [51/201] train loss: [0.6648] (epoch [1/3])
# [52/201] train loss: [0.6675] (epoch [1/3])
# [53/201] train loss: [0.6569] (epoch [1/3])
# [54/201] train loss: [0.6621] (epoch [1/3])
# [55/201] train loss: [0.6499] (epoch [1/3])
# [56/201] train loss: [0.6704] (epoch [1/3])
# [57/201] train loss: [0.6720] (epoch [1/3])
# [58/201] train loss: [0.6627] (epoch [1/3])
# [59/201] train loss: [0.6650] (epoch [1/3])
# [60/201] train loss: [0.6583] (epoch [1/3])
# [61/201] train loss: [0.6468] (epoch [1/3])
# [62/201] train loss: [0.6350] (epoch [1/3])
# [63/201] train loss: [0.6730] (epoch [1/3])
# [64/201] train loss: [0.6608] (epoch [1/3])
# [65/201] train loss: [0.6586] (epoch [1/3])
# [66/201] train loss: [0.6417] (epoch [1/3])
# [67/201] train loss: [0.6900] (epoch [1/3])
# [68/201] train loss: [0.6693] (epoch [2/3])
# [69/201] train loss: [0.6662] (epoch [2/3])
# [70/201] train loss: [0.6244] (epoch [2/3])
# [71/201] train loss: [0.6606] (epoch [2/3])
# [72/201] train loss: [0.6412] (epoch [2/3])
# [73/201] train loss: [0.6618] (epoch [2/3])
# [74/201] train loss: [0.6615] (epoch [2/3])
# [75/201] train loss: [0.6629] (epoch [2/3])
# [76/201] train loss: [0.6538] (epoch [2/3])
# [77/201] train loss: [0.6662] (epoch [2/3])
# [78/201] train loss: [0.6409] (epoch [2/3])
# [79/201] train loss: [0.6317] (epoch [2/3])
# [80/201] train loss: [0.6498] (epoch [2/3])
# [81/201] train loss: [0.6553] (epoch [2/3])
# [82/201] train loss: [0.6581] (epoch [2/3])
# [83/201] train loss: [0.6477] (epoch [2/3])
# [84/201] train loss: [0.6522] (epoch [2/3])
# [85/201] train loss: [0.6601] (epoch [2/3])
# [86/201] train loss: [0.6375] (epoch [2/3])
# [87/201] train loss: [0.6736] (epoch [2/3])
# [88/201] train loss: [0.6414] (epoch [2/3])
# [89/201] train loss: [0.6657] (epoch [2/3])
# [90/201] train loss: [0.6399] (epoch [2/3])
# [91/201] train loss: [0.6488] (epoch [2/3])
# [92/201] train loss: [0.6669] (epoch [2/3])
# [93/201] train loss: [0.6529] (epoch [2/3])
# [94/201] train loss: [0.6696] (epoch [2/3])
# [95/201] train loss: [0.6512] (epoch [2/3])
# [96/201] train loss: [0.6522] (epoch [2/3])
# [97/201] train loss: [0.6728] (epoch [2/3])
# [98/201] train loss: [0.6733] (epoch [2/3])
# [99/201] train loss: [0.6580] (epoch [2/3])
# [100/201] train loss: [0.6589] (epoch [2/3])
# [100/201] validation loss: [0.6564] validation accuracy: [0.6698]
# [101/201] train loss: [0.6655] (epoch [2/3])
# [102/201] train loss: [0.6563] (epoch [2/3])
# [103/201] train loss: [0.6507] (epoch [2/3])
# [104/201] train loss: [0.6832] (epoch [2/3])
# [105/201] train loss: [0.6610] (epoch [2/3])
# [106/201] train loss: [0.6597] (epoch [2/3])
# [107/201] train loss: [0.6532] (epoch [2/3])
# [108/201] train loss: [0.6646] (epoch [2/3])
# [109/201] train loss: [0.6510] (epoch [2/3])
# [110/201] train loss: [0.6665] (epoch [2/3])
# [111/201] train loss: [0.6535] (epoch [2/3])
# [112/201] train loss: [0.6538] (epoch [2/3])
# [113/201] train loss: [0.6739] (epoch [2/3])
# [114/201] train loss: [0.6487] (epoch [2/3])
# [115/201] train loss: [0.6500] (epoch [2/3])
# [116/201] train loss: [0.6582] (epoch [2/3])
# [117/201] train loss: [0.6500] (epoch [2/3])
# [118/201] train loss: [0.6837] (epoch [2/3])
# [119/201] train loss: [0.6695] (epoch [2/3])
# [120/201] train loss: [0.6596] (epoch [2/3])
# [121/201] train loss: [0.6639] (epoch [2/3])
# [122/201] train loss: [0.6595] (epoch [2/3])
# [123/201] train loss: [0.6365] (epoch [2/3])
# [124/201] train loss: [0.6554] (epoch [2/3])
# [125/201] train loss: [0.6578] (epoch [2/3])
# [126/201] train loss: [0.6506] (epoch [2/3])
# [127/201] train loss: [0.6606] (epoch [2/3])
# [128/201] train loss: [0.6454] (epoch [2/3])
# [129/201] train loss: [0.6678] (epoch [2/3])
# [130/201] train loss: [0.6489] (epoch [2/3])
# [131/201] train loss: [0.6549] (epoch [2/3])
# [132/201] train loss: [0.6617] (epoch [2/3])
# [133/201] train loss: [0.6642] (epoch [2/3])
# [134/201] train loss: [0.6429] (epoch [2/3])
# [135/201] train loss: [0.6364] (epoch [3/3])
# [136/201] train loss: [0.6430] (epoch [3/3])
# [137/201] train loss: [0.6536] (epoch [3/3])
# [138/201] train loss: [0.6744] (epoch [3/3])
# [139/201] train loss: [0.6581] (epoch [3/3])
# [140/201] train loss: [0.6536] (epoch [3/3])
# [141/201] train loss: [0.6780] (epoch [3/3])
# [142/201] train loss: [0.6521] (epoch [3/3])
# [143/201] train loss: [0.6557] (epoch [3/3])
# [144/201] train loss: [0.6363] (epoch [3/3])
# [145/201] train loss: [0.6630] (epoch [3/3])
# [146/201] train loss: [0.6455] (epoch [3/3])
# [147/201] train loss: [0.6481] (epoch [3/3])
# [148/201] train loss: [0.6572] (epoch [3/3])
# [149/201] train loss: [0.6632] (epoch [3/3])
# [150/201] train loss: [0.6589] (epoch [3/3])
# [151/201] train loss: [0.6571] (epoch [3/3])
# [152/201] train loss: [0.6573] (epoch [3/3])
# [153/201] train loss: [0.6555] (epoch [3/3])
# [154/201] train loss: [0.6731] (epoch [3/3])
# [155/201] train loss: [0.6370] (epoch [3/3])
# [156/201] train loss: [0.6722] (epoch [3/3])
# [157/201] train loss: [0.6643] (epoch [3/3])
# [158/201] train loss: [0.6692] (epoch [3/3])
# [159/201] train loss: [0.6497] (epoch [3/3])
# [160/201] train loss: [0.6506] (epoch [3/3])
# [161/201] train loss: [0.6663] (epoch [3/3])
# [162/201] train loss: [0.6558] (epoch [3/3])
# [163/201] train loss: [0.6681] (epoch [3/3])
# [164/201] train loss: [0.6590] (epoch [3/3])
# [165/201] train loss: [0.6291] (epoch [3/3])
# [166/201] train loss: [0.6675] (epoch [3/3])
# [167/201] train loss: [0.6423] (epoch [3/3])
# [168/201] train loss: [0.6896] (epoch [3/3])
# [169/201] train loss: [0.6706] (epoch [3/3])
# [170/201] train loss: [0.6618] (epoch [3/3])
# [171/201] train loss: [0.6690] (epoch [3/3])
# [172/201] train loss: [0.6536] (epoch [3/3])
# [173/201] train loss: [0.6533] (epoch [3/3])
# [174/201] train loss: [0.6560] (epoch [3/3])
# [175/201] train loss: [0.6556] (epoch [3/3])
# [176/201] train loss: [0.6508] (epoch [3/3])
# [177/201] train loss: [0.6715] (epoch [3/3])
# [178/201] train loss: [0.6697] (epoch [3/3])
# [179/201] train loss: [0.6683] (epoch [3/3])
# [180/201] train loss: [0.6347] (epoch [3/3])
# [181/201] train loss: [0.6549] (epoch [3/3])
# [182/201] train loss: [0.6504] (epoch [3/3])
# [183/201] train loss: [0.6642] (epoch [3/3])
# [184/201] train loss: [0.6497] (epoch [3/3])
# [185/201] train loss: [0.6642] (epoch [3/3])
# [186/201] train loss: [0.6331] (epoch [3/3])
# [187/201] train loss: [0.6493] (epoch [3/3])
# [188/201] train loss: [0.6577] (epoch [3/3])
# [189/201] train loss: [0.6565] (epoch [3/3])
# [190/201] train loss: [0.6614] (epoch [3/3])
# [191/201] train loss: [0.6725] (epoch [3/3])
# [192/201] train loss: [0.6750] (epoch [3/3])
# [193/201] train loss: [0.6655] (epoch [3/3])
# [194/201] train loss: [0.6541] (epoch [3/3])
# [195/201] train loss: [0.6768] (epoch [3/3])
# [196/201] train loss: [0.6543] (epoch [3/3])
# [197/201] train loss: [0.6619] (epoch [3/3])
# [198/201] train loss: [0.6466] (epoch [3/3])
# [199/201] train loss: [0.6543] (epoch [3/3])
# [200/201] train loss: [0.6558] (epoch [3/3])
# [200/201] validation loss: [0.6564] validation accuracy: [0.6698]
# [201/201] train loss: [0.6532] (epoch [3/3])

# %%
train_loss = compute_loss(train_loader)
train_acc = compute_accuracy(train_loader)
test_loss = compute_loss(test_loader)
test_acc = compute_accuracy(test_loader)
val_loss = compute_loss(val_loader)
test_acc = compute_accuracy(test_loader)

print(f"Train Loss: [{train_loss:.4f}]\nTrain accuracy: [{train_acc:.4f}]")
print(f"Test Loss: [{test_loss:.4f}]\nTest accuracy: [{test_acc:.4f}]")
print(f"Validation Loss: [{val_loss:.4f}]\nValidation accuracy: [{val_acc:.4f}]")
# Out:
# Train Loss: [1.2888]
# Train accuracy: [0.6597]
# Test Loss: [0.6563]
# Test accuracy: [0.6454]
# Validation Loss: [0.6564]
# Validation accuracy: [0.6698]

# %%
# compute predictions and labels for confusion matrix computing
def compute_pedictions_and_labels(
        model : nn.Module, 
        test_loader : DataLoader, 
        device : torch.device
    ) -> tuple:
    
    model.to(device)
    
    model.eval()
    
    # Lists to store all predictions and actual labels
    all_predictions = []
    all_labels = []
    
    with torch.no_grad():
        for data in test_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)
            
            logits = model(input_ids, attention_mask=attention_mask)
     
            predictions = (logits > 0).long()
            
            all_predictions.extend(predictions.view(-1).cpu().numpy())
            all_labels.extend(labels.view(-1).cpu().numpy())
    
    return all_predictions, all_labels

all_predictions, all_labels = compute_pedictions_and_labels(cls_model, test_loader, device)

# %%
# visualization 2: confusion matrix

def plot_confusion(
        all_predictions : list, 
        all_labels : list
    ) -> None:      
            
    cm = confusion_matrix(all_labels, all_predictions) # from sklearn
            
    plt.figure(figsize=(6,4))
    sns.heatmap(cm, annot=True, fmt='d', linewidths=0.2, cmap="YlGnBu", cbar=False)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.xticks([0.5, 1.5], ['Negative', 'Positive'])
    plt.yticks([0.5, 1.5], ['Negative', 'Positive'], va='center')
    plt.show()
    
plot_confusion(all_predictions, all_labels)
