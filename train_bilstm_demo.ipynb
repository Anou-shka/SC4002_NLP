# %% [markdown]
# ## Demo for train an RNN with our Embeddings/Tokenizers

# %%
GLOVE_PATH = "C:\\Users\\Administrator\\Desktop\\glove\\glove.6B.100d.txt" # change to your path
EMBED_DIM = 100 # No need to change

# %%
from transformers import get_cosine_schedule_with_warmup
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.utils.data import DataLoader, Dataset 
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
from sklearn.metrics import confusion_matrix, f1_score, f1_score, roc_curve, auc, precision_recall_curve, average_precision_score
import seaborn as sns
from Embeddings import GloveEmbedding, GloveTokenizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# set seeds
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
set_seed(114514)

# %%
# import tokenizer
tokenizer = GloveTokenizer(glove_file_path=GLOVE_PATH)
embedding = GloveEmbedding(
    glove_file_path = GLOVE_PATH, 
    trainable = True # False for part 2 to disable the Embedding training
)

# %%
class SentimentRNN(nn.Module):
    def __init__(self, embedding, hidden_size, embed_size, bidirectional, num_rnn_layer, dropout_rate, layer_norm):
        super(SentimentRNN, self).__init__()
        self.embedding = embedding  # pass pretrained embedding in
        self.bidirectional = bidirectional
        self.rnn = nn.LSTM(embed_size, hidden_size, batch_first=True, num_layers = num_rnn_layer, bidirectional=bidirectional, dropout = dropout_rate)
        
        # if bidirectional, the output hidden size is double
        self.hidden_size = hidden_size * 2 if bidirectional else hidden_size
        
        # MLP
        if not layer_norm:
            self.output_layer = nn.Sequential(
                nn.Dropout(dropout_rate),
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.GELU(),
                nn.Linear(self.hidden_size, 1),  # output dimension is 1 (sigmoid is in BCELossWithLogits, so no sigmoid here. This will get better result)
            )
        else:
            self.output_layer = nn.Sequential(
                nn.LayerNorm(self.hidden_size),
                nn.Dropout(dropout_rate),
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.LayerNorm(self.hidden_size),
                nn.GELU(),
                nn.Linear(self.hidden_size, 1), 
            )
        
    def forward(self, input_ids, attention_mask):
        '''
        This method is designed for BiLSTM/GRU/RNN. For LSTM/GRU/RNN for only one direction, just take hidden as the rnn output.
        RNN - hidden -> MLP --> outcome
        '''
        # embed the input
        embedded = self.embedding(input_ids)  # [batch_size, seq_length, embedding_dim]
        
        # feed forward
        output, hidden = self.rnn(embedded) # we don't need encoder so we only keep the output

        # make attention mask from [batch_size, seq_length] to [batch_size, seq_length, 1] as the same dimension as rnn
        attention_mask = attention_mask.unsqueeze(-1)  # [batch_size, seq_length, 1]

        # use attention mask to mask the output, ignore the padding embedding vector, only add the valid embedding vector 
        masked_output = output * attention_mask

        # sum up all the valid output
        summed_output = masked_output.sum(dim=1)  # [batch_size, hidden_size]

        logits = self.output_layer(summed_output)
        
        return logits  # The output is [batch_size, 1]

# %%
# import datasets

train_df = pd.read_csv("./preprocessed_dataset/train.csv").iloc[:,1:]
validation_df = pd.read_csv("./preprocessed_dataset/validation.csv").iloc[:,1:]
test_df = pd.read_csv("./preprocessed_dataset/test.csv").iloc[:,1:]
train_df
# Out:
#                                                    text  label
# 0     the rock is destined to be the 21st century's ...      1
# 1     the gorgeously elaborate continuation of " the...      1
# 2                        effective but too-tepid biopic      1
# 3     if you sometimes like to go to the movies to h...      1
# 4     emerges as something rare , an issue movie tha...      1
# ...                                                 ...    ...
# 8525  any enjoyment will be hinge from a personal th...      0
# 8526  if legendary shlockmeister ed wood had ever ma...      0
# 8527  hardly a nuanced portrait of a young woman's b...      0
# 8528    interminably bleak , to say nothing of boring .      0
# 8529  things really get weird , though not particula...      0
#
# [8530 rows x 2 columns]

# %%
# try to use tokenizer api
tokenizer.encode(["hello world", "how are you"], return_tensors = "pt") # insist to return pytorch
# Out:
# {'input_ids': tensor([[13077,    87,     0],
#          [  199,    34,    83]]),
#  'attention_mask': tensor([[1, 1, 0],
#          [1, 1, 1]])}

# %%
# define dataset and data loader
from typing import Any


class CustomizeDataset(Dataset):
    def __init__(
            self,
            df : pd.DataFrame
        ) -> None:
        super().__init__()
        self.df = df
        
    def __len__(self) -> int:
        return len(self.df)
    
    def __getitem__(
            self, 
            index : int
        ) -> dict:
        
        inputs = self.df.iloc[index,0] # 0 is text
        label = self.df.iloc[index, 1] # 1 is label
        
        return {
            "input_str" : inputs, # output a string
            "label" : label # output a label
        }
        
# collater function (used for dynamic padding to save memory)
class Collater:
    def __init__(
            self,
            tokenizer : GloveTokenizer
        ) -> None:
        self.tokenizer = tokenizer 
    
    def __call__(
            self,
            instances : list # a list of string
        ) -> Any:
        # __call__ is for function-like object
        input_str_list = [instance["input_str"] for instance in instances]
        input_dict = tokenizer.encode(input_str_list, return_tensors = "pt") # return pytorch tensor
        input_ids = input_dict["input_ids"]
        attention_mask = input_dict["attention_mask"]
        label = [torch.tensor(instance["label"], dtype = torch.int64) for instance in instances]

        return {
            "input_ids": input_ids,
            "label": torch.tensor(label),
            "attention_mask": attention_mask # mask the pad position
        }

# %%
# Hyper paramaters
dropout_rate = 0.1
num_rnn_layer = 2
hidden_dim = 256

val_steps = 100 # compute validation error every n step

num_train_epochs = 3

batch_size = 32
lr = 8e-5
weight_decay = 1e-5


warmup_ratio=0.1
max_grad_norm = 2.0

# %%
# create dataset and data loader

collate_fn = Collater(tokenizer)

train_ds = CustomizeDataset(
    df = train_df
)

train_loader = DataLoader(
    dataset = train_ds,
    batch_size = batch_size,
    collate_fn = collate_fn,
    shuffle = True
)

val_ds = CustomizeDataset(
    df = validation_df
)

val_loader = DataLoader(
    dataset = val_ds,
    batch_size = batch_size,
    collate_fn = collate_fn
)

test_ds = CustomizeDataset(
    df = test_df
)

test_loader = DataLoader(
    dataset = test_ds,
    batch_size = batch_size,
    collate_fn = collate_fn
)

# %%
# compute warmup status
num_training_steps = num_train_epochs * len(train_loader)
num_warmup_steps = int(num_training_steps * warmup_ratio)
print(f"train:{num_training_steps}, warm up: {num_warmup_steps}")
# Out:
# train:801, warm up: 80

# %%
# Set optimizer, loss_fn and so on

cls_model = SentimentRNN(
    embedding = embedding, 
    hidden_size = hidden_dim, 
    embed_size = EMBED_DIM, 
    bidirectional = True, #  False for part 2
    num_rnn_layer = num_rnn_layer,
    dropout_rate = dropout_rate,
    layer_norm = True # set if you need layer norm
)

loss_fn = nn.BCEWithLogitsLoss()

optimizer = AdamW(
    params = cls_model.parameters(),
    lr = lr,
    weight_decay = weight_decay
)

scheduler  = get_cosine_schedule_with_warmup(
    optimizer = optimizer,
    num_warmup_steps = num_warmup_steps,
    num_training_steps = num_training_steps
)

# %%
# compute accuracy for wach data loader

def compute_accuracy(data_loader: DataLoader) -> float:
    
    cls_model.eval()
    
    correct = 0
    total = 0
    
    with torch.no_grad():
        for data in data_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)
            
            logits = cls_model(input_ids, attention_mask=attention_mask)
     
            predictions = (logits > 0).long()
            
            correct += (predictions == labels).sum().item()
            total += labels.size(0)
    
    accuracy = correct / total
    return accuracy

def compute_loss(data_loader: DataLoader) -> float:
    total_loss = 0
    cls_model.eval()
    with torch.no_grad():
        for data in data_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)
            
            logits = cls_model.forward(input_ids, attention_mask)
            loss = loss_fn.forward(
                input = logits,
                target = labels
            )
            
            total_loss += loss.detach().cpu()
            
        total_loss /= len(val_loader)
        
        return total_loss

# %%
# Training loop

cls_model.to(device)

optimizer.zero_grad()

step = 0

train_losses = []

val_accs = []

val_losses = []

for epoch in range(num_train_epochs):
    
    # train loop
    for data in train_loader:
        cls_model.train()
        input_ids = data["input_ids"].to(device)
        attention_mask = data["attention_mask"].to(device)
        label = data["label"].view(-1, 1).float().to(device)
        
        logits = cls_model.forward(input_ids, attention_mask)
        
        
        loss = loss_fn.forward(
            input = logits,
            target = label
        )
        
        loss.backward()

        # Gradient clip (important for RNN, not necessary for LSTM/GRU/conv1d)
        torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)
        
        optimizer.step() # update paramater
        scheduler.step() 
        optimizer.zero_grad() # clear gradient
        
        vis_loss = loss.detach().cpu()
        
        print(f"[{step + 1}/{num_training_steps}] train loss: [{vis_loss:.4f}] (epoch [{epoch + 1}/{num_train_epochs}])")
        
        
        train_losses.append(vis_loss)
        
        if (step + 1) % val_steps == 0 or step == 0:
            # compute validation every "val_steps"
           
            cls_model.eval()
            val_loss = compute_loss(val_loader)
            val_acc = compute_accuracy(val_loader)
            
            val_accs.append(val_acc)
            val_losses.append(val_loss)
            
            print(f"[{step + 1}/{num_training_steps}] validation loss: [{val_loss:.4f}] validation accuracy: [{val_acc:.4f}]")
        
        step += 1
# Out:
# [1/801] train loss: [0.6970] (epoch [1/3])
# [1/801] validation loss: [0.7085] validation accuracy: [0.5000]
# [2/801] train loss: [0.7024] (epoch [1/3])
# [3/801] train loss: [0.7023] (epoch [1/3])
# [4/801] train loss: [0.7378] (epoch [1/3])
# [5/801] train loss: [0.6903] (epoch [1/3])
# [6/801] train loss: [0.6622] (epoch [1/3])
# [7/801] train loss: [0.7204] (epoch [1/3])
# [8/801] train loss: [0.7180] (epoch [1/3])
# [9/801] train loss: [0.6880] (epoch [1/3])
# [10/801] train loss: [0.7179] (epoch [1/3])
# [11/801] train loss: [0.6777] (epoch [1/3])
# [12/801] train loss: [0.6929] (epoch [1/3])
# [13/801] train loss: [0.6603] (epoch [1/3])
# [14/801] train loss: [0.6910] (epoch [1/3])
# [15/801] train loss: [0.6614] (epoch [1/3])
# [16/801] train loss: [0.6813] (epoch [1/3])
# [17/801] train loss: [0.6841] (epoch [1/3])
# [18/801] train loss: [0.7084] (epoch [1/3])
# [19/801] train loss: [0.6868] (epoch [1/3])
# [20/801] train loss: [0.7230] (epoch [1/3])
# [21/801] train loss: [0.6881] (epoch [1/3])
# [22/801] train loss: [0.7403] (epoch [1/3])
# [23/801] train loss: [0.6722] (epoch [1/3])
# [24/801] train loss: [0.7037] (epoch [1/3])
# [25/801] train loss: [0.6795] (epoch [1/3])
# [26/801] train loss: [0.6963] (epoch [1/3])
# [27/801] train loss: [0.6709] (epoch [1/3])
# [28/801] train loss: [0.6929] (epoch [1/3])
# [29/801] train loss: [0.6638] (epoch [1/3])
# [30/801] train loss: [0.6709] (epoch [1/3])
# [31/801] train loss: [0.6922] (epoch [1/3])
# [32/801] train loss: [0.6685] (epoch [1/3])
# [33/801] train loss: [0.6795] (epoch [1/3])
# [34/801] train loss: [0.7001] (epoch [1/3])
# [35/801] train loss: [0.6549] (epoch [1/3])
# [36/801] train loss: [0.6908] (epoch [1/3])
# [37/801] train loss: [0.6677] (epoch [1/3])
# [38/801] train loss: [0.6710] (epoch [1/3])
# [39/801] train loss: [0.6755] (epoch [1/3])
# [40/801] train loss: [0.6765] (epoch [1/3])
# [41/801] train loss: [0.6806] (epoch [1/3])
# [42/801] train loss: [0.6230] (epoch [1/3])
# [43/801] train loss: [0.6814] (epoch [1/3])
# [44/801] train loss: [0.6616] (epoch [1/3])
# [45/801] train loss: [0.7007] (epoch [1/3])
# [46/801] train loss: [0.6837] (epoch [1/3])
# [47/801] train loss: [0.6625] (epoch [1/3])
# [48/801] train loss: [0.6779] (epoch [1/3])
# [49/801] train loss: [0.6583] (epoch [1/3])
# [50/801] train loss: [0.7032] (epoch [1/3])
# [51/801] train loss: [0.6581] (epoch [1/3])
# [52/801] train loss: [0.6214] (epoch [1/3])
# [53/801] train loss: [0.6987] (epoch [1/3])
# [54/801] train loss: [0.7206] (epoch [1/3])
# [55/801] train loss: [0.6614] (epoch [1/3])
# [56/801] train loss: [0.6832] (epoch [1/3])
# [57/801] train loss: [0.6563] (epoch [1/3])
# [58/801] train loss: [0.7136] (epoch [1/3])
# [59/801] train loss: [0.7514] (epoch [1/3])
# [60/801] train loss: [0.6940] (epoch [1/3])
# [61/801] train loss: [0.6758] (epoch [1/3])
# [62/801] train loss: [0.5712] (epoch [1/3])
# [63/801] train loss: [0.6457] (epoch [1/3])
# [64/801] train loss: [0.5644] (epoch [1/3])
# [65/801] train loss: [0.6716] (epoch [1/3])
# [66/801] train loss: [0.6264] (epoch [1/3])
# [67/801] train loss: [0.6178] (epoch [1/3])
# [68/801] train loss: [0.6927] (epoch [1/3])
# [69/801] train loss: [0.6618] (epoch [1/3])
# [70/801] train loss: [0.6718] (epoch [1/3])
# [71/801] train loss: [0.6819] (epoch [1/3])
# [72/801] train loss: [0.6505] (epoch [1/3])
# [73/801] train loss: [0.6409] (epoch [1/3])
# [74/801] train loss: [0.5799] (epoch [1/3])
# [75/801] train loss: [0.6536] (epoch [1/3])
# [76/801] train loss: [0.6485] (epoch [1/3])
# [77/801] train loss: [0.7094] (epoch [1/3])
# [78/801] train loss: [0.6888] (epoch [1/3])
# [79/801] train loss: [0.6343] (epoch [1/3])
# [80/801] train loss: [0.6267] (epoch [1/3])
# [81/801] train loss: [0.6034] (epoch [1/3])
# [82/801] train loss: [0.6657] (epoch [1/3])
# [83/801] train loss: [0.6985] (epoch [1/3])
# [84/801] train loss: [0.6740] (epoch [1/3])
# [85/801] train loss: [0.6865] (epoch [1/3])
# [86/801] train loss: [0.5577] (epoch [1/3])
# [87/801] train loss: [0.6312] (epoch [1/3])
# [88/801] train loss: [0.6810] (epoch [1/3])
# [89/801] train loss: [0.6090] (epoch [1/3])
# [90/801] train loss: [0.6153] (epoch [1/3])
# [91/801] train loss: [0.5985] (epoch [1/3])
# [92/801] train loss: [0.5910] (epoch [1/3])
# [93/801] train loss: [0.6002] (epoch [1/3])
# [94/801] train loss: [0.6603] (epoch [1/3])
# [95/801] train loss: [0.5731] (epoch [1/3])
# [96/801] train loss: [0.6553] (epoch [1/3])
# [97/801] train loss: [0.5674] (epoch [1/3])
# [98/801] train loss: [0.5366] (epoch [1/3])
# [99/801] train loss: [0.6526] (epoch [1/3])
# [100/801] train loss: [0.5727] (epoch [1/3])
# [100/801] validation loss: [0.6152] validation accuracy: [0.6463]
# [101/801] train loss: [0.5272] (epoch [1/3])
# [102/801] train loss: [0.6887] (epoch [1/3])
# [103/801] train loss: [0.5728] (epoch [1/3])
# [104/801] train loss: [0.7352] (epoch [1/3])
# [105/801] train loss: [0.5252] (epoch [1/3])
# [106/801] train loss: [0.5411] (epoch [1/3])
# [107/801] train loss: [0.5159] (epoch [1/3])
# [108/801] train loss: [0.6229] (epoch [1/3])
# [109/801] train loss: [0.4922] (epoch [1/3])
# [110/801] train loss: [0.6163] (epoch [1/3])
# [111/801] train loss: [0.6402] (epoch [1/3])
# [112/801] train loss: [0.5410] (epoch [1/3])
# [113/801] train loss: [0.4905] (epoch [1/3])
# [114/801] train loss: [0.4786] (epoch [1/3])
# [115/801] train loss: [0.6153] (epoch [1/3])
# [116/801] train loss: [0.6261] (epoch [1/3])
# [117/801] train loss: [0.7055] (epoch [1/3])
# [118/801] train loss: [0.6609] (epoch [1/3])
# [119/801] train loss: [0.7221] (epoch [1/3])
# [120/801] train loss: [0.6094] (epoch [1/3])
# [121/801] train loss: [0.5064] (epoch [1/3])
# [122/801] train loss: [0.5644] (epoch [1/3])
# [123/801] train loss: [0.5192] (epoch [1/3])
# [124/801] train loss: [0.5157] (epoch [1/3])
# [125/801] train loss: [0.4996] (epoch [1/3])
# [126/801] train loss: [0.4955] (epoch [1/3])
# [127/801] train loss: [0.5256] (epoch [1/3])
# [128/801] train loss: [0.4543] (epoch [1/3])
# [129/801] train loss: [0.6004] (epoch [1/3])
# [130/801] train loss: [0.6740] (epoch [1/3])
# [131/801] train loss: [0.5517] (epoch [1/3])
# [132/801] train loss: [0.6186] (epoch [1/3])
# [133/801] train loss: [0.5098] (epoch [1/3])
# [134/801] train loss: [0.6180] (epoch [1/3])
# [135/801] train loss: [0.5396] (epoch [1/3])
# [136/801] train loss: [0.5738] (epoch [1/3])
# [137/801] train loss: [0.5706] (epoch [1/3])
# [138/801] train loss: [0.7362] (epoch [1/3])
# [139/801] train loss: [0.6982] (epoch [1/3])
# [140/801] train loss: [0.6445] (epoch [1/3])
# [141/801] train loss: [0.4260] (epoch [1/3])
# [142/801] train loss: [0.7882] (epoch [1/3])
# [143/801] train loss: [0.6507] (epoch [1/3])
# [144/801] train loss: [0.5073] (epoch [1/3])
# [145/801] train loss: [0.6122] (epoch [1/3])
# [146/801] train loss: [0.6358] (epoch [1/3])
# [147/801] train loss: [0.5609] (epoch [1/3])
# [148/801] train loss: [0.5084] (epoch [1/3])
# [149/801] train loss: [0.4735] (epoch [1/3])
# [150/801] train loss: [0.6874] (epoch [1/3])
# [151/801] train loss: [0.4913] (epoch [1/3])
# [152/801] train loss: [0.5904] (epoch [1/3])
# [153/801] train loss: [0.6146] (epoch [1/3])
# [154/801] train loss: [0.5960] (epoch [1/3])
# [155/801] train loss: [0.5324] (epoch [1/3])
# [156/801] train loss: [0.6680] (epoch [1/3])
# [157/801] train loss: [0.6000] (epoch [1/3])
# [158/801] train loss: [0.5077] (epoch [1/3])
# [159/801] train loss: [0.6519] (epoch [1/3])
# [160/801] train loss: [0.6075] (epoch [1/3])
# [161/801] train loss: [0.6366] (epoch [1/3])
# [162/801] train loss: [0.5058] (epoch [1/3])
# [163/801] train loss: [0.5477] (epoch [1/3])
# [164/801] train loss: [0.6685] (epoch [1/3])
# [165/801] train loss: [0.5479] (epoch [1/3])
# [166/801] train loss: [0.5752] (epoch [1/3])
# [167/801] train loss: [0.5866] (epoch [1/3])
# [168/801] train loss: [0.5511] (epoch [1/3])
# [169/801] train loss: [0.5139] (epoch [1/3])
# [170/801] train loss: [0.4830] (epoch [1/3])
# [171/801] train loss: [0.4540] (epoch [1/3])
# [172/801] train loss: [0.6006] (epoch [1/3])
# [173/801] train loss: [0.5056] (epoch [1/3])
# [174/801] train loss: [0.5366] (epoch [1/3])
# [175/801] train loss: [0.5588] (epoch [1/3])
# [176/801] train loss: [0.4816] (epoch [1/3])
# [177/801] train loss: [0.6995] (epoch [1/3])
# [178/801] train loss: [0.5077] (epoch [1/3])
# [179/801] train loss: [0.4244] (epoch [1/3])
# [180/801] train loss: [0.5323] (epoch [1/3])
# [181/801] train loss: [0.8062] (epoch [1/3])
# [182/801] train loss: [0.4329] (epoch [1/3])
# [183/801] train loss: [0.5047] (epoch [1/3])
# [184/801] train loss: [0.5667] (epoch [1/3])
# [185/801] train loss: [0.6148] (epoch [1/3])
# [186/801] train loss: [0.6214] (epoch [1/3])
# [187/801] train loss: [0.5914] (epoch [1/3])
# [188/801] train loss: [0.8108] (epoch [1/3])
# [189/801] train loss: [0.4449] (epoch [1/3])
# [190/801] train loss: [0.6424] (epoch [1/3])
# [191/801] train loss: [0.6408] (epoch [1/3])
# [192/801] train loss: [0.6852] (epoch [1/3])
# [193/801] train loss: [0.4738] (epoch [1/3])
# [194/801] train loss: [0.5764] (epoch [1/3])
# [195/801] train loss: [0.5962] (epoch [1/3])
# [196/801] train loss: [0.5136] (epoch [1/3])
# [197/801] train loss: [0.5711] (epoch [1/3])
# [198/801] train loss: [0.6023] (epoch [1/3])
# [199/801] train loss: [0.6156] (epoch [1/3])
# [200/801] train loss: [0.5906] (epoch [1/3])
# [200/801] validation loss: [0.6185] validation accuracy: [0.6698]
# [201/801] train loss: [0.5898] (epoch [1/3])
# [202/801] train loss: [0.6868] (epoch [1/3])
# [203/801] train loss: [0.5090] (epoch [1/3])
# [204/801] train loss: [0.4427] (epoch [1/3])
# [205/801] train loss: [0.4021] (epoch [1/3])
# [206/801] train loss: [0.5682] (epoch [1/3])
# [207/801] train loss: [0.6849] (epoch [1/3])
# [208/801] train loss: [0.5490] (epoch [1/3])
# [209/801] train loss: [0.6391] (epoch [1/3])
# [210/801] train loss: [0.4890] (epoch [1/3])
# [211/801] train loss: [0.4745] (epoch [1/3])
# [212/801] train loss: [0.4849] (epoch [1/3])
# [213/801] train loss: [0.6046] (epoch [1/3])
# [214/801] train loss: [0.4943] (epoch [1/3])
# [215/801] train loss: [0.5144] (epoch [1/3])
# [216/801] train loss: [0.6441] (epoch [1/3])
# [217/801] train loss: [0.5102] (epoch [1/3])
# [218/801] train loss: [0.5101] (epoch [1/3])
# [219/801] train loss: [0.6378] (epoch [1/3])
# [220/801] train loss: [0.5981] (epoch [1/3])
# [221/801] train loss: [0.6382] (epoch [1/3])
# [222/801] train loss: [0.5524] (epoch [1/3])
# [223/801] train loss: [0.5768] (epoch [1/3])
# [224/801] train loss: [0.3987] (epoch [1/3])
# [225/801] train loss: [0.5699] (epoch [1/3])
# [226/801] train loss: [0.3712] (epoch [1/3])
# [227/801] train loss: [0.4694] (epoch [1/3])
# [228/801] train loss: [0.8056] (epoch [1/3])
# [229/801] train loss: [0.7318] (epoch [1/3])
# [230/801] train loss: [0.8059] (epoch [1/3])
# [231/801] train loss: [0.7186] (epoch [1/3])
# [232/801] train loss: [0.7201] (epoch [1/3])
# [233/801] train loss: [0.6754] (epoch [1/3])
# [234/801] train loss: [0.6561] (epoch [1/3])
# [235/801] train loss: [0.5636] (epoch [1/3])
# [236/801] train loss: [0.5560] (epoch [1/3])
# [237/801] train loss: [0.5849] (epoch [1/3])
# [238/801] train loss: [0.5971] (epoch [1/3])
# [239/801] train loss: [0.6861] (epoch [1/3])
# [240/801] train loss: [0.5407] (epoch [1/3])
# [241/801] train loss: [0.6514] (epoch [1/3])
# [242/801] train loss: [0.4357] (epoch [1/3])
# [243/801] train loss: [0.6630] (epoch [1/3])
# [244/801] train loss: [0.6070] (epoch [1/3])
# [245/801] train loss: [0.5126] (epoch [1/3])
# [246/801] train loss: [0.5032] (epoch [1/3])
# [247/801] train loss: [0.5859] (epoch [1/3])
# [248/801] train loss: [0.5469] (epoch [1/3])
# [249/801] train loss: [0.6334] (epoch [1/3])
# [250/801] train loss: [0.4189] (epoch [1/3])
# [251/801] train loss: [0.5954] (epoch [1/3])
# [252/801] train loss: [0.5027] (epoch [1/3])
# [253/801] train loss: [0.5809] (epoch [1/3])
# [254/801] train loss: [0.5575] (epoch [1/3])
# [255/801] train loss: [0.5887] (epoch [1/3])
# [256/801] train loss: [0.6713] (epoch [1/3])
# [257/801] train loss: [0.5334] (epoch [1/3])
# [258/801] train loss: [0.4625] (epoch [1/3])
# [259/801] train loss: [0.4169] (epoch [1/3])
# [260/801] train loss: [0.5916] (epoch [1/3])
# [261/801] train loss: [0.6396] (epoch [1/3])
# [262/801] train loss: [0.5305] (epoch [1/3])
# [263/801] train loss: [0.5185] (epoch [1/3])
# [264/801] train loss: [0.5420] (epoch [1/3])
# [265/801] train loss: [0.6023] (epoch [1/3])
# [266/801] train loss: [0.5534] (epoch [1/3])
# [267/801] train loss: [0.5705] (epoch [1/3])
# [268/801] train loss: [0.4779] (epoch [2/3])
# [269/801] train loss: [0.5587] (epoch [2/3])
# [270/801] train loss: [0.6459] (epoch [2/3])
# [271/801] train loss: [0.5712] (epoch [2/3])
# [272/801] train loss: [0.5440] (epoch [2/3])
# [273/801] train loss: [0.7329] (epoch [2/3])
# [274/801] train loss: [0.5262] (epoch [2/3])
# [275/801] train loss: [0.6946] (epoch [2/3])
# [276/801] train loss: [0.5173] (epoch [2/3])
# [277/801] train loss: [0.6592] (epoch [2/3])
# [278/801] train loss: [0.5198] (epoch [2/3])
# [279/801] train loss: [0.3342] (epoch [2/3])
# [280/801] train loss: [0.6834] (epoch [2/3])
# [281/801] train loss: [0.5380] (epoch [2/3])
# [282/801] train loss: [0.6081] (epoch [2/3])
# [283/801] train loss: [0.6565] (epoch [2/3])
# [284/801] train loss: [0.4808] (epoch [2/3])
# [285/801] train loss: [0.5516] (epoch [2/3])
# [286/801] train loss: [0.5291] (epoch [2/3])
# [287/801] train loss: [0.4731] (epoch [2/3])
# [288/801] train loss: [0.6235] (epoch [2/3])
# [289/801] train loss: [0.5939] (epoch [2/3])
# [290/801] train loss: [0.5532] (epoch [2/3])
# [291/801] train loss: [0.4844] (epoch [2/3])
# [292/801] train loss: [0.5020] (epoch [2/3])
# [293/801] train loss: [0.7470] (epoch [2/3])
# [294/801] train loss: [0.6608] (epoch [2/3])
# [295/801] train loss: [0.5279] (epoch [2/3])
# [296/801] train loss: [0.5312] (epoch [2/3])
# [297/801] train loss: [0.5565] (epoch [2/3])
# [298/801] train loss: [0.4575] (epoch [2/3])
# [299/801] train loss: [0.3960] (epoch [2/3])
# [300/801] train loss: [0.7733] (epoch [2/3])
# [300/801] validation loss: [0.6079] validation accuracy: [0.6773]
# [301/801] train loss: [0.7125] (epoch [2/3])
# [302/801] train loss: [0.5306] (epoch [2/3])
# [303/801] train loss: [0.6033] (epoch [2/3])
# [304/801] train loss: [0.5487] (epoch [2/3])
# [305/801] train loss: [0.5733] (epoch [2/3])
# [306/801] train loss: [0.6201] (epoch [2/3])
# [307/801] train loss: [0.4689] (epoch [2/3])
# [308/801] train loss: [0.5319] (epoch [2/3])
# [309/801] train loss: [0.4549] (epoch [2/3])
# [310/801] train loss: [0.7436] (epoch [2/3])
# [311/801] train loss: [0.5561] (epoch [2/3])
# [312/801] train loss: [0.6669] (epoch [2/3])
# [313/801] train loss: [0.6451] (epoch [2/3])
# [314/801] train loss: [0.4805] (epoch [2/3])
# [315/801] train loss: [0.6676] (epoch [2/3])
# [316/801] train loss: [0.4107] (epoch [2/3])
# [317/801] train loss: [0.4942] (epoch [2/3])
# [318/801] train loss: [0.4635] (epoch [2/3])
# [319/801] train loss: [0.6733] (epoch [2/3])
# [320/801] train loss: [0.5605] (epoch [2/3])
# [321/801] train loss: [0.6133] (epoch [2/3])
# [322/801] train loss: [0.6996] (epoch [2/3])
# [323/801] train loss: [0.4666] (epoch [2/3])
# [324/801] train loss: [0.5610] (epoch [2/3])
# [325/801] train loss: [0.5003] (epoch [2/3])
# [326/801] train loss: [0.6007] (epoch [2/3])
# [327/801] train loss: [0.4473] (epoch [2/3])
# [328/801] train loss: [0.6620] (epoch [2/3])
# [329/801] train loss: [0.5480] (epoch [2/3])
# [330/801] train loss: [0.6225] (epoch [2/3])
# [331/801] train loss: [0.4940] (epoch [2/3])
# [332/801] train loss: [0.5280] (epoch [2/3])
# [333/801] train loss: [0.4727] (epoch [2/3])
# [334/801] train loss: [0.4345] (epoch [2/3])
# [335/801] train loss: [0.4525] (epoch [2/3])
# [336/801] train loss: [0.5370] (epoch [2/3])
# [337/801] train loss: [0.5052] (epoch [2/3])
# [338/801] train loss: [0.5043] (epoch [2/3])
# [339/801] train loss: [0.6393] (epoch [2/3])
# [340/801] train loss: [0.6266] (epoch [2/3])
# [341/801] train loss: [0.4820] (epoch [2/3])
# [342/801] train loss: [0.4406] (epoch [2/3])
# [343/801] train loss: [0.3998] (epoch [2/3])
# [344/801] train loss: [0.6396] (epoch [2/3])
# [345/801] train loss: [0.5863] (epoch [2/3])
# [346/801] train loss: [0.4648] (epoch [2/3])
# [347/801] train loss: [0.5980] (epoch [2/3])
# [348/801] train loss: [0.6368] (epoch [2/3])
# [349/801] train loss: [0.5711] (epoch [2/3])
# [350/801] train loss: [0.6507] (epoch [2/3])
# [351/801] train loss: [0.4982] (epoch [2/3])
# [352/801] train loss: [0.4903] (epoch [2/3])
# [353/801] train loss: [0.5882] (epoch [2/3])
# [354/801] train loss: [0.4777] (epoch [2/3])
# [355/801] train loss: [0.4339] (epoch [2/3])
# [356/801] train loss: [0.5676] (epoch [2/3])
# [357/801] train loss: [0.5903] (epoch [2/3])
# [358/801] train loss: [0.5765] (epoch [2/3])
# [359/801] train loss: [0.5512] (epoch [2/3])
# [360/801] train loss: [0.5072] (epoch [2/3])
# [361/801] train loss: [0.5438] (epoch [2/3])
# [362/801] train loss: [0.6355] (epoch [2/3])
# [363/801] train loss: [0.5743] (epoch [2/3])
# [364/801] train loss: [0.5017] (epoch [2/3])
# [365/801] train loss: [0.5528] (epoch [2/3])
# [366/801] train loss: [0.5586] (epoch [2/3])
# [367/801] train loss: [0.5111] (epoch [2/3])
# [368/801] train loss: [0.4358] (epoch [2/3])
# [369/801] train loss: [0.5692] (epoch [2/3])
# [370/801] train loss: [0.4815] (epoch [2/3])
# [371/801] train loss: [0.3525] (epoch [2/3])
# [372/801] train loss: [0.5572] (epoch [2/3])
# [373/801] train loss: [0.6054] (epoch [2/3])
# [374/801] train loss: [0.4809] (epoch [2/3])
# [375/801] train loss: [0.4114] (epoch [2/3])
# [376/801] train loss: [0.5866] (epoch [2/3])
# [377/801] train loss: [0.4380] (epoch [2/3])
# [378/801] train loss: [0.4744] (epoch [2/3])
# [379/801] train loss: [0.5336] (epoch [2/3])
# [380/801] train loss: [0.5936] (epoch [2/3])
# [381/801] train loss: [0.5788] (epoch [2/3])
# [382/801] train loss: [0.6154] (epoch [2/3])
# [383/801] train loss: [0.4975] (epoch [2/3])
# [384/801] train loss: [0.5500] (epoch [2/3])
# [385/801] train loss: [0.5467] (epoch [2/3])
# [386/801] train loss: [0.5101] (epoch [2/3])
# [387/801] train loss: [0.5709] (epoch [2/3])
# [388/801] train loss: [0.4907] (epoch [2/3])
# [389/801] train loss: [0.5165] (epoch [2/3])
# [390/801] train loss: [0.4125] (epoch [2/3])
# [391/801] train loss: [0.4461] (epoch [2/3])
# [392/801] train loss: [0.5354] (epoch [2/3])
# [393/801] train loss: [0.6985] (epoch [2/3])
# [394/801] train loss: [0.6760] (epoch [2/3])
# [395/801] train loss: [0.4419] (epoch [2/3])
# [396/801] train loss: [0.4117] (epoch [2/3])
# [397/801] train loss: [0.4969] (epoch [2/3])
# [398/801] train loss: [0.4358] (epoch [2/3])
# [399/801] train loss: [0.5325] (epoch [2/3])
# [400/801] train loss: [0.5273] (epoch [2/3])
# [400/801] validation loss: [0.5253] validation accuracy: [0.7345]
# [401/801] train loss: [0.4476] (epoch [2/3])
# [402/801] train loss: [0.6717] (epoch [2/3])
# [403/801] train loss: [0.4124] (epoch [2/3])
# [404/801] train loss: [0.4031] (epoch [2/3])
# [405/801] train loss: [0.5592] (epoch [2/3])
# [406/801] train loss: [0.4618] (epoch [2/3])
# [407/801] train loss: [0.5702] (epoch [2/3])
# [408/801] train loss: [0.4768] (epoch [2/3])
# [409/801] train loss: [0.5412] (epoch [2/3])
# [410/801] train loss: [0.5361] (epoch [2/3])
# [411/801] train loss: [0.5158] (epoch [2/3])
# [412/801] train loss: [0.5050] (epoch [2/3])
# [413/801] train loss: [0.6683] (epoch [2/3])
# [414/801] train loss: [0.5638] (epoch [2/3])
# [415/801] train loss: [0.6154] (epoch [2/3])
# [416/801] train loss: [0.4302] (epoch [2/3])
# [417/801] train loss: [0.4611] (epoch [2/3])
# [418/801] train loss: [0.4998] (epoch [2/3])
# [419/801] train loss: [0.6209] (epoch [2/3])
# [420/801] train loss: [0.5677] (epoch [2/3])
# [421/801] train loss: [0.3580] (epoch [2/3])
# [422/801] train loss: [0.5613] (epoch [2/3])
# [423/801] train loss: [0.4440] (epoch [2/3])
# [424/801] train loss: [0.4012] (epoch [2/3])
# [425/801] train loss: [0.5688] (epoch [2/3])
# [426/801] train loss: [0.5477] (epoch [2/3])
# [427/801] train loss: [0.5060] (epoch [2/3])
# [428/801] train loss: [0.3523] (epoch [2/3])
# [429/801] train loss: [0.6081] (epoch [2/3])
# [430/801] train loss: [0.4548] (epoch [2/3])
# [431/801] train loss: [0.4416] (epoch [2/3])
# [432/801] train loss: [0.3359] (epoch [2/3])
# [433/801] train loss: [0.5372] (epoch [2/3])
# [434/801] train loss: [0.4185] (epoch [2/3])
# [435/801] train loss: [0.5213] (epoch [2/3])
# [436/801] train loss: [0.4935] (epoch [2/3])
# [437/801] train loss: [0.5916] (epoch [2/3])
# [438/801] train loss: [0.4566] (epoch [2/3])
# [439/801] train loss: [0.5833] (epoch [2/3])
# [440/801] train loss: [0.4815] (epoch [2/3])
# [441/801] train loss: [0.4304] (epoch [2/3])
# [442/801] train loss: [0.4092] (epoch [2/3])
# [443/801] train loss: [0.5530] (epoch [2/3])
# [444/801] train loss: [0.6036] (epoch [2/3])
# [445/801] train loss: [0.6263] (epoch [2/3])
# [446/801] train loss: [0.5654] (epoch [2/3])
# [447/801] train loss: [0.6130] (epoch [2/3])
# [448/801] train loss: [0.3573] (epoch [2/3])
# [449/801] train loss: [0.6528] (epoch [2/3])
# [450/801] train loss: [0.6605] (epoch [2/3])
# [451/801] train loss: [0.5249] (epoch [2/3])
# [452/801] train loss: [0.5178] (epoch [2/3])
# [453/801] train loss: [0.4361] (epoch [2/3])
# [454/801] train loss: [0.3725] (epoch [2/3])
# [455/801] train loss: [0.5239] (epoch [2/3])
# [456/801] train loss: [0.5745] (epoch [2/3])
# [457/801] train loss: [0.5437] (epoch [2/3])
# [458/801] train loss: [0.4161] (epoch [2/3])
# [459/801] train loss: [0.7565] (epoch [2/3])
# [460/801] train loss: [0.6455] (epoch [2/3])
# [461/801] train loss: [0.4378] (epoch [2/3])
# [462/801] train loss: [0.5189] (epoch [2/3])
# [463/801] train loss: [0.5450] (epoch [2/3])
# [464/801] train loss: [0.6874] (epoch [2/3])
# [465/801] train loss: [0.4772] (epoch [2/3])
# [466/801] train loss: [0.5301] (epoch [2/3])
# [467/801] train loss: [0.6894] (epoch [2/3])
# [468/801] train loss: [0.5231] (epoch [2/3])
# [469/801] train loss: [0.5553] (epoch [2/3])
# [470/801] train loss: [0.6010] (epoch [2/3])
# [471/801] train loss: [0.4432] (epoch [2/3])
# [472/801] train loss: [0.4557] (epoch [2/3])
# [473/801] train loss: [0.4381] (epoch [2/3])
# [474/801] train loss: [0.4538] (epoch [2/3])
# [475/801] train loss: [0.6187] (epoch [2/3])
# [476/801] train loss: [0.4174] (epoch [2/3])
# [477/801] train loss: [0.3968] (epoch [2/3])
# [478/801] train loss: [0.4155] (epoch [2/3])
# [479/801] train loss: [0.6334] (epoch [2/3])
# [480/801] train loss: [0.5057] (epoch [2/3])
# [481/801] train loss: [0.6091] (epoch [2/3])
# [482/801] train loss: [0.5801] (epoch [2/3])
# [483/801] train loss: [0.6662] (epoch [2/3])
# [484/801] train loss: [0.5570] (epoch [2/3])
# [485/801] train loss: [0.5626] (epoch [2/3])
# [486/801] train loss: [0.4200] (epoch [2/3])
# [487/801] train loss: [0.5682] (epoch [2/3])
# [488/801] train loss: [0.5934] (epoch [2/3])
# [489/801] train loss: [0.6601] (epoch [2/3])
# [490/801] train loss: [0.4313] (epoch [2/3])
# [491/801] train loss: [0.4989] (epoch [2/3])
# [492/801] train loss: [0.6461] (epoch [2/3])
# [493/801] train loss: [0.4899] (epoch [2/3])
# [494/801] train loss: [0.4058] (epoch [2/3])
# [495/801] train loss: [0.4136] (epoch [2/3])
# [496/801] train loss: [0.5326] (epoch [2/3])
# [497/801] train loss: [0.5443] (epoch [2/3])
# [498/801] train loss: [0.4754] (epoch [2/3])
# [499/801] train loss: [0.5111] (epoch [2/3])
# [500/801] train loss: [0.3973] (epoch [2/3])
# [500/801] validation loss: [0.5290] validation accuracy: [0.7298]
# [501/801] train loss: [0.7449] (epoch [2/3])
# [502/801] train loss: [0.5908] (epoch [2/3])
# [503/801] train loss: [0.5468] (epoch [2/3])
# [504/801] train loss: [0.4588] (epoch [2/3])
# [505/801] train loss: [0.3901] (epoch [2/3])
# [506/801] train loss: [0.6016] (epoch [2/3])
# [507/801] train loss: [0.5046] (epoch [2/3])
# [508/801] train loss: [0.5341] (epoch [2/3])
# [509/801] train loss: [0.4204] (epoch [2/3])
# [510/801] train loss: [0.6389] (epoch [2/3])
# [511/801] train loss: [0.4437] (epoch [2/3])
# [512/801] train loss: [0.3698] (epoch [2/3])
# [513/801] train loss: [0.5647] (epoch [2/3])
# [514/801] train loss: [0.5634] (epoch [2/3])
# [515/801] train loss: [0.5962] (epoch [2/3])
# [516/801] train loss: [0.6334] (epoch [2/3])
# [517/801] train loss: [0.5756] (epoch [2/3])
# [518/801] train loss: [0.4774] (epoch [2/3])
# [519/801] train loss: [0.6743] (epoch [2/3])
# [520/801] train loss: [0.3519] (epoch [2/3])
# [521/801] train loss: [0.5090] (epoch [2/3])
# [522/801] train loss: [0.5014] (epoch [2/3])
# [523/801] train loss: [0.5582] (epoch [2/3])
# [524/801] train loss: [0.5142] (epoch [2/3])
# [525/801] train loss: [0.6020] (epoch [2/3])
# [526/801] train loss: [0.4323] (epoch [2/3])
# [527/801] train loss: [0.6109] (epoch [2/3])
# [528/801] train loss: [0.6958] (epoch [2/3])
# [529/801] train loss: [0.6047] (epoch [2/3])
# [530/801] train loss: [0.4976] (epoch [2/3])
# [531/801] train loss: [0.6843] (epoch [2/3])
# [532/801] train loss: [0.3585] (epoch [2/3])
# [533/801] train loss: [0.5368] (epoch [2/3])
# [534/801] train loss: [0.4398] (epoch [2/3])
# [535/801] train loss: [0.4519] (epoch [3/3])
# [536/801] train loss: [0.6069] (epoch [3/3])
# [537/801] train loss: [0.5892] (epoch [3/3])
# [538/801] train loss: [0.7185] (epoch [3/3])
# [539/801] train loss: [0.4696] (epoch [3/3])
# [540/801] train loss: [0.4061] (epoch [3/3])
# [541/801] train loss: [0.4555] (epoch [3/3])
# [542/801] train loss: [0.4359] (epoch [3/3])
# [543/801] train loss: [0.3905] (epoch [3/3])
# [544/801] train loss: [0.5505] (epoch [3/3])
# [545/801] train loss: [0.6968] (epoch [3/3])
# [546/801] train loss: [0.5358] (epoch [3/3])
# [547/801] train loss: [0.5867] (epoch [3/3])
# [548/801] train loss: [0.4634] (epoch [3/3])
# [549/801] train loss: [0.6709] (epoch [3/3])
# [550/801] train loss: [0.4598] (epoch [3/3])
# [551/801] train loss: [0.5728] (epoch [3/3])
# [552/801] train loss: [0.5539] (epoch [3/3])
# [553/801] train loss: [0.3592] (epoch [3/3])
# [554/801] train loss: [0.5266] (epoch [3/3])
# [555/801] train loss: [0.4157] (epoch [3/3])
# [556/801] train loss: [0.5886] (epoch [3/3])
# [557/801] train loss: [0.5349] (epoch [3/3])
# [558/801] train loss: [0.5773] (epoch [3/3])
# [559/801] train loss: [0.4108] (epoch [3/3])
# [560/801] train loss: [0.5757] (epoch [3/3])
# [561/801] train loss: [0.5799] (epoch [3/3])
# [562/801] train loss: [0.5045] (epoch [3/3])
# [563/801] train loss: [0.3240] (epoch [3/3])
# [564/801] train loss: [0.5035] (epoch [3/3])
# [565/801] train loss: [0.5198] (epoch [3/3])
# [566/801] train loss: [0.5684] (epoch [3/3])
# [567/801] train loss: [0.5273] (epoch [3/3])
# [568/801] train loss: [0.5652] (epoch [3/3])
# [569/801] train loss: [0.5900] (epoch [3/3])
# [570/801] train loss: [0.4267] (epoch [3/3])
# [571/801] train loss: [0.5282] (epoch [3/3])
# [572/801] train loss: [0.4426] (epoch [3/3])
# [573/801] train loss: [0.4067] (epoch [3/3])
# [574/801] train loss: [0.5022] (epoch [3/3])
# [575/801] train loss: [0.5679] (epoch [3/3])
# [576/801] train loss: [0.4004] (epoch [3/3])
# [577/801] train loss: [0.6282] (epoch [3/3])
# [578/801] train loss: [0.4140] (epoch [3/3])
# [579/801] train loss: [0.4661] (epoch [3/3])
# [580/801] train loss: [0.4501] (epoch [3/3])
# [581/801] train loss: [0.4420] (epoch [3/3])
# [582/801] train loss: [0.5348] (epoch [3/3])
# [583/801] train loss: [0.6231] (epoch [3/3])
# [584/801] train loss: [0.4707] (epoch [3/3])
# [585/801] train loss: [0.4642] (epoch [3/3])
# [586/801] train loss: [0.5189] (epoch [3/3])
# [587/801] train loss: [0.5943] (epoch [3/3])
# [588/801] train loss: [0.4120] (epoch [3/3])
# [589/801] train loss: [0.4899] (epoch [3/3])
# [590/801] train loss: [0.6661] (epoch [3/3])
# [591/801] train loss: [0.5446] (epoch [3/3])
# [592/801] train loss: [0.3971] (epoch [3/3])
# [593/801] train loss: [0.6464] (epoch [3/3])
# [594/801] train loss: [0.4073] (epoch [3/3])
# [595/801] train loss: [0.5245] (epoch [3/3])
# [596/801] train loss: [0.5334] (epoch [3/3])
# [597/801] train loss: [0.5024] (epoch [3/3])
# [598/801] train loss: [0.5979] (epoch [3/3])
# [599/801] train loss: [0.5948] (epoch [3/3])
# [600/801] train loss: [0.4618] (epoch [3/3])
# [600/801] validation loss: [0.5226] validation accuracy: [0.7336]
# [601/801] train loss: [0.5141] (epoch [3/3])
# [602/801] train loss: [0.4999] (epoch [3/3])
# [603/801] train loss: [0.5358] (epoch [3/3])
# [604/801] train loss: [0.5173] (epoch [3/3])
# [605/801] train loss: [0.5220] (epoch [3/3])
# [606/801] train loss: [0.4844] (epoch [3/3])
# [607/801] train loss: [0.5950] (epoch [3/3])
# [608/801] train loss: [0.5375] (epoch [3/3])
# [609/801] train loss: [0.6118] (epoch [3/3])
# [610/801] train loss: [0.6097] (epoch [3/3])
# [611/801] train loss: [0.5971] (epoch [3/3])
# [612/801] train loss: [0.5022] (epoch [3/3])
# [613/801] train loss: [0.5214] (epoch [3/3])
# [614/801] train loss: [0.5526] (epoch [3/3])
# [615/801] train loss: [0.4595] (epoch [3/3])
# [616/801] train loss: [0.4193] (epoch [3/3])
# [617/801] train loss: [0.5860] (epoch [3/3])
# [618/801] train loss: [0.5784] (epoch [3/3])
# [619/801] train loss: [0.5029] (epoch [3/3])
# [620/801] train loss: [0.4639] (epoch [3/3])
# [621/801] train loss: [0.4299] (epoch [3/3])
# [622/801] train loss: [0.3924] (epoch [3/3])
# [623/801] train loss: [0.4172] (epoch [3/3])
# [624/801] train loss: [0.4656] (epoch [3/3])
# [625/801] train loss: [0.4121] (epoch [3/3])
# [626/801] train loss: [0.6338] (epoch [3/3])
# [627/801] train loss: [0.5486] (epoch [3/3])
# [628/801] train loss: [0.5994] (epoch [3/3])
# [629/801] train loss: [0.6005] (epoch [3/3])
# [630/801] train loss: [0.6186] (epoch [3/3])
# [631/801] train loss: [0.4275] (epoch [3/3])
# [632/801] train loss: [0.5169] (epoch [3/3])
# [633/801] train loss: [0.3978] (epoch [3/3])
# [634/801] train loss: [0.3567] (epoch [3/3])
# [635/801] train loss: [0.5429] (epoch [3/3])
# [636/801] train loss: [0.5656] (epoch [3/3])
# [637/801] train loss: [0.4150] (epoch [3/3])
# [638/801] train loss: [0.5933] (epoch [3/3])
# [639/801] train loss: [0.6506] (epoch [3/3])
# [640/801] train loss: [0.4873] (epoch [3/3])
# [641/801] train loss: [0.4031] (epoch [3/3])
# [642/801] train loss: [0.6708] (epoch [3/3])
# [643/801] train loss: [0.5141] (epoch [3/3])
# [644/801] train loss: [0.5820] (epoch [3/3])
# [645/801] train loss: [0.3743] (epoch [3/3])
# [646/801] train loss: [0.4711] (epoch [3/3])
# [647/801] train loss: [0.4761] (epoch [3/3])
# [648/801] train loss: [0.5391] (epoch [3/3])
# [649/801] train loss: [0.5329] (epoch [3/3])
# [650/801] train loss: [0.5209] (epoch [3/3])
# [651/801] train loss: [0.4362] (epoch [3/3])
# [652/801] train loss: [0.5317] (epoch [3/3])
# [653/801] train loss: [0.4436] (epoch [3/3])
# [654/801] train loss: [0.5168] (epoch [3/3])
# [655/801] train loss: [0.3770] (epoch [3/3])
# [656/801] train loss: [0.6875] (epoch [3/3])
# [657/801] train loss: [0.4682] (epoch [3/3])
# [658/801] train loss: [0.4400] (epoch [3/3])
# [659/801] train loss: [0.4730] (epoch [3/3])
# [660/801] train loss: [0.3915] (epoch [3/3])
# [661/801] train loss: [0.4929] (epoch [3/3])
# [662/801] train loss: [0.5664] (epoch [3/3])
# [663/801] train loss: [0.5765] (epoch [3/3])
# [664/801] train loss: [0.5031] (epoch [3/3])
# [665/801] train loss: [0.5310] (epoch [3/3])
# [666/801] train loss: [0.5716] (epoch [3/3])
# [667/801] train loss: [0.3391] (epoch [3/3])
# [668/801] train loss: [0.3839] (epoch [3/3])
# [669/801] train loss: [0.4230] (epoch [3/3])
# [670/801] train loss: [0.4367] (epoch [3/3])
# [671/801] train loss: [0.5080] (epoch [3/3])
# [672/801] train loss: [0.6049] (epoch [3/3])
# [673/801] train loss: [0.5530] (epoch [3/3])
# [674/801] train loss: [0.5416] (epoch [3/3])
# [675/801] train loss: [0.5473] (epoch [3/3])
# [676/801] train loss: [0.5097] (epoch [3/3])
# [677/801] train loss: [0.4354] (epoch [3/3])
# [678/801] train loss: [0.6086] (epoch [3/3])
# [679/801] train loss: [0.5744] (epoch [3/3])
# [680/801] train loss: [0.4388] (epoch [3/3])
# [681/801] train loss: [0.3951] (epoch [3/3])
# [682/801] train loss: [0.4944] (epoch [3/3])
# [683/801] train loss: [0.4857] (epoch [3/3])
# [684/801] train loss: [0.5570] (epoch [3/3])
# [685/801] train loss: [0.4548] (epoch [3/3])
# [686/801] train loss: [0.5197] (epoch [3/3])
# [687/801] train loss: [0.3969] (epoch [3/3])
# [688/801] train loss: [0.5690] (epoch [3/3])
# [689/801] train loss: [0.4567] (epoch [3/3])
# [690/801] train loss: [0.4954] (epoch [3/3])
# [691/801] train loss: [0.5063] (epoch [3/3])
# [692/801] train loss: [0.4084] (epoch [3/3])
# [693/801] train loss: [0.5221] (epoch [3/3])
# [694/801] train loss: [0.5515] (epoch [3/3])
# [695/801] train loss: [0.4956] (epoch [3/3])
# [696/801] train loss: [0.4628] (epoch [3/3])
# [697/801] train loss: [0.5942] (epoch [3/3])
# [698/801] train loss: [0.5350] (epoch [3/3])
# [699/801] train loss: [0.4865] (epoch [3/3])
# [700/801] train loss: [0.5328] (epoch [3/3])
# [700/801] validation loss: [0.5212] validation accuracy: [0.7317]
# [701/801] train loss: [0.5036] (epoch [3/3])
# [702/801] train loss: [0.4086] (epoch [3/3])
# [703/801] train loss: [0.5372] (epoch [3/3])
# [704/801] train loss: [0.3624] (epoch [3/3])
# [705/801] train loss: [0.5182] (epoch [3/3])
# [706/801] train loss: [0.4797] (epoch [3/3])
# [707/801] train loss: [0.5033] (epoch [3/3])
# [708/801] train loss: [0.4454] (epoch [3/3])
# [709/801] train loss: [0.5470] (epoch [3/3])
# [710/801] train loss: [0.4256] (epoch [3/3])
# [711/801] train loss: [0.4485] (epoch [3/3])
# [712/801] train loss: [0.4513] (epoch [3/3])
# [713/801] train loss: [0.6546] (epoch [3/3])
# [714/801] train loss: [0.3373] (epoch [3/3])
# [715/801] train loss: [0.5482] (epoch [3/3])
# [716/801] train loss: [0.4332] (epoch [3/3])
# [717/801] train loss: [0.4645] (epoch [3/3])
# [718/801] train loss: [0.5269] (epoch [3/3])
# [719/801] train loss: [0.5572] (epoch [3/3])
# [720/801] train loss: [0.4389] (epoch [3/3])
# [721/801] train loss: [0.6155] (epoch [3/3])
# [722/801] train loss: [0.4721] (epoch [3/3])
# [723/801] train loss: [0.3959] (epoch [3/3])
# [724/801] train loss: [0.4541] (epoch [3/3])
# [725/801] train loss: [0.6522] (epoch [3/3])
# [726/801] train loss: [0.4601] (epoch [3/3])
# [727/801] train loss: [0.4155] (epoch [3/3])
# [728/801] train loss: [0.4592] (epoch [3/3])
# [729/801] train loss: [0.4601] (epoch [3/3])
# [730/801] train loss: [0.5158] (epoch [3/3])
# [731/801] train loss: [0.4910] (epoch [3/3])
# [732/801] train loss: [0.3292] (epoch [3/3])
# [733/801] train loss: [0.5177] (epoch [3/3])
# [734/801] train loss: [0.5084] (epoch [3/3])
# [735/801] train loss: [0.4936] (epoch [3/3])
# [736/801] train loss: [0.5337] (epoch [3/3])
# [737/801] train loss: [0.3794] (epoch [3/3])
# [738/801] train loss: [0.5471] (epoch [3/3])
# [739/801] train loss: [0.4001] (epoch [3/3])
# [740/801] train loss: [0.3948] (epoch [3/3])
# [741/801] train loss: [0.5354] (epoch [3/3])
# [742/801] train loss: [0.3283] (epoch [3/3])
# [743/801] train loss: [0.4056] (epoch [3/3])
# [744/801] train loss: [0.3932] (epoch [3/3])
# [745/801] train loss: [0.4152] (epoch [3/3])
# [746/801] train loss: [0.4645] (epoch [3/3])
# [747/801] train loss: [0.4456] (epoch [3/3])
# [748/801] train loss: [0.6342] (epoch [3/3])
# [749/801] train loss: [0.4536] (epoch [3/3])
# [750/801] train loss: [0.4433] (epoch [3/3])
# [751/801] train loss: [0.4139] (epoch [3/3])
# [752/801] train loss: [0.5037] (epoch [3/3])
# [753/801] train loss: [0.5370] (epoch [3/3])
# [754/801] train loss: [0.4493] (epoch [3/3])
# [755/801] train loss: [0.4620] (epoch [3/3])
# [756/801] train loss: [0.5637] (epoch [3/3])
# [757/801] train loss: [0.4939] (epoch [3/3])
# [758/801] train loss: [0.4024] (epoch [3/3])
# [759/801] train loss: [0.3748] (epoch [3/3])
# [760/801] train loss: [0.5701] (epoch [3/3])
# [761/801] train loss: [0.5154] (epoch [3/3])
# [762/801] train loss: [0.4782] (epoch [3/3])
# [763/801] train loss: [0.4577] (epoch [3/3])
# [764/801] train loss: [0.5337] (epoch [3/3])
# [765/801] train loss: [0.3900] (epoch [3/3])
# [766/801] train loss: [0.5941] (epoch [3/3])
# [767/801] train loss: [0.5207] (epoch [3/3])
# [768/801] train loss: [0.4970] (epoch [3/3])
# [769/801] train loss: [0.6946] (epoch [3/3])
# [770/801] train loss: [0.4539] (epoch [3/3])
# [771/801] train loss: [0.3726] (epoch [3/3])
# [772/801] train loss: [0.5190] (epoch [3/3])
# [773/801] train loss: [0.5061] (epoch [3/3])
# [774/801] train loss: [0.4479] (epoch [3/3])
# [775/801] train loss: [0.4757] (epoch [3/3])
# [776/801] train loss: [0.6230] (epoch [3/3])
# [777/801] train loss: [0.5038] (epoch [3/3])
# [778/801] train loss: [0.5288] (epoch [3/3])
# [779/801] train loss: [0.5674] (epoch [3/3])
# [780/801] train loss: [0.4991] (epoch [3/3])
# [781/801] train loss: [0.5327] (epoch [3/3])
# [782/801] train loss: [0.8411] (epoch [3/3])
# [783/801] train loss: [0.6165] (epoch [3/3])
# [784/801] train loss: [0.4154] (epoch [3/3])
# [785/801] train loss: [0.4508] (epoch [3/3])
# [786/801] train loss: [0.6282] (epoch [3/3])
# [787/801] train loss: [0.4920] (epoch [3/3])
# [788/801] train loss: [0.4376] (epoch [3/3])
# [789/801] train loss: [0.3996] (epoch [3/3])
# [790/801] train loss: [0.5317] (epoch [3/3])
# [791/801] train loss: [0.4025] (epoch [3/3])
# [792/801] train loss: [0.4673] (epoch [3/3])
# [793/801] train loss: [0.6421] (epoch [3/3])
# [794/801] train loss: [0.5126] (epoch [3/3])
# [795/801] train loss: [0.4810] (epoch [3/3])
# [796/801] train loss: [0.5005] (epoch [3/3])
# [797/801] train loss: [0.4378] (epoch [3/3])
# [798/801] train loss: [0.4828] (epoch [3/3])
# [799/801] train loss: [0.4046] (epoch [3/3])
# [800/801] train loss: [0.5195] (epoch [3/3])
# [800/801] validation loss: [0.5218] validation accuracy: [0.7326]
# [801/801] train loss: [0.4748] (epoch [3/3])

# %%
# test loss
cls_model.eval()

test_loss = compute_loss(test_loader)
    
test_acc = compute_accuracy(test_loader)

print(f"Test Loss: [{test_loss:.4f}]\nTest accuracy: [{test_acc:.4f}]")
# Out:
# Test Loss: [0.5169]
# Test accuracy: [0.7364]

# %%
test_word = "It is the law of Inverse Relevance: the less you intend to do about something, the more you have to keep talking about it."

toks = tokenizer.encode(test_word, return_tensors="pt")
F.sigmoid(cls_model.forward(toks["input_ids"].to(device), toks["attention_mask"].to(device))).detach().cpu().item()
# Out:
# 0.3715182840824127

# %%
# visualization 1: train / val curve

val_steps = [i * val_steps for i in range(len(val_losses))]


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# loss
ax1.plot(train_losses, label='Training Loss', marker='x')
ax1.plot(val_steps, val_losses, label='Validation Loss', marker='o')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Training Steps')
ax1.set_ylabel('Loss')
ax1.grid(True)
ax1.legend()

# acc
ax2.plot(val_steps, val_accs, label='Validation Accuracy', color='green', marker='x')
ax2.set_title('Validation Accuracy')
ax2.set_xlabel('Training Steps')
ax2.set_ylabel('Accuracy')
ax2.grid(True)
ax2.legend()


plt.tight_layout()
plt.show()

# %%
# compute predictions and labels for confusion matrix computing
def compute_pedictions_and_labels(
        model : nn.Module, 
        test_loader : DataLoader, 
        device : torch.device
    ) -> tuple:
    
    model.to(device)
    
    model.eval()
    
    # Lists to store all predictions and actual labels
    all_predictions = []
    all_labels = []
    
    with torch.no_grad():
        for data in test_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)
            
            logits = model(input_ids, attention_mask=attention_mask)
     
            predictions = (logits > 0).long()
            
            all_predictions.extend(predictions.view(-1).cpu().numpy())
            all_labels.extend(labels.view(-1).cpu().numpy())
    
    return all_predictions, all_labels

all_predictions, all_labels = compute_pedictions_and_labels(cls_model, test_loader, device)

# %%
# visualization 2: confusion matrix

def plot_confusion(
        all_predictions : list, 
        all_labels : list
    ) -> None:      
            
    cm = confusion_matrix(all_labels, all_predictions) # from sklearn
            
    plt.figure(figsize=(6,4))
    sns.heatmap(cm, annot=True, fmt='d', linewidths=0.2, cmap="YlGnBu", cbar=False)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.xticks([0.5, 1.5], ['Negative', 'Positive'])
    plt.yticks([0.5, 1.5], ['Negative', 'Positive'], va='center')
    plt.show()
    
plot_confusion(all_predictions, all_labels)

# %%
def plot_f1_score(
        all_predictions : list, 
        all_labels : list
    ) -> None:
    f1 = f1_score(all_labels, all_predictions)
    print("F1 Score: ", f1)
    
plot_f1_score(all_predictions, all_labels)
# Out:
# F1 Score:  0.7300672430355427

# %%
def plot_roc_curve(
        all_predictions : list, 
        all_labels : list
    ) -> None:
    fpr, tpr, _ = roc_curve(all_labels, all_predictions)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='r', lw=2, label=f"ROC curve (area = {roc_auc:0.4f})")
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("Receiver Operating Characteristic")
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()
    
plot_roc_curve(all_predictions, all_labels)

# %%
def plot_precision_recall_curve(
        all_predictions : list, 
        all_labels : list
    ) -> None:
    precision, recall, _ = precision_recall_curve(all_labels, all_predictions)
    average_precision = average_precision_score(all_labels, all_predictions)

    plt.figure()
    plt.step(recall, precision, color='b', alpha=0.2, where='post')
    plt.fill_between(recall, precision, step='post', alpha=0.2, color='b')
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title(f"Precision-Recall curve: AP={average_precision:.4f}")
    plt.grid(True)
    plt.show()
    
plot_precision_recall_curve(all_predictions, all_labels)
