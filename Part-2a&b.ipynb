# %%
GLOVE_PATH = "glove.6B.100d.txt" # change to your path
EMBED_DIM = 100 # No need to change

# %%
from transformers import get_cosine_schedule_with_warmup
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.utils.data import DataLoader, Dataset 
import matplotlib as mpl
import matplotlib.pyplot as plt
from tensorflow import keras
import pandas as pd
import numpy as np
import random
from sklearn.metrics import confusion_matrix, f1_score, f1_score, roc_curve, auc, precision_recall_curve, average_precision_score
import seaborn as sns
from Embeddings import GloveEmbedding, GloveTokenizerNoSub
import itertools
import torch
from torch.utils.data import DataLoader
from typing import Any
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import copy

# %%
# set seeds
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
set_seed(114514)

# %%
# import tokenizer
tokenizer_no_sub = GloveTokenizerNoSub(glove_file_path=GLOVE_PATH)
embedding = GloveEmbedding(
    glove_file_path = GLOVE_PATH, 
    trainable = False # False for part 2 to disable the Embedding training
)

# %%
class SentimentRNN(nn.Module):
    def __init__(self, embedding, hidden_size, embed_size, bidirectional, num_rnn_layer, dropout_rate, layer_norm):
        super(SentimentRNN, self).__init__()
        self.embedding = embedding  # pass pretrained embedding in
        self.bidirectional = bidirectional
        self.rnn = nn.RNN(embed_size, hidden_size, batch_first=True, num_layers = num_rnn_layer, bidirectional=bidirectional, dropout = dropout_rate if num_rnn_layer > 1 else 0)
        
        # if bidirectional, the output hidden size is double
        self.hidden_size = hidden_size * 2 if bidirectional else hidden_size
        
        # MLP
        if not layer_norm:
            self.output_layer = nn.Sequential(
                nn.Dropout(dropout_rate),
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.GELU(),
                nn.Linear(self.hidden_size, 1),  # output dimension is 1 (sigmoid is in BCELossWithLogits, so no sigmoid here. This will get better result)
            )
        else:
            self.output_layer = nn.Sequential(
                nn.LayerNorm(self.hidden_size),
                nn.Dropout(dropout_rate),
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.LayerNorm(self.hidden_size),
                nn.GELU(),
                nn.Linear(self.hidden_size, 1), 
            )
        
    def forward(self, input_ids, attention_mask):
        '''
        This method is designed for biLSTM/GRU/RNN. For LSTM/GRU/RNN for only one direction, just take hidden as the rnn output.
        RNN - hidden -> MLP --> outcome
        '''
        # embed the input
        embedded = self.embedding(input_ids)  # [batch_size, seq_length, embedding_dim]
        
        # feed forward
        output, hidden = self.rnn(embedded) # we don't need encoder so we only keep the output

        # make attention mask from [batch_size, seq_length] to [batch_size, seq_length, 1] as the same dimension as rnn
        attention_mask = attention_mask.unsqueeze(-1)  # [batch_size, seq_length, 1]

        # use attention mask to mask the output, ignore the padding embedding vector, only add the valid embedding vector 
        masked_output = output * attention_mask

        # sum up all the valid output
        summed_output = masked_output.sum(dim=1)  # [batch_size, hidden_size]

        logits = self.output_layer(summed_output)
        
        return logits  # The output is [batch_size, 1]

# %%
# import datasets

train_df = pd.read_csv("./preprocessed_dataset/train.csv").iloc[:,1:]
validation_df = pd.read_csv("./preprocessed_dataset/validation.csv").iloc[:,1:]
test_df = pd.read_csv("./preprocessed_dataset/test.csv").iloc[:,1:]

# %%
# try to use tokenizer api
tokenizer_no_sub.encode(["hello world", "how are you"], return_tensors = "pt") # insist to return pytorch
# Out:
# {'input_ids': tensor([[13077,    87,     0],
#          [  199,    34,    83]]),
#  'attention_mask': tensor([[1, 1, 0],
#          [1, 1, 1]])}

# %%
# Hyper paramaters
dropout_rate = 0.1
num_rnn_layer = 1
hidden_dim = 256

val_steps = 100 # compute validation error every n step

num_train_epochs = 3

batch_size = 32
lr = 8e-5
weight_decay = 1e-5


warmup_ratio=0.1
max_grad_norm = 2.0

# %%
# define dataset and data loader
class CustomizeDataset(Dataset):
    def __init__(
            self,
            df : pd.DataFrame
        ) -> None:
        super().__init__()
        self.df = df
        
    def __len__(self) -> int:
        return len(self.df)
    
    def __getitem__(
            self, 
            index : int
        ) -> dict:
        
        inputs = self.df.iloc[index,0] # 0 is text
        label = self.df.iloc[index, 1] # 1 is label
        
        return {
            "input_str" : inputs, # output a string
            "label" : label # output a label
        }
        
# collater function (used for dynamic padding to save memory)
class Collater:
    def __init__(
            self,
            tokenizer_no_sub : GloveTokenizerNoSub
        ) -> None:
        self.tokenizer_no_sub = tokenizer_no_sub 
    
    def __call__(
            self,
            instances : list # a list of string
        ) -> Any:
        # __call__ is for function-like object
        input_str_list = [instance["input_str"] for instance in instances]
        input_dict = tokenizer_no_sub.encode(input_str_list, return_tensors = "pt") # return pytorch tensor
        input_ids = input_dict["input_ids"]
        attention_mask = input_dict["attention_mask"]
        label = [torch.tensor(instance["label"], dtype = torch.int64) for instance in instances]

        return {
            "input_ids": input_ids,
            "label": torch.tensor(label),
            "attention_mask": attention_mask # mask the pad position
        }

# %%
# create dataset and data loader
collate_fn = Collater(tokenizer_no_sub)



train_ds = CustomizeDataset(
    df = train_df
)

train_loader = DataLoader(
    dataset = train_ds,
    batch_size = batch_size,
    collate_fn = collate_fn,
    shuffle = True
)

val_ds = CustomizeDataset(
    df = validation_df
)

val_loader = DataLoader(
    dataset = val_ds,
    batch_size = batch_size,
    collate_fn = collate_fn
)

test_ds = CustomizeDataset(
    df = test_df
)

test_loader = DataLoader(
    dataset = test_ds,
    batch_size = batch_size,
    collate_fn = collate_fn
)

# %%
# compute warmup status
num_training_steps = num_train_epochs * len(train_loader)
num_warmup_steps = int(num_training_steps * warmup_ratio)
print(f"train:{num_training_steps}, warm up: {num_warmup_steps}")
# Out:
# train:801, warm up: 80

# %%
# Set optimizer, loss_fn and so on

cls_model = SentimentRNN(
    embedding = embedding, 
    hidden_size = hidden_dim, 
    embed_size = EMBED_DIM, 
    bidirectional = False, #  False for part 2
    num_rnn_layer = num_rnn_layer,
    dropout_rate = dropout_rate,
    layer_norm = True # set if you need layer norm
)

loss_fn = nn.BCEWithLogitsLoss()

optimizer = AdamW(
    params = cls_model.parameters(),
    lr = lr,
    weight_decay = weight_decay
)

scheduler  = get_cosine_schedule_with_warmup(
    optimizer = optimizer,
    num_warmup_steps = num_warmup_steps,
    num_training_steps = num_training_steps
)

# %%
# compute accuracy for wach data loader

def compute_accuracy(data_loader: DataLoader) -> float:
    
    cls_model.eval()
    
    correct = 0
    total = 0
    
    with torch.no_grad():
        for data in data_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)
            
            logits = cls_model(input_ids, attention_mask=attention_mask)
     
            predictions = (logits > 0).long()
            
            correct += (predictions == labels).sum().item()
            total += labels.size(0)
    
    accuracy = correct / total
    return accuracy

def compute_loss(data_loader: DataLoader) -> float:
    total_loss = 0
    cls_model.eval()
    with torch.no_grad():
        for data in data_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)
            
            logits = cls_model.forward(input_ids, attention_mask)
            loss = loss_fn.forward(
                input = logits,
                target = labels
            )
            
            total_loss += loss.detach().cpu()
            
        total_loss /= len(val_loader)
        
        return total_loss

# %%
def early_stopping(train_loss, validation_loss, min_delta, tolerance, counter):
    positive_diff = abs(validation_loss - train_loss)

    # Increment counter if no significant improvement
    if positive_diff >= min_delta:
        counter += 1
        if counter >= tolerance:
            return True, counter
    # Ensure the function always returns both values
    return False, counter

# %%
# Training loop

cls_model.to(device)

optimizer.zero_grad()

step = 0

train_losses = []

val_accs = []

val_losses = []

counter = 0

for epoch in range(num_train_epochs):
    
    # train loop
    for data in train_loader:
        cls_model.train()
        input_ids = data["input_ids"].to(device)
        attention_mask = data["attention_mask"].to(device)
        label = data["label"].view(-1, 1).float().to(device)
        
        logits = cls_model.forward(input_ids, attention_mask)
        
        
        loss = loss_fn.forward(
            input = logits,
            target = label
        )
        
        loss.backward()

        # Gradient clip (important for RNN, not necessary for LSTM/GRU/conv1d)
        torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)
        
        optimizer.step() # update paramater
        scheduler.step() 
        optimizer.zero_grad() # clear gradient
        
        vis_loss = loss.detach().cpu()
        
        print(f"[{step + 1}/{num_training_steps}] train loss: [{vis_loss:.4f}] (epoch [{epoch + 1}/{num_train_epochs}])")
        
        
        train_losses.append(vis_loss)
        i =0 

        if (step + 1) % val_steps == 0 or step == 0:
            # compute validation every "val_steps"
           
            cls_model.eval()
            val_loss = compute_loss(val_loader)
            val_acc = compute_accuracy(val_loader)
            val_accs.append(val_acc)
            val_losses.append(val_loss)
            
            print(f"[{step + 1}/{num_training_steps}] validation loss: [{val_loss:.4f}] validation accuracy: [{val_acc:.4f}]")
            # Apply early stopping
            should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.01, tolerance=2, counter=counter)
            if should_stop:
                print("Early stopping triggered.")
                break
        
        step += 1
        
    if should_stop:
        break  # Exit e
# Out:
# [1/801] train loss: [0.7229] (epoch [1/3])
# [1/801] validation loss: [0.7005] validation accuracy: [0.4981]
# [2/801] train loss: [0.7196] (epoch [1/3])
# [3/801] train loss: [0.7347] (epoch [1/3])
# [4/801] train loss: [0.7215] (epoch [1/3])
# [5/801] train loss: [0.7200] (epoch [1/3])
# [6/801] train loss: [0.7437] (epoch [1/3])
# [7/801] train loss: [0.6639] (epoch [1/3])
# [8/801] train loss: [0.7321] (epoch [1/3])
# [9/801] train loss: [0.6915] (epoch [1/3])
# [10/801] train loss: [0.7232] (epoch [1/3])
# [11/801] train loss: [0.6936] (epoch [1/3])
# [12/801] train loss: [0.6853] (epoch [1/3])
# [13/801] train loss: [0.7137] (epoch [1/3])
# [14/801] train loss: [0.6974] (epoch [1/3])
# [15/801] train loss: [0.6878] (epoch [1/3])
# [16/801] train loss: [0.6936] (epoch [1/3])
# [17/801] train loss: [0.7036] (epoch [1/3])
# [18/801] train loss: [0.6968] (epoch [1/3])
# [19/801] train loss: [0.7112] (epoch [1/3])
# [20/801] train loss: [0.6952] (epoch [1/3])
# [21/801] train loss: [0.6948] (epoch [1/3])
# [22/801] train loss: [0.6913] (epoch [1/3])
# [23/801] train loss: [0.7010] (epoch [1/3])
# [24/801] train loss: [0.6954] (epoch [1/3])
# [25/801] train loss: [0.6756] (epoch [1/3])
# [26/801] train loss: [0.6705] (epoch [1/3])
# [27/801] train loss: [0.6979] (epoch [1/3])
# [28/801] train loss: [0.7172] (epoch [1/3])
# [29/801] train loss: [0.6899] (epoch [1/3])
# [30/801] train loss: [0.7123] (epoch [1/3])
# [31/801] train loss: [0.6817] (epoch [1/3])
# [32/801] train loss: [0.6958] (epoch [1/3])
# [33/801] train loss: [0.6776] (epoch [1/3])
# [34/801] train loss: [0.7356] (epoch [1/3])
# [35/801] train loss: [0.6986] (epoch [1/3])
# [36/801] train loss: [0.6899] (epoch [1/3])
# [37/801] train loss: [0.6921] (epoch [1/3])
# [38/801] train loss: [0.6975] (epoch [1/3])
# [39/801] train loss: [0.7086] (epoch [1/3])
# [40/801] train loss: [0.6700] (epoch [1/3])
# [41/801] train loss: [0.7106] (epoch [1/3])
# [42/801] train loss: [0.7013] (epoch [1/3])
# [43/801] train loss: [0.7009] (epoch [1/3])
# [44/801] train loss: [0.6699] (epoch [1/3])
# [45/801] train loss: [0.6613] (epoch [1/3])
# [46/801] train loss: [0.6669] (epoch [1/3])
# [47/801] train loss: [0.6810] (epoch [1/3])
# [48/801] train loss: [0.7057] (epoch [1/3])
# [49/801] train loss: [0.6704] (epoch [1/3])
# [50/801] train loss: [0.6730] (epoch [1/3])
# [51/801] train loss: [0.6774] (epoch [1/3])
# [52/801] train loss: [0.6710] (epoch [1/3])
# [53/801] train loss: [0.6631] (epoch [1/3])
# [54/801] train loss: [0.6919] (epoch [1/3])
# [55/801] train loss: [0.6569] (epoch [1/3])
# [56/801] train loss: [0.6602] (epoch [1/3])
# [57/801] train loss: [0.6873] (epoch [1/3])
# [58/801] train loss: [0.6438] (epoch [1/3])
# [59/801] train loss: [0.6703] (epoch [1/3])
# [60/801] train loss: [0.7084] (epoch [1/3])
# [61/801] train loss: [0.6915] (epoch [1/3])
# [62/801] train loss: [0.6476] (epoch [1/3])
# [63/801] train loss: [0.6408] (epoch [1/3])
# [64/801] train loss: [0.7096] (epoch [1/3])
# [65/801] train loss: [0.6855] (epoch [1/3])
# [66/801] train loss: [0.6791] (epoch [1/3])
# [67/801] train loss: [0.7100] (epoch [1/3])
# [68/801] train loss: [0.6627] (epoch [1/3])
# [69/801] train loss: [0.6778] (epoch [1/3])
# [70/801] train loss: [0.6856] (epoch [1/3])
# [71/801] train loss: [0.6586] (epoch [1/3])
# [72/801] train loss: [0.6335] (epoch [1/3])
# [73/801] train loss: [0.6185] (epoch [1/3])
# [74/801] train loss: [0.6436] (epoch [1/3])
# [75/801] train loss: [0.6511] (epoch [1/3])
# [76/801] train loss: [0.6864] (epoch [1/3])
# [77/801] train loss: [0.6811] (epoch [1/3])
# [78/801] train loss: [0.6442] (epoch [1/3])
# [79/801] train loss: [0.5780] (epoch [1/3])
# [80/801] train loss: [0.6412] (epoch [1/3])
# [81/801] train loss: [0.7313] (epoch [1/3])
# [82/801] train loss: [0.7112] (epoch [1/3])
# [83/801] train loss: [0.7997] (epoch [1/3])
# [84/801] train loss: [0.6375] (epoch [1/3])
# [85/801] train loss: [0.6226] (epoch [1/3])
# [86/801] train loss: [0.6166] (epoch [1/3])
# [87/801] train loss: [0.6581] (epoch [1/3])
# [88/801] train loss: [0.6958] (epoch [1/3])
# [89/801] train loss: [0.6316] (epoch [1/3])
# [90/801] train loss: [0.6512] (epoch [1/3])
# [91/801] train loss: [0.7286] (epoch [1/3])
# [92/801] train loss: [0.6218] (epoch [1/3])
# [93/801] train loss: [0.5910] (epoch [1/3])
# [94/801] train loss: [0.6492] (epoch [1/3])
# [95/801] train loss: [0.6517] (epoch [1/3])
# [96/801] train loss: [0.6022] (epoch [1/3])
# [97/801] train loss: [0.7119] (epoch [1/3])
# [98/801] train loss: [0.6573] (epoch [1/3])
# [99/801] train loss: [0.6395] (epoch [1/3])
# [100/801] train loss: [0.6761] (epoch [1/3])
# [100/801] validation loss: [0.6305] validation accuracy: [0.6811]
# Early stopping triggered.

# %%
# Test the model
# Define hyperparameter ranges
param_grid = {
    "num_rnn_layer": range(1, 2),  # Integer range for number of RNN layers
    "hidden_dim": [128, 256],  # Integer range for hidden dimension size
    "dropout_rate": [0.1, 0.2],  # Continuous range for dropout rate
    "learning_rate": [1e-4, 1e-3],  # Continuous range for learning rate
    "batch_size": [128, 256],  # Integer range for batch size
    "max_grad_norm": [1.0, 2.0],  # Continuous range for gradient clipping
    "num_train_epochs": [1,2,3]  # Integer range for number of training epochs
}

# Track the best configuration
best_val_loss = float('inf')
best_val_accuracy = 0.0
best_params = None

# Generate all combinations of hyperparameters
for params in itertools.product(
    param_grid["num_rnn_layer"],
    param_grid["hidden_dim"],
    param_grid["dropout_rate"],
    param_grid["learning_rate"],
    param_grid["batch_size"],
    param_grid["max_grad_norm"],
    param_grid["num_train_epochs"]
):
    # Unpack hyperparameters
    num_rnn_layer, hidden_dim, dropout_rate, learning_rate, batch_size, max_grad_norm, num_train_epochs = params
    
    # Initialize model with current parameters
    cls_model = SentimentRNN(
        embedding=embedding,
        hidden_size=hidden_dim,
        embed_size=EMBED_DIM,
        bidirectional=False,
        num_rnn_layer=num_rnn_layer,
        dropout_rate=dropout_rate,
        layer_norm=True
    ).to(device)
    
    # Set up optimizer and scheduler
    optimizer = torch.optim.Adam(cls_model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)
    
    # DataLoader for selected batch size
    train_loader = DataLoader(
        dataset=train_ds,
        batch_size=batch_size,
        collate_fn=collate_fn,
        shuffle=True
    )
    
    # Early stopping and metrics tracking variables
    counter = 0
    step = 0
    train_losses = []
    val_losses = []
    val_accs = []
    should_stop = False
    early_stopped = False  # Flag to indicate early stopping for this trial
    
    for epoch in range(num_train_epochs):
        # Training loop
        for data in train_loader:
            cls_model.train()
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            label = data["label"].view(-1, 1).float().to(device)
            
            logits = cls_model(input_ids, attention_mask)
            
            loss = loss_fn(input=logits, target=label)
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)
            
            optimizer.step()
            scheduler.step()
            optimizer.zero_grad()
            
            vis_loss = loss.detach().cpu().item()
            train_losses.append(vis_loss)
            
            # Validation step every `val_steps`
            if (step + 1) % val_steps == 0 or step == 0:
                cls_model.eval()
                val_loss = compute_loss(val_loader)
                val_acc = compute_accuracy(val_loader)
                val_losses.append(val_loss)
                val_accs.append(val_acc)
                
                # Early stopping check
                should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.5, tolerance=2, counter=counter)
                if should_stop:
                    print("Early stopping triggered.")
                    early_stopped = True  # Mark this trial as early stopped
                    break

            step += 1
        
        if should_stop:
            break  # Exit epoch loop if early stopping is triggered

    # Track the best parameters and validation loss
    current_val_loss = val_losses[-1] if val_losses else float('inf')
    current_val_accuracy = val_accs[-1] if val_accs else 0.0
    if current_val_accuracy > best_val_accuracy and early_stopped==False:
        best_val_loss = current_val_loss
        best_val_accuracy = current_val_accuracy
        best_params = params
    
    # Print the trial's results, including early stopping info
    print(f"Trial with params: {params}")
    print(f"  Validation Loss: {current_val_loss}")
    print(f"  Validation Accuracy: {current_val_accuracy}")
    if early_stopped:
        print("  Early stopped")
    

# Print the best result
print("Best result:")
print(f"  Validation Loss: {best_val_loss}")
print(f"  Validation Accuracy: {best_val_accuracy}")
print("  Best hyperparameters:", best_params)
# Out:
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.6849384307861328
#   Validation Accuracy: 0.575046904315197
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6882970929145813
#   Validation Accuracy: 0.5469043151969981
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6943038702011108
#   Validation Accuracy: 0.49624765478424016
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.6925140023231506
#   Validation Accuracy: 0.5215759849906192
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6873345375061035
#   Validation Accuracy: 0.525328330206379
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6874017715454102
#   Validation Accuracy: 0.5412757973733584
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6906883120536804
#   Validation Accuracy: 0.5459662288930581
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6896554231643677
#   Validation Accuracy: 0.5150093808630394
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6931682825088501
#   Validation Accuracy: 0.5234521575984991
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.697262167930603
#   Validation Accuracy: 0.5046904315196998
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6921278238296509
#   Validation Accuracy: 0.5281425891181989
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6747461557388306
#   Validation Accuracy: 0.6238273921200751
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.7956108450889587
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6488251686096191
#   Validation Accuracy: 0.6435272045028143
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6271645426750183
#   Validation Accuracy: 0.6538461538461539
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.6937481760978699
#   Validation Accuracy: 0.5084427767354597
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.676024854183197
#   Validation Accuracy: 0.6322701688555347
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6626583337783813
#   Validation Accuracy: 0.6782363977485929
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.6939093470573425
#   Validation Accuracy: 0.5159474671669794
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.789951503276825
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.628273069858551
#   Validation Accuracy: 0.6538461538461539
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.7540781497955322
#   Validation Accuracy: 0.4981238273921201
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.7685545086860657
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6679579019546509
#   Validation Accuracy: 0.6801125703564728
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.7048329710960388
#   Validation Accuracy: 0.4915572232645403
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6862488389015198
#   Validation Accuracy: 0.551594746716698
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6813659071922302
#   Validation Accuracy: 0.5919324577861164
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.6909096837043762
#   Validation Accuracy: 0.5159474671669794
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6828793287277222
#   Validation Accuracy: 0.5609756097560976
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6949745416641235
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6967495679855347
#   Validation Accuracy: 0.4971857410881801
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6908329129219055
#   Validation Accuracy: 0.5178236397748592
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6846229434013367
#   Validation Accuracy: 0.5769230769230769
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.6972432136535645
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.7182976603507996
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6814782023429871
#   Validation Accuracy: 0.5919324577861164
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.7521442174911499
#   Validation Accuracy: 0.4981238273921201
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6434531807899475
#   Validation Accuracy: 0.6604127579737336
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6167887449264526
#   Validation Accuracy: 0.6697936210131332
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.7946929931640625
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.6334399580955505
#   Validation Accuracy: 0.6726078799249531
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6718835234642029
#   Validation Accuracy: 0.650093808630394
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.7510470747947693
#   Validation Accuracy: 0.4981238273921201
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.7354105114936829
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6035175919532776
#   Validation Accuracy: 0.6754221388367729
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.7262442111968994
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.7326773405075073
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6371601223945618
#   Validation Accuracy: 0.6547842401500938
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.6948399543762207
#   Validation Accuracy: 0.4896810506566604
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.671406626701355
#   Validation Accuracy: 0.6116322701688556
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6631417274475098
#   Validation Accuracy: 0.6529080675422139
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.6990914940834045
#   Validation Accuracy: 0.4831144465290807
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6785765290260315
#   Validation Accuracy: 0.6163227016885553
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6771132946014404
#   Validation Accuracy: 0.6031894934333959
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6997154355049133
#   Validation Accuracy: 0.4634146341463415
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6955476999282837
#   Validation Accuracy: 0.4981238273921201
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6663771271705627
#   Validation Accuracy: 0.6444652908067542
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.7031262516975403
#   Validation Accuracy: 0.49530956848030017
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.7050662040710449
#   Validation Accuracy: 0.4981238273921201
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6728293895721436
#   Validation Accuracy: 0.6238273921200751
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 1)
#   Validation Loss: 1.0568677186965942
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6241121888160706
#   Validation Accuracy: 0.6735459662288931
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6553918123245239
#   Validation Accuracy: 0.6557223264540337
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 1)
#   Validation Loss: 1.2248667478561401
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.676849901676178
#   Validation Accuracy: 0.6463414634146342
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6681331396102905
#   Validation Accuracy: 0.6726078799249531
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 1)
#   Validation Loss: 1.1083531379699707
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 2)
#   Validation Loss: 1.0960890054702759
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6376484632492065
#   Validation Accuracy: 0.6735459662288931
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 1)
#   Validation Loss: 1.0443048477172852
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.6680030226707458
#   Validation Accuracy: 0.5947467166979362
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.654502272605896
#   Validation Accuracy: 0.6651031894934334
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.6942948698997498
#   Validation Accuracy: 0.5131332082551595
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6673011779785156
#   Validation Accuracy: 0.6341463414634146
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6737794876098633
#   Validation Accuracy: 0.6078799249530957
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.7083432078361511
#   Validation Accuracy: 0.4971857410881801
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6730031967163086
#   Validation Accuracy: 0.5975609756097561
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6795638799667358
#   Validation Accuracy: 0.6031894934333959
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6922421455383301
#   Validation Accuracy: 0.5065666041275797
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6903659105300903
#   Validation Accuracy: 0.5187617260787992
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6731653809547424
#   Validation Accuracy: 0.6125703564727955
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.6974532008171082
#   Validation Accuracy: 0.5103189493433395
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6967971920967102
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6720296740531921
#   Validation Accuracy: 0.6200750469043153
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 1)
#   Validation Loss: 1.1878695487976074
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.665380597114563
#   Validation Accuracy: 0.6632270168855535
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6590149998664856
#   Validation Accuracy: 0.6585365853658537
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.9710953831672668
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.6499170660972595
#   Validation Accuracy: 0.6519699812382739
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6725864410400391
#   Validation Accuracy: 0.6472795497185742
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 1)
#   Validation Loss: 1.0573686361312866
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 2)
#   Validation Loss: 1.0107159614562988
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6387338042259216
#   Validation Accuracy: 0.6622889305816135
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 1)
#   Validation Loss: 1.073981761932373
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 2)
#   Validation Loss: 1.009009599685669
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6517549157142639
#   Validation Accuracy: 0.6519699812382739
# Best result:
#   Validation Loss: 0.6679579019546509
#   Validation Accuracy: 0.6801125703564728
#   Best hyperparameters: (1, 128, 0.1, 0.001, 256, 2.0, 3)

# %%
## (1, 256, 0.2, 0.001, 128, 2.0, 3)--> higest accuracy
print({best_val_loss})
print({best_val_accuracy})
print(best_params)
# Out:
# {tensor(0.6680)}
# {0.6801125703564728}
# (1, 128, 0.1, 0.001, 256, 2.0, 3)

# %%
val_steps = 100
batch_size = 128
dropout_rate = 0.1
hidden_dim = 256
learning_rate = 0.001
num_rnn_layer = 1
max_grad_norm = 2.0
num_train_epochs = 3

# %%
num_training_steps = num_train_epochs * len(train_loader)
num_warmup_steps = int(num_training_steps * warmup_ratio)
print(f"train:{num_training_steps}, warm up: {num_warmup_steps}")
# Out:
# train:201, warm up: 20

# %%
cls_model = SentimentRNN(
    embedding=embedding,
    hidden_size=hidden_dim,
    embed_size=EMBED_DIM,
    bidirectional=False,  # False for part 2
    num_rnn_layer=num_rnn_layer,
    dropout_rate=dropout_rate,
    layer_norm=True
).to(device)
# Set up optimizer and scheduler
optimizer = torch.optim.Adam(cls_model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

train_loader = DataLoader(
    dataset=train_ds,
    batch_size=batch_size,
    collate_fn=collate_fn,
    shuffle=True
)

optimizer.zero_grad()

step = 0

train_losses = []

val_accs = []

val_losses = []

counter = 0

for epoch in range(num_train_epochs):
    
    # train loop
    for data in train_loader:
        cls_model.train()
        input_ids = data["input_ids"].to(device)
        attention_mask = data["attention_mask"].to(device)
        label = data["label"].view(-1, 1).float().to(device)
        
        logits = cls_model.forward(input_ids, attention_mask)
        
        
        loss = loss_fn.forward(
            input = logits,
            target = label
        )
        
        loss.backward()

        # Gradient clip (important for RNN, not necessary for LSTM/GRU/conv1d)
        torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)
        
        optimizer.step() # update paramater
        scheduler.step() 
        optimizer.zero_grad() # clear gradient
        
        vis_loss = loss.detach().cpu()
        
        print(f"[{step + 1}/{num_training_steps}] train loss: [{vis_loss:.4f}] (epoch [{epoch + 1}/{num_train_epochs}])")
        
        
        train_losses.append(vis_loss)
        i =0 

        if (step + 1) % val_steps == 0 or step == 0:
            # compute validation every "val_steps"
           
            cls_model.eval()
            val_loss = compute_loss(val_loader)
            val_acc = compute_accuracy(val_loader)
            val_accs.append(val_acc)
            val_losses.append(val_loss)
            
            print(f"[{step + 1}/{num_training_steps}] validation loss: [{val_loss:.4f}] validation accuracy: [{val_acc:.4f}]")
            # Apply early stopping
            should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.5, tolerance=2, counter=counter)
            if should_stop:
                print("Early stopping triggered.")
                break
        
        step += 1
        
    if should_stop:
        break  # Exit e
# Out:
# [1/201] train loss: [0.6933] (epoch [1/3])
# [1/201] validation loss: [0.8240] validation accuracy: [0.5000]
# [2/201] train loss: [0.7843] (epoch [1/3])
# [3/201] train loss: [0.7308] (epoch [1/3])
# [4/201] train loss: [0.6794] (epoch [1/3])
# [5/201] train loss: [0.6792] (epoch [1/3])
# [6/201] train loss: [0.6831] (epoch [1/3])
# [7/201] train loss: [0.6752] (epoch [1/3])
# [8/201] train loss: [0.6559] (epoch [1/3])
# [9/201] train loss: [0.6832] (epoch [1/3])
# [10/201] train loss: [0.6457] (epoch [1/3])
# [11/201] train loss: [0.6737] (epoch [1/3])
# [12/201] train loss: [0.6655] (epoch [1/3])
# [13/201] train loss: [0.6628] (epoch [1/3])
# [14/201] train loss: [0.6674] (epoch [1/3])
# [15/201] train loss: [0.6571] (epoch [1/3])
# [16/201] train loss: [0.6477] (epoch [1/3])
# [17/201] train loss: [0.6400] (epoch [1/3])
# [18/201] train loss: [0.6581] (epoch [1/3])
# [19/201] train loss: [0.6612] (epoch [1/3])
# [20/201] train loss: [0.6352] (epoch [1/3])
# [21/201] train loss: [0.6204] (epoch [1/3])
# [22/201] train loss: [0.6392] (epoch [1/3])
# [23/201] train loss: [0.6489] (epoch [1/3])
# [24/201] train loss: [0.6309] (epoch [1/3])
# [25/201] train loss: [0.6249] (epoch [1/3])
# [26/201] train loss: [0.6106] (epoch [1/3])
# [27/201] train loss: [0.6177] (epoch [1/3])
# [28/201] train loss: [0.6477] (epoch [1/3])
# [29/201] train loss: [0.6486] (epoch [1/3])
# [30/201] train loss: [0.6505] (epoch [1/3])
# [31/201] train loss: [0.6343] (epoch [1/3])
# [32/201] train loss: [0.6244] (epoch [1/3])
# [33/201] train loss: [0.6353] (epoch [1/3])
# [34/201] train loss: [0.6410] (epoch [1/3])
# [35/201] train loss: [0.5868] (epoch [1/3])
# [36/201] train loss: [0.6230] (epoch [1/3])
# [37/201] train loss: [0.6265] (epoch [1/3])
# [38/201] train loss: [0.6023] (epoch [1/3])
# [39/201] train loss: [0.6351] (epoch [1/3])
# [40/201] train loss: [0.6197] (epoch [1/3])
# [41/201] train loss: [0.6358] (epoch [1/3])
# [42/201] train loss: [0.6705] (epoch [1/3])
# [43/201] train loss: [0.6128] (epoch [1/3])
# [44/201] train loss: [0.6097] (epoch [1/3])
# [45/201] train loss: [0.6493] (epoch [1/3])
# [46/201] train loss: [0.6116] (epoch [1/3])
# [47/201] train loss: [0.6328] (epoch [1/3])
# [48/201] train loss: [0.6300] (epoch [1/3])
# [49/201] train loss: [0.5996] (epoch [1/3])
# [50/201] train loss: [0.6030] (epoch [1/3])
# [51/201] train loss: [0.6146] (epoch [1/3])
# [52/201] train loss: [0.6244] (epoch [1/3])
# [53/201] train loss: [0.6090] (epoch [1/3])
# [54/201] train loss: [0.6044] (epoch [1/3])
# [55/201] train loss: [0.6342] (epoch [1/3])
# [56/201] train loss: [0.6567] (epoch [1/3])
# [57/201] train loss: [0.6043] (epoch [1/3])
# [58/201] train loss: [0.5915] (epoch [1/3])
# [59/201] train loss: [0.6235] (epoch [1/3])
# [60/201] train loss: [0.6046] (epoch [1/3])
# [61/201] train loss: [0.5792] (epoch [1/3])
# [62/201] train loss: [0.6146] (epoch [1/3])
# [63/201] train loss: [0.6393] (epoch [1/3])
# [64/201] train loss: [0.6380] (epoch [1/3])
# [65/201] train loss: [0.6131] (epoch [1/3])
# [66/201] train loss: [0.6173] (epoch [1/3])
# [67/201] train loss: [0.6203] (epoch [1/3])
# [68/201] train loss: [0.6044] (epoch [2/3])
# [69/201] train loss: [0.6269] (epoch [2/3])
# [70/201] train loss: [0.6062] (epoch [2/3])
# [71/201] train loss: [0.6006] (epoch [2/3])
# [72/201] train loss: [0.6028] (epoch [2/3])
# [73/201] train loss: [0.5997] (epoch [2/3])
# [74/201] train loss: [0.6426] (epoch [2/3])
# [75/201] train loss: [0.6397] (epoch [2/3])
# [76/201] train loss: [0.5768] (epoch [2/3])
# [77/201] train loss: [0.5864] (epoch [2/3])
# [78/201] train loss: [0.6033] (epoch [2/3])
# [79/201] train loss: [0.6043] (epoch [2/3])
# [80/201] train loss: [0.6207] (epoch [2/3])
# [81/201] train loss: [0.6506] (epoch [2/3])
# [82/201] train loss: [0.6375] (epoch [2/3])
# [83/201] train loss: [0.6319] (epoch [2/3])
# [84/201] train loss: [0.5966] (epoch [2/3])
# [85/201] train loss: [0.5865] (epoch [2/3])
# [86/201] train loss: [0.6139] (epoch [2/3])
# [87/201] train loss: [0.6001] (epoch [2/3])
# [88/201] train loss: [0.6176] (epoch [2/3])
# [89/201] train loss: [0.6644] (epoch [2/3])
# [90/201] train loss: [0.6236] (epoch [2/3])
# [91/201] train loss: [0.5926] (epoch [2/3])
# [92/201] train loss: [0.6178] (epoch [2/3])
# [93/201] train loss: [0.6261] (epoch [2/3])
# [94/201] train loss: [0.6173] (epoch [2/3])
# [95/201] train loss: [0.6087] (epoch [2/3])
# [96/201] train loss: [0.6648] (epoch [2/3])
# [97/201] train loss: [0.6048] (epoch [2/3])
# [98/201] train loss: [0.6352] (epoch [2/3])
# [99/201] train loss: [0.6093] (epoch [2/3])
# [100/201] train loss: [0.5939] (epoch [2/3])
# [100/201] validation loss: [0.6207] validation accuracy: [0.6689]
# [101/201] train loss: [0.6264] (epoch [2/3])
# [102/201] train loss: [0.6070] (epoch [2/3])
# [103/201] train loss: [0.5987] (epoch [2/3])
# [104/201] train loss: [0.6079] (epoch [2/3])
# [105/201] train loss: [0.6250] (epoch [2/3])
# [106/201] train loss: [0.6204] (epoch [2/3])
# [107/201] train loss: [0.6224] (epoch [2/3])
# [108/201] train loss: [0.6064] (epoch [2/3])
# [109/201] train loss: [0.6409] (epoch [2/3])
# [110/201] train loss: [0.6474] (epoch [2/3])
# [111/201] train loss: [0.5962] (epoch [2/3])
# [112/201] train loss: [0.6266] (epoch [2/3])
# [113/201] train loss: [0.5989] (epoch [2/3])
# [114/201] train loss: [0.6007] (epoch [2/3])
# [115/201] train loss: [0.6025] (epoch [2/3])
# [116/201] train loss: [0.6189] (epoch [2/3])
# [117/201] train loss: [0.6140] (epoch [2/3])
# [118/201] train loss: [0.6511] (epoch [2/3])
# [119/201] train loss: [0.6237] (epoch [2/3])
# [120/201] train loss: [0.6516] (epoch [2/3])
# [121/201] train loss: [0.6023] (epoch [2/3])
# [122/201] train loss: [0.6100] (epoch [2/3])
# [123/201] train loss: [0.6062] (epoch [2/3])
# [124/201] train loss: [0.6437] (epoch [2/3])
# [125/201] train loss: [0.5920] (epoch [2/3])
# [126/201] train loss: [0.6183] (epoch [2/3])
# [127/201] train loss: [0.6040] (epoch [2/3])
# [128/201] train loss: [0.5943] (epoch [2/3])
# [129/201] train loss: [0.6040] (epoch [2/3])
# [130/201] train loss: [0.6307] (epoch [2/3])
# [131/201] train loss: [0.6082] (epoch [2/3])
# [132/201] train loss: [0.5903] (epoch [2/3])
# [133/201] train loss: [0.5949] (epoch [2/3])
# [134/201] train loss: [0.5958] (epoch [2/3])
# [135/201] train loss: [0.6071] (epoch [3/3])
# [136/201] train loss: [0.5964] (epoch [3/3])
# [137/201] train loss: [0.6269] (epoch [3/3])
# [138/201] train loss: [0.6274] (epoch [3/3])
# [139/201] train loss: [0.6262] (epoch [3/3])
# [140/201] train loss: [0.6251] (epoch [3/3])
# [141/201] train loss: [0.6417] (epoch [3/3])
# [142/201] train loss: [0.6397] (epoch [3/3])
# [143/201] train loss: [0.6050] (epoch [3/3])
# [144/201] train loss: [0.5963] (epoch [3/3])
# [145/201] train loss: [0.6345] (epoch [3/3])
# [146/201] train loss: [0.5956] (epoch [3/3])
# [147/201] train loss: [0.6141] (epoch [3/3])
# [148/201] train loss: [0.6603] (epoch [3/3])
# [149/201] train loss: [0.6219] (epoch [3/3])
# [150/201] train loss: [0.5958] (epoch [3/3])
# [151/201] train loss: [0.5923] (epoch [3/3])
# [152/201] train loss: [0.6106] (epoch [3/3])
# [153/201] train loss: [0.6337] (epoch [3/3])
# [154/201] train loss: [0.6332] (epoch [3/3])
# [155/201] train loss: [0.6327] (epoch [3/3])
# [156/201] train loss: [0.6428] (epoch [3/3])
# [157/201] train loss: [0.6058] (epoch [3/3])
# [158/201] train loss: [0.5992] (epoch [3/3])
# [159/201] train loss: [0.6131] (epoch [3/3])
# [160/201] train loss: [0.5707] (epoch [3/3])
# [161/201] train loss: [0.5838] (epoch [3/3])
# [162/201] train loss: [0.6154] (epoch [3/3])
# [163/201] train loss: [0.6259] (epoch [3/3])
# [164/201] train loss: [0.6377] (epoch [3/3])
# [165/201] train loss: [0.6130] (epoch [3/3])
# [166/201] train loss: [0.6426] (epoch [3/3])
# [167/201] train loss: [0.5996] (epoch [3/3])
# [168/201] train loss: [0.6143] (epoch [3/3])
# [169/201] train loss: [0.5901] (epoch [3/3])
# [170/201] train loss: [0.6195] (epoch [3/3])
# [171/201] train loss: [0.6246] (epoch [3/3])
# [172/201] train loss: [0.6280] (epoch [3/3])
# [173/201] train loss: [0.6325] (epoch [3/3])
# [174/201] train loss: [0.6068] (epoch [3/3])
# [175/201] train loss: [0.5999] (epoch [3/3])
# [176/201] train loss: [0.6024] (epoch [3/3])
# [177/201] train loss: [0.6217] (epoch [3/3])
# [178/201] train loss: [0.5909] (epoch [3/3])
# [179/201] train loss: [0.5981] (epoch [3/3])
# [180/201] train loss: [0.6110] (epoch [3/3])
# [181/201] train loss: [0.6182] (epoch [3/3])
# [182/201] train loss: [0.6508] (epoch [3/3])
# [183/201] train loss: [0.6182] (epoch [3/3])
# [184/201] train loss: [0.6097] (epoch [3/3])
# [185/201] train loss: [0.5648] (epoch [3/3])
# [186/201] train loss: [0.5937] (epoch [3/3])
# [187/201] train loss: [0.6420] (epoch [3/3])
# [188/201] train loss: [0.5768] (epoch [3/3])
# [189/201] train loss: [0.5938] (epoch [3/3])
# [190/201] train loss: [0.6119] (epoch [3/3])
# [191/201] train loss: [0.6435] (epoch [3/3])
# [192/201] train loss: [0.6296] (epoch [3/3])
# [193/201] train loss: [0.6130] (epoch [3/3])
# [194/201] train loss: [0.6060] (epoch [3/3])
# [195/201] train loss: [0.5835] (epoch [3/3])
# [196/201] train loss: [0.6478] (epoch [3/3])
# [197/201] train loss: [0.6231] (epoch [3/3])
# [198/201] train loss: [0.6413] (epoch [3/3])
# [199/201] train loss: [0.6302] (epoch [3/3])
# [200/201] train loss: [0.5843] (epoch [3/3])
# [200/201] validation loss: [0.6207] validation accuracy: [0.6689]
# [201/201] train loss: [0.5671] (epoch [3/3])

# %%
train_loss = compute_loss(train_loader)
train_acc = compute_accuracy(train_loader)
test_loss = compute_loss(test_loader)
test_acc = compute_accuracy(test_loader)
val_loss = compute_loss(val_loader)
test_acc = compute_accuracy(test_loader)

print(f"Train Loss: [{train_loss:.4f}]\nTrain accuracy: [{train_acc:.4f}]")
print(f"Test Loss: [{test_loss:.4f}]\nTest accuracy: [{test_acc:.4f}]")
print(f"Validation Loss: [{val_loss:.4f}]\nValidation accuracy: [{val_acc:.4f}]")
# Out:
# Train Loss: [1.2042]
# Train accuracy: [0.6758]
# Test Loss: [0.6122]
# Test accuracy: [0.6576]
# Validation Loss: [0.6207]
# Validation accuracy: [0.6689]

# %%
# Set validation steps to match the indices in val_losses
val_steps = [i * 100 for i in range(len(val_losses))]

# Subplots for training and vlidation loss & validation accuracy (updated for each epoch)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot Training and Validation Loss subplot
ax1.plot(train_losses, label='Training Loss', marker='x')
ax1.plot(val_steps, val_losses, label='Validation Loss', marker='o')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Training Steps')
ax1.set_ylabel('Loss')
ax1.grid(True)
ax1.legend()

# Plot Validation Accuracy subplot
ax2.plot(val_steps, val_accs, label='Validation Accuracy', marker='x')
ax2.set_title('Validation Accuracy')
ax2.set_xlabel('Training Steps')
ax2.set_ylabel('Accuracy')
ax2.grid(True)
ax2.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# compute predictions and labels for confusion matrix computing
def compute_pedictions_and_labels(
        model : nn.Module, 
        test_loader : DataLoader, 
        device : torch.device
    ) -> tuple:
    
    model.to(device)
    
    model.eval()
    
    # Lists to store all predictions and actual labels
    all_predictions = []
    all_labels = []
    
    with torch.no_grad():
        for data in test_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)
            
            logits = model(input_ids, attention_mask=attention_mask)
     
            predictions = (logits > 0).long()
            
            all_predictions.extend(predictions.view(-1).cpu().numpy())
            all_labels.extend(labels.view(-1).cpu().numpy())
    
    return all_predictions, all_labels

all_predictions, all_labels = compute_pedictions_and_labels(cls_model, test_loader, device)

# %%
def plot_f1_score(
        all_predictions : list,
        all_labels : list
    ) -> None:
    f1 = f1_score(all_labels, all_predictions)
    print("F1 Score: ", f1)

plot_f1_score(all_predictions, all_labels)
# Out:
# F1 Score:  0.6473429951690821

# %%
def accuracyscore(
      all_predictions: list,
      all_labels: list
    ) -> float:
    correct_predicts = sum([1 for pred, label in zip(all_predictions, all_labels) if pred == label])
    accuracy = correct_predicts / len(all_labels)
    return accuracy

print("Accuracy Score: ",accuracyscore(all_predictions, all_labels))
# Out:
# Accuracy Score:  0.6575984990619137

# %%
# visualization 2: confusion matrix

def plot_confusion(
        all_predictions : list, 
        all_labels : list
    ) -> None:      
            
    cm = confusion_matrix(all_labels, all_predictions) # from sklearn
            
    plt.figure(figsize=(6,4))
    sns.heatmap(cm, annot=True, fmt='d', linewidths=0.2, cmap="YlGnBu", cbar=False)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.xticks([0.5, 1.5], ['Negative', 'Positive'])
    plt.yticks([0.5, 1.5], ['Negative', 'Positive'], va='center')
    plt.show()
    
plot_confusion(all_predictions, all_labels)
