# %%
GLOVE_PATH = "glove.6B.100d.txt" # change to your path
EMBED_DIM = 100 # No need to change

# %%
from transformers import get_cosine_schedule_with_warmup
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.utils.data import DataLoader, Dataset
import matplotlib as mpl
import matplotlib.pyplot as plt
from tensorflow import keras
import pandas as pd
import numpy as np
import random
from sklearn.metrics import confusion_matrix, f1_score, f1_score, roc_curve, auc, precision_recall_curve, average_precision_score
import seaborn as sns
from Embeddings import GloveEmbedding, GloveTokenizer
import itertools
import torch
from torch.utils.data import DataLoader
from typing import Any
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import copy

# %%
# set seeds
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(114514)

# %%
# import tokenizer
tokenizer = GloveTokenizer(glove_file_path=GLOVE_PATH)
embedding = GloveEmbedding(
    glove_file_path = GLOVE_PATH,
    trainable = True # True for part 3 to disable the Embedding training
)

# %%
class SentimentRNN(nn.Module):
    def __init__(self, embedding, hidden_size, embed_size, bidirectional, num_rnn_layer, dropout_rate, layer_norm):
        super(SentimentRNN, self).__init__()
        self.embedding = embedding  # pass pretrained embedding in
        self.bidirectional = bidirectional
        self.rnn = nn.RNN(embed_size, hidden_size, batch_first=True, num_layers = num_rnn_layer, bidirectional=bidirectional, dropout = dropout_rate if num_rnn_layer > 1 else 0)

        # if bidirectional, the output hidden size is double
        self.hidden_size = hidden_size * 2 if bidirectional else hidden_size

        # MLP
        if not layer_norm:
            self.output_layer = nn.Sequential(
                nn.Dropout(dropout_rate),
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.GELU(),
                nn.Linear(self.hidden_size, 1),  # output dimension is 1 (sigmoid is in BCELossWithLogits, so no sigmoid here. This will get better result)
            )
        else:
            self.output_layer = nn.Sequential(
                nn.LayerNorm(self.hidden_size),
                nn.Dropout(dropout_rate),
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.LayerNorm(self.hidden_size),
                nn.GELU(),
                nn.Linear(self.hidden_size, 1),
            )

    def forward(self, input_ids, attention_mask):
        '''
        This method is designed for biLSTM/GRU/RNN. For LSTM/GRU/RNN for only one direction, just take hidden as the rnn output.
        RNN - hidden -> MLP --> outcome
        '''
        # embed the input
        embedded = self.embedding(input_ids)  # [batch_size, seq_length, embedding_dim]

        # feed forward
        output, hidden = self.rnn(embedded) # we don't need encoder so we only keep the output

        # make attention mask from [batch_size, seq_length] to [batch_size, seq_length, 1] as the same dimension as rnn
        attention_mask = attention_mask.unsqueeze(-1)  # [batch_size, seq_length, 1]

        # use attention mask to mask the output, ignore the padding embedding vector, only add the valid embedding vector
        masked_output = output * attention_mask

        # sum up all the valid output
        summed_output = masked_output.sum(dim=1)  # [batch_size, hidden_size]

        logits = self.output_layer(summed_output)

        return logits  # The output is [batch_size, 1]

# %%
# import datasets

train_df = pd.read_csv("./preprocessed_dataset/train.csv").iloc[:,1:]
validation_df = pd.read_csv("./preprocessed_dataset/validation.csv").iloc[:,1:]
test_df = pd.read_csv("./preprocessed_dataset/test.csv").iloc[:,1:]

# %%
# try to use tokenizer api
tokenizer.encode(["hello world", "how are you"], return_tensors = "pt") # insist to return pytorch
# Out:
# {'input_ids': tensor([[13077,    87,     0],
#          [  199,    34,    83]]),
#  'attention_mask': tensor([[1, 1, 0],
#          [1, 1, 1]])}

# %%
# Hyper paramaters
dropout_rate = 0.1
num_rnn_layer = 1
hidden_dim = 256

val_steps = 100 # compute validation error every n step

num_train_epochs = 3

batch_size = 32
lr = 8e-5
weight_decay = 1e-5


warmup_ratio=0.1
max_grad_norm = 2.0

# %%
# define dataset and data loader
class CustomizeDataset(Dataset):
    def __init__(
            self,
            df : pd.DataFrame
        ) -> None:
        super().__init__()
        self.df = df

    def __len__(self) -> int:
        return len(self.df)

    def __getitem__(
            self,
            index : int
        ) -> dict:

        inputs = self.df.iloc[index,0] # 0 is text
        label = self.df.iloc[index, 1] # 1 is label

        return {
            "input_str" : inputs, # output a string
            "label" : label # output a label
        }

# collater function (used for dynamic padding to save memory)
class Collater:
    def __init__(
            self,
            tokenizer : GloveTokenizer
        ) -> None:
        self.tokenizer = tokenizer

    def __call__(
            self,
            instances : list # a list of string
        ) -> Any:
        # __call__ is for function-like object
        input_str_list = [instance["input_str"] for instance in instances]
        input_dict = tokenizer.encode(input_str_list, return_tensors = "pt") # return pytorch tensor
        input_ids = input_dict["input_ids"]
        attention_mask = input_dict["attention_mask"]
        label = [torch.tensor(instance["label"], dtype = torch.int64) for instance in instances]

        return {
            "input_ids": input_ids,
            "label": torch.tensor(label),
            "attention_mask": attention_mask # mask the pad position
        }

# %%
# create dataset and data loader
collate_fn = Collater(tokenizer)



train_ds = CustomizeDataset(
    df = train_df
)

train_loader = DataLoader(
    dataset = train_ds,
    batch_size = batch_size,
    collate_fn = collate_fn,
    shuffle = True
)

val_ds = CustomizeDataset(
    df = validation_df
)

val_loader = DataLoader(
    dataset = val_ds,
    batch_size = batch_size,
    collate_fn = collate_fn
)

test_ds = CustomizeDataset(
    df = test_df
)

test_loader = DataLoader(
    dataset = test_ds,
    batch_size = batch_size,
    collate_fn = collate_fn
)

# %%
# compute warmup status
num_training_steps = num_train_epochs * len(train_loader)
num_warmup_steps = int(num_training_steps * warmup_ratio)
print(f"train:{num_training_steps}, warm up: {num_warmup_steps}")
# Out:
# train:801, warm up: 80

# %%
# Set optimizer, loss_fn and so on

cls_model = SentimentRNN(
    embedding = embedding,
    hidden_size = hidden_dim,
    embed_size = EMBED_DIM,
    bidirectional = False, #  False for part 2
    num_rnn_layer = num_rnn_layer,
    dropout_rate = dropout_rate,
    layer_norm = True # set if you need layer norm
)

loss_fn = nn.BCEWithLogitsLoss()

optimizer = AdamW(
    params = cls_model.parameters(),
    lr = lr,
    weight_decay = weight_decay
)

scheduler  = get_cosine_schedule_with_warmup(
    optimizer = optimizer,
    num_warmup_steps = num_warmup_steps,
    num_training_steps = num_training_steps
)

# %%
# compute accuracy for wach data loader

def compute_accuracy(data_loader: DataLoader) -> float:

    cls_model.eval()

    correct = 0
    total = 0

    with torch.no_grad():
        for data in data_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)

            logits = cls_model(input_ids, attention_mask=attention_mask)

            predictions = (logits > 0).long()

            correct += (predictions == labels).sum().item()
            total += labels.size(0)

    accuracy = correct / total
    return accuracy

def compute_loss(data_loader: DataLoader) -> float:
    total_loss = 0
    cls_model.eval()
    with torch.no_grad():
        for data in data_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)

            logits = cls_model.forward(input_ids, attention_mask)
            loss = loss_fn.forward(
                input = logits,
                target = labels
            )

            total_loss += loss.detach().cpu()

        total_loss /= len(val_loader)

        return total_loss

# %%
def early_stopping(train_loss, validation_loss, min_delta, tolerance, counter):
    positive_diff = abs(validation_loss - train_loss)

    # Increment counter if no significant improvement
    if positive_diff >= min_delta:
        counter += 1
        if counter >= tolerance:
            return True, counter
    # Ensure the function always returns both values
    return False, counter

# %%
# Training loop

cls_model.to(device)

optimizer.zero_grad()

step = 0

train_losses = []

val_accs = []

val_losses = []

counter = 0

for epoch in range(num_train_epochs):

    # train loop
    for data in train_loader:
        cls_model.train()
        input_ids = data["input_ids"].to(device)
        attention_mask = data["attention_mask"].to(device)
        label = data["label"].view(-1, 1).float().to(device)

        logits = cls_model.forward(input_ids, attention_mask)


        loss = loss_fn.forward(
            input = logits,
            target = label
        )

        loss.backward()

        # Gradient clip (important for RNN, not necessary for LSTM/GRU/conv1d)
        torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)

        optimizer.step() # update paramater
        scheduler.step()
        optimizer.zero_grad() # clear gradient

        vis_loss = loss.detach().cpu()

        print(f"[{step + 1}/{num_training_steps}] train loss: [{vis_loss:.4f}] (epoch [{epoch + 1}/{num_train_epochs}])")


        train_losses.append(vis_loss)
        i =0

        if (step + 1) % val_steps == 0 or step == 0:
            # compute validation every "val_steps"

            cls_model.eval()
            val_loss = compute_loss(val_loader)
            val_acc = compute_accuracy(val_loader)
            val_accs.append(val_acc)
            val_losses.append(val_loss)

            print(f"[{step + 1}/{num_training_steps}] validation loss: [{val_loss:.4f}] validation accuracy: [{val_acc:.4f}]")
            # Apply early stopping
            should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.01, tolerance=2, counter=counter)
            if should_stop:
                print("Early stopping triggered.")
                break

        step += 1

    if should_stop:
        break  # Exit e
# Out:
# [1/801] train loss: [0.7175] (epoch [1/3])
# [1/801] validation loss: [0.7006] validation accuracy: [0.4972]
# [2/801] train loss: [0.7221] (epoch [1/3])
# [3/801] train loss: [0.7316] (epoch [1/3])
# [4/801] train loss: [0.7200] (epoch [1/3])
# [5/801] train loss: [0.7241] (epoch [1/3])
# [6/801] train loss: [0.7328] (epoch [1/3])
# [7/801] train loss: [0.6664] (epoch [1/3])
# [8/801] train loss: [0.7222] (epoch [1/3])
# [9/801] train loss: [0.6904] (epoch [1/3])
# [10/801] train loss: [0.7298] (epoch [1/3])
# [11/801] train loss: [0.6965] (epoch [1/3])
# [12/801] train loss: [0.6867] (epoch [1/3])
# [13/801] train loss: [0.7076] (epoch [1/3])
# [14/801] train loss: [0.6897] (epoch [1/3])
# [15/801] train loss: [0.6911] (epoch [1/3])
# [16/801] train loss: [0.6906] (epoch [1/3])
# [17/801] train loss: [0.7053] (epoch [1/3])
# [18/801] train loss: [0.7031] (epoch [1/3])
# [19/801] train loss: [0.7096] (epoch [1/3])
# [20/801] train loss: [0.6938] (epoch [1/3])
# [21/801] train loss: [0.6971] (epoch [1/3])
# [22/801] train loss: [0.6957] (epoch [1/3])
# [23/801] train loss: [0.7011] (epoch [1/3])
# [24/801] train loss: [0.6897] (epoch [1/3])
# [25/801] train loss: [0.6759] (epoch [1/3])
# [26/801] train loss: [0.6722] (epoch [1/3])
# [27/801] train loss: [0.6942] (epoch [1/3])
# [28/801] train loss: [0.7264] (epoch [1/3])
# [29/801] train loss: [0.6893] (epoch [1/3])
# [30/801] train loss: [0.7175] (epoch [1/3])
# [31/801] train loss: [0.6820] (epoch [1/3])
# [32/801] train loss: [0.7006] (epoch [1/3])
# [33/801] train loss: [0.6822] (epoch [1/3])
# [34/801] train loss: [0.7303] (epoch [1/3])
# [35/801] train loss: [0.6881] (epoch [1/3])
# [36/801] train loss: [0.6925] (epoch [1/3])
# [37/801] train loss: [0.6928] (epoch [1/3])
# [38/801] train loss: [0.6940] (epoch [1/3])
# [39/801] train loss: [0.7001] (epoch [1/3])
# [40/801] train loss: [0.6717] (epoch [1/3])
# [41/801] train loss: [0.7117] (epoch [1/3])
# [42/801] train loss: [0.6971] (epoch [1/3])
# [43/801] train loss: [0.7070] (epoch [1/3])
# [44/801] train loss: [0.6712] (epoch [1/3])
# [45/801] train loss: [0.6567] (epoch [1/3])
# [46/801] train loss: [0.6668] (epoch [1/3])
# [47/801] train loss: [0.6777] (epoch [1/3])
# [48/801] train loss: [0.7079] (epoch [1/3])
# [49/801] train loss: [0.6707] (epoch [1/3])
# [50/801] train loss: [0.6754] (epoch [1/3])
# [51/801] train loss: [0.6699] (epoch [1/3])
# [52/801] train loss: [0.6753] (epoch [1/3])
# [53/801] train loss: [0.6642] (epoch [1/3])
# [54/801] train loss: [0.6916] (epoch [1/3])
# [55/801] train loss: [0.6515] (epoch [1/3])
# [56/801] train loss: [0.6629] (epoch [1/3])
# [57/801] train loss: [0.6737] (epoch [1/3])
# [58/801] train loss: [0.6474] (epoch [1/3])
# [59/801] train loss: [0.6628] (epoch [1/3])
# [60/801] train loss: [0.7094] (epoch [1/3])
# [61/801] train loss: [0.6927] (epoch [1/3])
# [62/801] train loss: [0.6502] (epoch [1/3])
# [63/801] train loss: [0.6389] (epoch [1/3])
# [64/801] train loss: [0.7168] (epoch [1/3])
# [65/801] train loss: [0.6886] (epoch [1/3])
# [66/801] train loss: [0.6719] (epoch [1/3])
# [67/801] train loss: [0.7121] (epoch [1/3])
# [68/801] train loss: [0.6709] (epoch [1/3])
# [69/801] train loss: [0.6910] (epoch [1/3])
# [70/801] train loss: [0.6836] (epoch [1/3])
# [71/801] train loss: [0.6648] (epoch [1/3])
# [72/801] train loss: [0.6324] (epoch [1/3])
# [73/801] train loss: [0.6190] (epoch [1/3])
# [74/801] train loss: [0.6482] (epoch [1/3])
# [75/801] train loss: [0.6447] (epoch [1/3])
# [76/801] train loss: [0.6867] (epoch [1/3])
# [77/801] train loss: [0.6826] (epoch [1/3])
# [78/801] train loss: [0.6271] (epoch [1/3])
# [79/801] train loss: [0.5801] (epoch [1/3])
# [80/801] train loss: [0.6429] (epoch [1/3])
# [81/801] train loss: [0.7172] (epoch [1/3])
# [82/801] train loss: [0.7020] (epoch [1/3])
# [83/801] train loss: [0.7874] (epoch [1/3])
# [84/801] train loss: [0.6366] (epoch [1/3])
# [85/801] train loss: [0.6225] (epoch [1/3])
# [86/801] train loss: [0.6140] (epoch [1/3])
# [87/801] train loss: [0.6484] (epoch [1/3])
# [88/801] train loss: [0.6894] (epoch [1/3])
# [89/801] train loss: [0.6388] (epoch [1/3])
# [90/801] train loss: [0.6572] (epoch [1/3])
# [91/801] train loss: [0.7118] (epoch [1/3])
# [92/801] train loss: [0.6112] (epoch [1/3])
# [93/801] train loss: [0.5877] (epoch [1/3])
# [94/801] train loss: [0.6557] (epoch [1/3])
# [95/801] train loss: [0.6572] (epoch [1/3])
# [96/801] train loss: [0.5981] (epoch [1/3])
# [97/801] train loss: [0.7147] (epoch [1/3])
# [98/801] train loss: [0.6546] (epoch [1/3])
# [99/801] train loss: [0.6403] (epoch [1/3])
# [100/801] train loss: [0.6742] (epoch [1/3])
# [100/801] validation loss: [0.6315] validation accuracy: [0.6632]
# Early stopping triggered.

# %%
# Test the model
# Define hyperparameter ranges
param_grid = {
    "num_rnn_layer": range(1, 2),  # Integer range for number of RNN layers
    "hidden_dim": [128, 256],  # Integer range for hidden dimension size
    "dropout_rate": [0.1, 0.2],  # Continuous range for dropout rate
    "learning_rate": [1e-4, 1e-3],  # Continuous range for learning rate
    "batch_size": [128, 256],  # Integer range for batch size
    "max_grad_norm": [1.0, 2.0],  # Continuous range for gradient clipping
    "num_train_epochs": [1,2,3]  # Integer range for number of training epochs
}

# Track the best configuration
best_val_loss = float('inf')
best_val_accuracy = 0.0
best_params = None

# Generate all combinations of hyperparameters
for params in itertools.product(
    param_grid["num_rnn_layer"],
    param_grid["hidden_dim"],
    param_grid["dropout_rate"],
    param_grid["learning_rate"],
    param_grid["batch_size"],
    param_grid["max_grad_norm"],
    param_grid["num_train_epochs"]
):
    # Unpack hyperparameters
    num_rnn_layer, hidden_dim, dropout_rate, learning_rate, batch_size, max_grad_norm, num_train_epochs = params

    # Initialize model with current parameters
    cls_model = SentimentRNN(
        embedding=embedding,
        hidden_size=hidden_dim,
        embed_size=EMBED_DIM,
        bidirectional=False,
        num_rnn_layer=num_rnn_layer,
        dropout_rate=dropout_rate,
        layer_norm=True
    ).to(device)

    # Set up optimizer and scheduler
    optimizer = torch.optim.Adam(cls_model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

    # DataLoader for selected batch size
    train_loader = DataLoader(
        dataset=train_ds,
        batch_size=batch_size,
        collate_fn=collate_fn,
        shuffle=True
    )

    # Early stopping and metrics tracking variables
    counter = 0
    step = 0
    train_losses = []
    val_losses = []
    val_accs = []
    should_stop = False
    early_stopped = False  # Flag to indicate early stopping for this trial

    for epoch in range(num_train_epochs):
        # Training loop
        for data in train_loader:
            cls_model.train()
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            label = data["label"].view(-1, 1).float().to(device)

            logits = cls_model(input_ids, attention_mask)

            loss = loss_fn(input=logits, target=label)
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)

            optimizer.step()
            scheduler.step()
            optimizer.zero_grad()

            vis_loss = loss.detach().cpu().item()
            train_losses.append(vis_loss)

            # Validation step every `val_steps`
            if (step + 1) % val_steps == 0 or step == 0:
                cls_model.eval()
                val_loss = compute_loss(val_loader)
                val_acc = compute_accuracy(val_loader)
                val_losses.append(val_loss)
                val_accs.append(val_acc)

                # Early stopping check
                should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.5, tolerance=2, counter=counter)
                if should_stop:
                    print("Early stopping triggered.")
                    early_stopped = True  # Mark this trial as early stopped
                    break

            step += 1

        if should_stop:
            break  # Exit epoch loop if early stopping is triggered

    # Track the best parameters and validation loss
    current_val_loss = val_losses[-1] if val_losses else float('inf')
    current_val_accuracy = val_accs[-1] if val_accs else 0.0
    if current_val_accuracy > best_val_accuracy and early_stopped==False:
        best_val_loss = current_val_loss
        best_val_accuracy = current_val_accuracy
        best_params = params

    # Print the trial's results, including early stopping info
    print(f"Trial with params: {params}")
    print(f"  Validation Loss: {current_val_loss}")
    print(f"  Validation Accuracy: {current_val_accuracy}")
    if early_stopped:
        print("  Early stopped")


# Print the best result
print("Best result:")
print(f"  Validation Loss: {best_val_loss}")
print(f"  Validation Accuracy: {best_val_accuracy}")
print("  Best hyperparameters:", best_params)
# Out:
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.693998396396637
#   Validation Accuracy: 0.5028142589118199
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6899796724319458
#   Validation Accuracy: 0.5300187617260788
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6812169551849365
#   Validation Accuracy: 0.5778611632270169
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.7116232514381409
#   Validation Accuracy: 0.4718574108818011
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6879140734672546
#   Validation Accuracy: 0.5347091932457786
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6704587340354919
#   Validation Accuracy: 0.6294559099437148
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.735625684261322
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6954152584075928
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6935829520225525
#   Validation Accuracy: 0.5075046904315197
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.684800922870636
#   Validation Accuracy: 0.5666041275797373
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6994974613189697
#   Validation Accuracy: 0.474671669793621
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6916726231575012
#   Validation Accuracy: 0.5272045028142589
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.7833143472671509
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6179840564727783
#   Validation Accuracy: 0.6744840525328331
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6391460299491882
#   Validation Accuracy: 0.651031894934334
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.7199892401695251
#   Validation Accuracy: 0.5028142589118199
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.5952165722846985
#   Validation Accuracy: 0.6791744840525328
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6281300783157349
#   Validation Accuracy: 0.6876172607879925
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.7269198298454285
#   Validation Accuracy: 0.4971857410881801
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.7005947232246399
#   Validation Accuracy: 0.5046904315196998
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6234676241874695
#   Validation Accuracy: 0.6904315196998124
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.6952002644538879
#   Validation Accuracy: 0.5168855534709194
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.6823607683181763
#   Validation Accuracy: 0.5356472795497186
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6109088063240051
#   Validation Accuracy: 0.6829268292682927
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.6956670880317688
#   Validation Accuracy: 0.49624765478424016
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6809895038604736
#   Validation Accuracy: 0.5797373358348968
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6838363409042358
#   Validation Accuracy: 0.575984990619137
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.7067373991012573
#   Validation Accuracy: 0.48874296435272047
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.684349536895752
#   Validation Accuracy: 0.5684803001876173
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6858213543891907
#   Validation Accuracy: 0.5637898686679175
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6931864023208618
#   Validation Accuracy: 0.5121951219512195
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.7148516774177551
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6836485862731934
#   Validation Accuracy: 0.5722326454033771
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.6980099678039551
#   Validation Accuracy: 0.4896810506566604
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6931243538856506
#   Validation Accuracy: 0.5215759849906192
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.677619457244873
#   Validation Accuracy: 0.6078799249530957
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.768958568572998
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.5952273607254028
#   Validation Accuracy: 0.6772983114446529
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6244165301322937
#   Validation Accuracy: 0.6688555347091932
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.705538272857666
#   Validation Accuracy: 0.5046904315196998
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.6156773567199707
#   Validation Accuracy: 0.6763602251407129
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6190696954727173
#   Validation Accuracy: 0.6810506566604128
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.7267333269119263
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.7443383932113647
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.5954893231391907
#   Validation Accuracy: 0.6829268292682927
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.7748346328735352
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.7078990936279297
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.5879101157188416
#   Validation Accuracy: 0.6838649155722326
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.6931722164154053
#   Validation Accuracy: 0.5131332082551595
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6513275504112244
#   Validation Accuracy: 0.6697936210131332
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6484664678573608
#   Validation Accuracy: 0.650093808630394
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.6825272440910339
#   Validation Accuracy: 0.5093808630393997
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6532822847366333
#   Validation Accuracy: 0.6435272045028143
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6563244462013245
#   Validation Accuracy: 0.651031894934334
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.7000117301940918
#   Validation Accuracy: 0.5065666041275797
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6793552041053772
#   Validation Accuracy: 0.5816135084427767
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6443020701408386
#   Validation Accuracy: 0.6660412757973734
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.6740389466285706
#   Validation Accuracy: 0.5656660412757973
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.7397388219833374
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6403696537017822
#   Validation Accuracy: 0.6772983114446529
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 1)
#   Validation Loss: 1.0858193635940552
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.5974306464195251
#   Validation Accuracy: 0.698874296435272
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6145336031913757
#   Validation Accuracy: 0.6791744840525328
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 1)
#   Validation Loss: 1.3070532083511353
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.5645334720611572
#   Validation Accuracy: 0.7045028142589118
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.563779354095459
#   Validation Accuracy: 0.7101313320825516
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.8445980548858643
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.8100911974906921
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.5343842506408691
#   Validation Accuracy: 0.7204502814258912
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.8044994473457336
#   Validation Accuracy: 0.5056285178236398
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.8701961636543274
#   Validation Accuracy: 0.5046904315196998
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.5448417067527771
#   Validation Accuracy: 0.7185741088180112
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.6985068321228027
#   Validation Accuracy: 0.4803001876172608
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6578473448753357
#   Validation Accuracy: 0.6679174484052532
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6423373222351074
#   Validation Accuracy: 0.6848030018761726
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.6853224635124207
#   Validation Accuracy: 0.573170731707317
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6566462516784668
#   Validation Accuracy: 0.6538461538461539
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6408692598342896
#   Validation Accuracy: 0.6810506566604128
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6926053762435913
#   Validation Accuracy: 0.5150093808630394
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.7115148305892944
#   Validation Accuracy: 0.49624765478424016
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6328173875808716
#   Validation Accuracy: 0.6894934333958724
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.6854087710380554
#   Validation Accuracy: 0.5056285178236398
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6813473701477051
#   Validation Accuracy: 0.5778611632270169
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6460840106010437
#   Validation Accuracy: 0.6782363977485929
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 1)
#   Validation Loss: 1.0439306497573853
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.5402708053588867
#   Validation Accuracy: 0.724202626641651
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.5512778759002686
#   Validation Accuracy: 0.723264540337711
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 1)
#   Validation Loss: 1.0946474075317383
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.5705842971801758
#   Validation Accuracy: 0.702626641651032
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.5382537841796875
#   Validation Accuracy: 0.7401500938086304
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.9423487186431885
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 2)
#   Validation Loss: 1.0474143028259277
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.5333115458488464
#   Validation Accuracy: 0.7288930581613509
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 1)
#   Validation Loss: 1.1246708631515503
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.7851980328559875
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.5633853077888489
#   Validation Accuracy: 0.7035647279549718
# Best result:
#   Validation Loss: 0.5382537841796875
#   Validation Accuracy: 0.7401500938086304
#   Best hyperparameters: (1, 256, 0.2, 0.001, 128, 2.0, 3)

# %%
#result of the best parameters ("num_rnn_layer", "hidden_dim", "dropout_rate", "learning_rate", "batch_size", "max_grad_norm", "num_train_epochs")
print("Best Validation Loss: ", {best_val_loss})
print("Best Validation Accurcy: ",{best_val_accuracy})
print("Best Parameters: ", best_params)
# Out:
# Best Validation Loss:  {tensor(0.5383)}
# Best Validation Accurcy:  {0.7401500938086304}
# Best Parameters:  (1, 256, 0.2, 0.001, 128, 2.0, 3)

# %%
val_steps = 100
batch_size = 128
dropout_rate = 0.2
hidden_dim = 256
learning_rate = 0.001
num_rnn_layer = 1
max_grad_norm = 2.0
num_train_epochs = 3

# %%
num_training_steps = num_train_epochs * len(train_loader)
num_warmup_steps = int(num_training_steps * warmup_ratio)
print(f"train:{num_training_steps}, warm up: {num_warmup_steps}")
# Out:
# train:201, warm up: 20

# %%
cls_model = SentimentRNN(
    embedding=embedding,
    hidden_size=hidden_dim,
    embed_size=EMBED_DIM,
    bidirectional=False,  # False for part 2
    num_rnn_layer=num_rnn_layer,
    dropout_rate=dropout_rate,
    layer_norm=True
).to(device)
# Set up optimizer and scheduler
optimizer = torch.optim.Adam(cls_model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

train_loader = DataLoader(
    dataset=train_ds,
    batch_size=batch_size,
    collate_fn=collate_fn,
    shuffle=True
)

optimizer.zero_grad()

step = 0

train_losses = []

val_accs = []

val_losses = []

counter = 0

for epoch in range(num_train_epochs):

    # train loop
    for data in train_loader:
        cls_model.train()
        input_ids = data["input_ids"].to(device)
        attention_mask = data["attention_mask"].to(device)
        label = data["label"].view(-1, 1).float().to(device)

        logits = cls_model.forward(input_ids, attention_mask)


        loss = loss_fn.forward(
            input = logits,
            target = label
        )

        loss.backward()

        # Gradient clip (important for RNN, not necessary for LSTM/GRU/conv1d)
        torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)

        optimizer.step() # update paramater
        scheduler.step()
        optimizer.zero_grad() # clear gradient

        vis_loss = loss.detach().cpu()

        print(f"[{step + 1}/{num_training_steps}] train loss: [{vis_loss:.4f}] (epoch [{epoch + 1}/{num_train_epochs}])")


        train_losses.append(vis_loss)
        i =0

        if (step + 1) % val_steps == 0 or step == 0:
            # compute validation every "val_steps"

            cls_model.eval()
            val_loss = compute_loss(val_loader)
            val_acc = compute_accuracy(val_loader)
            val_accs.append(val_acc)
            val_losses.append(val_loss)

            print(f"[{step + 1}/{num_training_steps}] validation loss: [{val_loss:.4f}] validation accuracy: [{val_acc:.4f}]")
            # Apply early stopping
            should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.5, tolerance=2, counter=counter)
            if should_stop:
                print("Early stopping triggered.")
                break

        step += 1

    if should_stop:
        break  # Exit e
# Out:
# [1/201] train loss: [0.7194] (epoch [1/3])
# [1/201] validation loss: [0.9759] validation accuracy: [0.5000]
# [2/201] train loss: [1.1111] (epoch [1/3])
# [3/201] train loss: [0.7019] (epoch [1/3])
# [4/201] train loss: [0.6780] (epoch [1/3])
# [5/201] train loss: [0.7609] (epoch [1/3])
# [6/201] train loss: [0.7409] (epoch [1/3])
# [7/201] train loss: [0.6868] (epoch [1/3])
# [8/201] train loss: [0.6720] (epoch [1/3])
# [9/201] train loss: [0.6572] (epoch [1/3])
# [10/201] train loss: [0.6673] (epoch [1/3])
# [11/201] train loss: [0.6892] (epoch [1/3])
# [12/201] train loss: [0.7114] (epoch [1/3])
# [13/201] train loss: [0.6968] (epoch [1/3])
# [14/201] train loss: [0.6992] (epoch [1/3])
# [15/201] train loss: [0.6778] (epoch [1/3])
# [16/201] train loss: [0.6841] (epoch [1/3])
# [17/201] train loss: [0.6568] (epoch [1/3])
# [18/201] train loss: [0.6580] (epoch [1/3])
# [19/201] train loss: [0.6469] (epoch [1/3])
# [20/201] train loss: [0.6634] (epoch [1/3])
# [21/201] train loss: [0.6657] (epoch [1/3])
# [22/201] train loss: [0.6731] (epoch [1/3])
# [23/201] train loss: [0.6684] (epoch [1/3])
# [24/201] train loss: [0.6568] (epoch [1/3])
# [25/201] train loss: [0.6401] (epoch [1/3])
# [26/201] train loss: [0.6604] (epoch [1/3])
# [27/201] train loss: [0.6603] (epoch [1/3])
# [28/201] train loss: [0.6545] (epoch [1/3])
# [29/201] train loss: [0.6802] (epoch [1/3])
# [30/201] train loss: [0.6521] (epoch [1/3])
# [31/201] train loss: [0.6449] (epoch [1/3])
# [32/201] train loss: [0.6640] (epoch [1/3])
# [33/201] train loss: [0.6599] (epoch [1/3])
# [34/201] train loss: [0.6475] (epoch [1/3])
# [35/201] train loss: [0.6718] (epoch [1/3])
# [36/201] train loss: [0.6425] (epoch [1/3])
# [37/201] train loss: [0.6453] (epoch [1/3])
# [38/201] train loss: [0.6579] (epoch [1/3])
# [39/201] train loss: [0.6637] (epoch [1/3])
# [40/201] train loss: [0.6325] (epoch [1/3])
# [41/201] train loss: [0.6499] (epoch [1/3])
# [42/201] train loss: [0.6575] (epoch [1/3])
# [43/201] train loss: [0.6502] (epoch [1/3])
# [44/201] train loss: [0.6453] (epoch [1/3])
# [45/201] train loss: [0.6432] (epoch [1/3])
# [46/201] train loss: [0.6451] (epoch [1/3])
# [47/201] train loss: [0.6524] (epoch [1/3])
# [48/201] train loss: [0.6553] (epoch [1/3])
# [49/201] train loss: [0.6461] (epoch [1/3])
# [50/201] train loss: [0.6426] (epoch [1/3])
# [51/201] train loss: [0.6531] (epoch [1/3])
# [52/201] train loss: [0.6550] (epoch [1/3])
# [53/201] train loss: [0.6555] (epoch [1/3])
# [54/201] train loss: [0.6430] (epoch [1/3])
# [55/201] train loss: [0.6552] (epoch [1/3])
# [56/201] train loss: [0.6564] (epoch [1/3])
# [57/201] train loss: [0.6453] (epoch [1/3])
# [58/201] train loss: [0.6326] (epoch [1/3])
# [59/201] train loss: [0.6348] (epoch [1/3])
# [60/201] train loss: [0.6530] (epoch [1/3])
# [61/201] train loss: [0.6419] (epoch [1/3])
# [62/201] train loss: [0.6364] (epoch [1/3])
# [63/201] train loss: [0.6513] (epoch [1/3])
# [64/201] train loss: [0.6318] (epoch [1/3])
# [65/201] train loss: [0.6494] (epoch [1/3])
# [66/201] train loss: [0.6425] (epoch [1/3])
# [67/201] train loss: [0.6472] (epoch [1/3])
# [68/201] train loss: [0.6534] (epoch [2/3])
# [69/201] train loss: [0.6527] (epoch [2/3])
# [70/201] train loss: [0.6360] (epoch [2/3])
# [71/201] train loss: [0.6520] (epoch [2/3])
# [72/201] train loss: [0.6460] (epoch [2/3])
# [73/201] train loss: [0.6541] (epoch [2/3])
# [74/201] train loss: [0.6488] (epoch [2/3])
# [75/201] train loss: [0.6451] (epoch [2/3])
# [76/201] train loss: [0.6589] (epoch [2/3])
# [77/201] train loss: [0.6602] (epoch [2/3])
# [78/201] train loss: [0.6546] (epoch [2/3])
# [79/201] train loss: [0.6531] (epoch [2/3])
# [80/201] train loss: [0.6425] (epoch [2/3])
# [81/201] train loss: [0.6334] (epoch [2/3])
# [82/201] train loss: [0.6488] (epoch [2/3])
# [83/201] train loss: [0.6470] (epoch [2/3])
# [84/201] train loss: [0.6287] (epoch [2/3])
# [85/201] train loss: [0.6389] (epoch [2/3])
# [86/201] train loss: [0.6517] (epoch [2/3])
# [87/201] train loss: [0.6306] (epoch [2/3])
# [88/201] train loss: [0.6429] (epoch [2/3])
# [89/201] train loss: [0.6498] (epoch [2/3])
# [90/201] train loss: [0.6402] (epoch [2/3])
# [91/201] train loss: [0.6464] (epoch [2/3])
# [92/201] train loss: [0.6441] (epoch [2/3])
# [93/201] train loss: [0.6619] (epoch [2/3])
# [94/201] train loss: [0.6503] (epoch [2/3])
# [95/201] train loss: [0.6460] (epoch [2/3])
# [96/201] train loss: [0.6475] (epoch [2/3])
# [97/201] train loss: [0.6491] (epoch [2/3])
# [98/201] train loss: [0.6426] (epoch [2/3])
# [99/201] train loss: [0.6445] (epoch [2/3])
# [100/201] train loss: [0.6389] (epoch [2/3])
# [100/201] validation loss: [0.6494] validation accuracy: [0.6792]
# [101/201] train loss: [0.6567] (epoch [2/3])
# [102/201] train loss: [0.6244] (epoch [2/3])
# [103/201] train loss: [0.6391] (epoch [2/3])
# [104/201] train loss: [0.6202] (epoch [2/3])
# [105/201] train loss: [0.6310] (epoch [2/3])
# [106/201] train loss: [0.6434] (epoch [2/3])
# [107/201] train loss: [0.6502] (epoch [2/3])
# [108/201] train loss: [0.6382] (epoch [2/3])
# [109/201] train loss: [0.6295] (epoch [2/3])
# [110/201] train loss: [0.6474] (epoch [2/3])
# [111/201] train loss: [0.6544] (epoch [2/3])
# [112/201] train loss: [0.6336] (epoch [2/3])
# [113/201] train loss: [0.6568] (epoch [2/3])
# [114/201] train loss: [0.6606] (epoch [2/3])
# [115/201] train loss: [0.6346] (epoch [2/3])
# [116/201] train loss: [0.6440] (epoch [2/3])
# [117/201] train loss: [0.6443] (epoch [2/3])
# [118/201] train loss: [0.6455] (epoch [2/3])
# [119/201] train loss: [0.6532] (epoch [2/3])
# [120/201] train loss: [0.6501] (epoch [2/3])
# [121/201] train loss: [0.6477] (epoch [2/3])
# [122/201] train loss: [0.6346] (epoch [2/3])
# [123/201] train loss: [0.6328] (epoch [2/3])
# [124/201] train loss: [0.6502] (epoch [2/3])
# [125/201] train loss: [0.6398] (epoch [2/3])
# [126/201] train loss: [0.6341] (epoch [2/3])
# [127/201] train loss: [0.6519] (epoch [2/3])
# [128/201] train loss: [0.6422] (epoch [2/3])
# [129/201] train loss: [0.6436] (epoch [2/3])
# [130/201] train loss: [0.6447] (epoch [2/3])
# [131/201] train loss: [0.6545] (epoch [2/3])
# [132/201] train loss: [0.6467] (epoch [2/3])
# [133/201] train loss: [0.6580] (epoch [2/3])
# [134/201] train loss: [0.6142] (epoch [2/3])
# [135/201] train loss: [0.6355] (epoch [3/3])
# [136/201] train loss: [0.6411] (epoch [3/3])
# [137/201] train loss: [0.6514] (epoch [3/3])
# [138/201] train loss: [0.6533] (epoch [3/3])
# [139/201] train loss: [0.6537] (epoch [3/3])
# [140/201] train loss: [0.6383] (epoch [3/3])
# [141/201] train loss: [0.6487] (epoch [3/3])
# [142/201] train loss: [0.6438] (epoch [3/3])
# [143/201] train loss: [0.6500] (epoch [3/3])
# [144/201] train loss: [0.6491] (epoch [3/3])
# [145/201] train loss: [0.6662] (epoch [3/3])
# [146/201] train loss: [0.6660] (epoch [3/3])
# [147/201] train loss: [0.6349] (epoch [3/3])
# [148/201] train loss: [0.6342] (epoch [3/3])
# [149/201] train loss: [0.6428] (epoch [3/3])
# [150/201] train loss: [0.6534] (epoch [3/3])
# [151/201] train loss: [0.6343] (epoch [3/3])
# [152/201] train loss: [0.6527] (epoch [3/3])
# [153/201] train loss: [0.6364] (epoch [3/3])
# [154/201] train loss: [0.6159] (epoch [3/3])
# [155/201] train loss: [0.6514] (epoch [3/3])
# [156/201] train loss: [0.6475] (epoch [3/3])
# [157/201] train loss: [0.6300] (epoch [3/3])
# [158/201] train loss: [0.6457] (epoch [3/3])
# [159/201] train loss: [0.6378] (epoch [3/3])
# [160/201] train loss: [0.6499] (epoch [3/3])
# [161/201] train loss: [0.6491] (epoch [3/3])
# [162/201] train loss: [0.6595] (epoch [3/3])
# [163/201] train loss: [0.6234] (epoch [3/3])
# [164/201] train loss: [0.6440] (epoch [3/3])
# [165/201] train loss: [0.6326] (epoch [3/3])
# [166/201] train loss: [0.6428] (epoch [3/3])
# [167/201] train loss: [0.6430] (epoch [3/3])
# [168/201] train loss: [0.6502] (epoch [3/3])
# [169/201] train loss: [0.6408] (epoch [3/3])
# [170/201] train loss: [0.6469] (epoch [3/3])
# [171/201] train loss: [0.6598] (epoch [3/3])
# [172/201] train loss: [0.6476] (epoch [3/3])
# [173/201] train loss: [0.6571] (epoch [3/3])
# [174/201] train loss: [0.6393] (epoch [3/3])
# [175/201] train loss: [0.6484] (epoch [3/3])
# [176/201] train loss: [0.6545] (epoch [3/3])
# [177/201] train loss: [0.6465] (epoch [3/3])
# [178/201] train loss: [0.6345] (epoch [3/3])
# [179/201] train loss: [0.6515] (epoch [3/3])
# [180/201] train loss: [0.6239] (epoch [3/3])
# [181/201] train loss: [0.6440] (epoch [3/3])
# [182/201] train loss: [0.6412] (epoch [3/3])
# [183/201] train loss: [0.6343] (epoch [3/3])
# [184/201] train loss: [0.6463] (epoch [3/3])
# [185/201] train loss: [0.6382] (epoch [3/3])
# [186/201] train loss: [0.6618] (epoch [3/3])
# [187/201] train loss: [0.6402] (epoch [3/3])
# [188/201] train loss: [0.6550] (epoch [3/3])
# [189/201] train loss: [0.6374] (epoch [3/3])
# [190/201] train loss: [0.6344] (epoch [3/3])
# [191/201] train loss: [0.6454] (epoch [3/3])
# [192/201] train loss: [0.6441] (epoch [3/3])
# [193/201] train loss: [0.6535] (epoch [3/3])
# [194/201] train loss: [0.6493] (epoch [3/3])
# [195/201] train loss: [0.6491] (epoch [3/3])
# [196/201] train loss: [0.6457] (epoch [3/3])
# [197/201] train loss: [0.6498] (epoch [3/3])
# [198/201] train loss: [0.6635] (epoch [3/3])
# [199/201] train loss: [0.6502] (epoch [3/3])
# [200/201] train loss: [0.6347] (epoch [3/3])
# [200/201] validation loss: [0.6494] validation accuracy: [0.6792]
# [201/201] train loss: [0.6648] (epoch [3/3])

# %%
train_loss = compute_loss(train_loader)
train_acc = compute_accuracy(train_loader)
test_loss = compute_loss(test_loader)
test_acc = compute_accuracy(test_loader)
val_loss = compute_loss(val_loader)
test_acc = compute_accuracy(test_loader)

print(f"Train Loss: [{train_loss:.4f}]\nTrain accuracy: [{train_acc:.4f}]")
print(f"Test Loss: [{test_loss:.4f}]\nTest accuracy: [{test_acc:.4f}]")
print(f"Validation Loss: [{val_loss:.4f}]\nValidation accuracy: [{val_acc:.4f}]")
print(val_losses)
# Out:
# Train Loss: [1.2643]
# Train accuracy: [0.6930]
# Test Loss: [0.6461]
# Test accuracy: [0.6792]
# Validation Loss: [0.6494]
# Validation accuracy: [0.6792]
# [tensor(0.9759), tensor(0.6494), tensor(0.6494)]

# %%
# Set validation steps to match the indices in val_losses
val_steps = [i * 100 for i in range(len(val_losses))]

# Subplots for training and vlidation loss & validation accuracy (updated for each epoch)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot Training and Validation Loss subplot
ax1.plot(train_losses, label='Training Loss', marker='x')
ax1.plot(val_steps, val_losses, label='Validation Loss', marker='o')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Training Steps')
ax1.set_ylabel('Loss')
ax1.grid(True)
ax1.legend()

# Plot Validation Accuracy subplot
ax2.plot(val_steps, val_accs, label='Validation Accuracy', marker='x')
ax2.set_title('Validation Accuracy')
ax2.set_xlabel('Training Steps')
ax2.set_ylabel('Accuracy')
ax2.grid(True)
ax2.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# compute predictions and labels for confusion matrix computing
def compute_pedictions_and_labels(
        model : nn.Module,
        test_loader : DataLoader,
        device : torch.device
    ) -> tuple:

    model.to(device)

    model.eval()

    # Lists to store all predictions and actual labels
    all_predictions = []
    all_labels = []

    with torch.no_grad():
        for data in test_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)

            logits = model(input_ids, attention_mask=attention_mask)

            predictions = (logits > 0).long()

            all_predictions.extend(predictions.view(-1).cpu().numpy())
            all_labels.extend(labels.view(-1).cpu().numpy())

    return all_predictions, all_labels

all_predictions, all_labels = compute_pedictions_and_labels(cls_model, test_loader, device)

# %%
def plot_f1_score(
        all_predictions : list,
        all_labels : list
    ) -> None:
    f1 = f1_score(all_labels, all_predictions)
    print("F1 Score: ", f1)

plot_f1_score(all_predictions, all_labels)
# Out:
# F1 Score:  0.6736641221374046

# %%
def accuracyscore(
      all_predictions: list,
      all_labels: list
    ) -> float:
    correct_predicts = sum([1 for pred, label in zip(all_predictions, all_labels) if pred == label])
    accuracy = correct_predicts / len(all_labels)
    return accuracy

print("Accuracy Score: ",accuracyscore(all_predictions, all_labels))
# Out:
# Accuracy Score:  0.6791744840525328

# %%
# visualization 2: confusion matrix

def plot_confusion(
        all_predictions : list,
        all_labels : list
    ) -> None:

    cm = confusion_matrix(all_labels, all_predictions) # from sklearn

    plt.figure(figsize=(6,4))
    sns.heatmap(cm, annot=True, fmt='d', linewidths=0.2, cmap="YlGnBu", cbar=False)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.xticks([0.5, 1.5], ['Negative', 'Positive'])
    plt.yticks([0.5, 1.5], ['Negative', 'Positive'], va='center')
    plt.show()

plot_confusion(all_predictions, all_labels)
