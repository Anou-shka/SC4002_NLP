# %%
GLOVE_PATH = "glove.6B.100d.txt" # change to your path
EMBED_DIM = 100 # No need to change

# %%
from transformers import get_cosine_schedule_with_warmup
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.utils.data import DataLoader, Dataset
import matplotlib as mpl
import matplotlib.pyplot as plt
from tensorflow import keras
import pandas as pd
import numpy as np
import random
from sklearn.metrics import confusion_matrix, f1_score, f1_score, roc_curve, auc, precision_recall_curve, average_precision_score
import seaborn as sns
from Embeddings import GloveEmbedding, GloveTokenizerNoSub
import itertools
import torch
from torch.utils.data import DataLoader
from typing import Any
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import copy

# %%
# set seeds
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(114514)

# %%
# import tokenizer
tokenizer_no_sub = GloveTokenizerNoSub(glove_file_path=GLOVE_PATH)
embedding = GloveEmbedding(
    glove_file_path = GLOVE_PATH,
    trainable = True # False for part 2 to disable the Embedding training
)

# %%
class SentimentRNN(nn.Module):
    def __init__(self, embedding, hidden_size, embed_size, bidirectional, num_rnn_layer, dropout_rate, layer_norm):
        super(SentimentRNN, self).__init__()
        self.embedding = embedding  # pass pretrained embedding in
        self.bidirectional = bidirectional
        self.rnn = nn.RNN(embed_size, hidden_size, batch_first=True, num_layers = num_rnn_layer, bidirectional=bidirectional, dropout = dropout_rate if num_rnn_layer > 1 else 0)

        # if bidirectional, the output hidden size is double
        self.hidden_size = hidden_size * 2 if bidirectional else hidden_size

        # MLP
        if not layer_norm:
            self.output_layer = nn.Sequential(
                nn.Dropout(dropout_rate),
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.GELU(),
                nn.Linear(self.hidden_size, 1),  # output dimension is 1 (sigmoid is in BCELossWithLogits, so no sigmoid here. This will get better result)
            )
        else:
            self.output_layer = nn.Sequential(
                nn.LayerNorm(self.hidden_size),
                nn.Dropout(dropout_rate),
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.LayerNorm(self.hidden_size),
                nn.GELU(),
                nn.Linear(self.hidden_size, 1),
            )

    def forward(self, input_ids, attention_mask):
        '''
        This method is designed for biLSTM/GRU/RNN. For LSTM/GRU/RNN for only one direction, just take hidden as the rnn output.
        RNN - hidden -> MLP --> outcome
        '''
        # embed the input
        embedded = self.embedding(input_ids)  # [batch_size, seq_length, embedding_dim]

        # feed forward
        output, hidden = self.rnn(embedded) # we don't need encoder so we only keep the output

        # make attention mask from [batch_size, seq_length] to [batch_size, seq_length, 1] as the same dimension as rnn
        attention_mask = attention_mask.unsqueeze(-1)  # [batch_size, seq_length, 1]

        # use attention mask to mask the output, ignore the padding embedding vector, only add the valid embedding vector
        masked_output = output * attention_mask

        # sum up all the valid output
        summed_output = masked_output.sum(dim=1)  # [batch_size, hidden_size]

        logits = self.output_layer(summed_output)

        return logits  # The output is [batch_size, 1]

# %%
# import datasets

train_df = pd.read_csv("./preprocessed_dataset/train.csv").iloc[:,1:]
validation_df = pd.read_csv("./preprocessed_dataset/validation.csv").iloc[:,1:]
test_df = pd.read_csv("./preprocessed_dataset/test.csv").iloc[:,1:]

# %%
# try to use tokenizer api
tokenizer_no_sub.encode(["hello world", "how are you"], return_tensors = "pt") # insist to return pytorch
# Out:
# {'input_ids': tensor([[13077,    87,     0],
#          [  199,    34,    83]]),
#  'attention_mask': tensor([[1, 1, 0],
#          [1, 1, 1]])}

# %%
# Hyper paramaters
dropout_rate = 0.1
num_rnn_layer = 1
hidden_dim = 256

val_steps = 100 # compute validation error every n step

num_train_epochs = 3

batch_size = 32
lr = 8e-5
weight_decay = 1e-5


warmup_ratio=0.1
max_grad_norm = 2.0

# %%
# define dataset and data loader
class CustomizeDataset(Dataset):
    def __init__(
            self,
            df : pd.DataFrame
        ) -> None:
        super().__init__()
        self.df = df

    def __len__(self) -> int:
        return len(self.df)

    def __getitem__(
            self,
            index : int
        ) -> dict:

        inputs = self.df.iloc[index,0] # 0 is text
        label = self.df.iloc[index, 1] # 1 is label

        return {
            "input_str" : inputs, # output a string
            "label" : label # output a label
        }

# collater function (used for dynamic padding to save memory)
class Collater:
    def __init__(
            self,
            tokenizer_no_sub : GloveTokenizerNoSub
        ) -> None:
        self.tokenizer_no_sub = tokenizer_no_sub

    def __call__(
            self,
            instances : list # a list of string
        ) -> Any:
        # __call__ is for function-like object
        input_str_list = [instance["input_str"] for instance in instances]
        input_dict = tokenizer_no_sub.encode(input_str_list, return_tensors = "pt") # return pytorch tensor
        input_ids = input_dict["input_ids"]
        attention_mask = input_dict["attention_mask"]
        label = [torch.tensor(instance["label"], dtype = torch.int64) for instance in instances]

        return {
            "input_ids": input_ids,
            "label": torch.tensor(label),
            "attention_mask": attention_mask # mask the pad position
        }

# %%
# create dataset and data loader
collate_fn = Collater(tokenizer_no_sub)



train_ds = CustomizeDataset(
    df = train_df
)

train_loader = DataLoader(
    dataset = train_ds,
    batch_size = batch_size,
    collate_fn = collate_fn,
    shuffle = True
)

val_ds = CustomizeDataset(
    df = validation_df
)

val_loader = DataLoader(
    dataset = val_ds,
    batch_size = batch_size,
    collate_fn = collate_fn
)

test_ds = CustomizeDataset(
    df = test_df
)

test_loader = DataLoader(
    dataset = test_ds,
    batch_size = batch_size,
    collate_fn = collate_fn
)

# %%
# compute warmup status
num_training_steps = num_train_epochs * len(train_loader)
num_warmup_steps = int(num_training_steps * warmup_ratio)
print(f"train:{num_training_steps}, warm up: {num_warmup_steps}")
# Out:
# train:801, warm up: 80

# %%
# Set optimizer, loss_fn and so on

cls_model = SentimentRNN(
    embedding = embedding,
    hidden_size = hidden_dim,
    embed_size = EMBED_DIM,
    bidirectional = False, #  False for part 2
    num_rnn_layer = num_rnn_layer,
    dropout_rate = dropout_rate,
    layer_norm = True # set if you need layer norm
)

loss_fn = nn.BCEWithLogitsLoss()

optimizer = AdamW(
    params = cls_model.parameters(),
    lr = lr,
    weight_decay = weight_decay
)

scheduler  = get_cosine_schedule_with_warmup(
    optimizer = optimizer,
    num_warmup_steps = num_warmup_steps,
    num_training_steps = num_training_steps
)

# %%
# compute accuracy for wach data loader

def compute_accuracy(data_loader: DataLoader) -> float:

    cls_model.eval()

    correct = 0
    total = 0

    with torch.no_grad():
        for data in data_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)

            logits = cls_model(input_ids, attention_mask=attention_mask)

            predictions = (logits > 0).long()

            correct += (predictions == labels).sum().item()
            total += labels.size(0)

    accuracy = correct / total
    return accuracy

def compute_loss(data_loader: DataLoader) -> float:
    total_loss = 0
    cls_model.eval()
    with torch.no_grad():
        for data in data_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)

            logits = cls_model.forward(input_ids, attention_mask)
            loss = loss_fn.forward(
                input = logits,
                target = labels
            )

            total_loss += loss.detach().cpu()

        total_loss /= len(val_loader)

        return total_loss

# %%
def early_stopping(train_loss, validation_loss, min_delta, tolerance, counter):
    positive_diff = abs(validation_loss - train_loss)

    # Increment counter if no significant improvement
    if positive_diff >= min_delta:
        counter += 1
        if counter >= tolerance:
            return True, counter
    # Ensure the function always returns both values
    return False, counter

# %%
# Training loop

cls_model.to(device)

optimizer.zero_grad()

step = 0

train_losses = []

val_accs = []

val_losses = []

counter = 0

for epoch in range(num_train_epochs):

    # train loop
    for data in train_loader:
        cls_model.train()
        input_ids = data["input_ids"].to(device)
        attention_mask = data["attention_mask"].to(device)
        label = data["label"].view(-1, 1).float().to(device)

        logits = cls_model.forward(input_ids, attention_mask)


        loss = loss_fn.forward(
            input = logits,
            target = label
        )

        loss.backward()

        # Gradient clip (important for RNN, not necessary for LSTM/GRU/conv1d)
        torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)

        optimizer.step() # update paramater
        scheduler.step()
        optimizer.zero_grad() # clear gradient

        vis_loss = loss.detach().cpu()

        print(f"[{step + 1}/{num_training_steps}] train loss: [{vis_loss:.4f}] (epoch [{epoch + 1}/{num_train_epochs}])")


        train_losses.append(vis_loss)
        i =0

        if (step + 1) % val_steps == 0 or step == 0:
            # compute validation every "val_steps"

            cls_model.eval()
            val_loss = compute_loss(val_loader)
            val_acc = compute_accuracy(val_loader)
            val_accs.append(val_acc)
            val_losses.append(val_loss)

            print(f"[{step + 1}/{num_training_steps}] validation loss: [{val_loss:.4f}] validation accuracy: [{val_acc:.4f}]")
            # Apply early stopping
            should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.01, tolerance=2, counter=counter)
            if should_stop:
                print("Early stopping triggered.")
                break

        step += 1

    if should_stop:
        break  # Exit e
# Out:
# [1/801] train loss: [0.7229] (epoch [1/3])
# [1/801] validation loss: [0.7005] validation accuracy: [0.4981]
# [2/801] train loss: [0.7196] (epoch [1/3])
# [3/801] train loss: [0.7347] (epoch [1/3])
# [4/801] train loss: [0.7215] (epoch [1/3])
# [5/801] train loss: [0.7200] (epoch [1/3])
# [6/801] train loss: [0.7436] (epoch [1/3])
# [7/801] train loss: [0.6639] (epoch [1/3])
# [8/801] train loss: [0.7321] (epoch [1/3])
# [9/801] train loss: [0.6915] (epoch [1/3])
# [10/801] train loss: [0.7232] (epoch [1/3])
# [11/801] train loss: [0.6936] (epoch [1/3])
# [12/801] train loss: [0.6853] (epoch [1/3])
# [13/801] train loss: [0.7137] (epoch [1/3])
# [14/801] train loss: [0.6974] (epoch [1/3])
# [15/801] train loss: [0.6877] (epoch [1/3])
# [16/801] train loss: [0.6936] (epoch [1/3])
# [17/801] train loss: [0.7036] (epoch [1/3])
# [18/801] train loss: [0.6968] (epoch [1/3])
# [19/801] train loss: [0.7112] (epoch [1/3])
# [20/801] train loss: [0.6952] (epoch [1/3])
# [21/801] train loss: [0.6948] (epoch [1/3])
# [22/801] train loss: [0.6913] (epoch [1/3])
# [23/801] train loss: [0.7010] (epoch [1/3])
# [24/801] train loss: [0.6953] (epoch [1/3])
# [25/801] train loss: [0.6756] (epoch [1/3])
# [26/801] train loss: [0.6704] (epoch [1/3])
# [27/801] train loss: [0.6979] (epoch [1/3])
# [28/801] train loss: [0.7172] (epoch [1/3])
# [29/801] train loss: [0.6898] (epoch [1/3])
# [30/801] train loss: [0.7122] (epoch [1/3])
# [31/801] train loss: [0.6816] (epoch [1/3])
# [32/801] train loss: [0.6958] (epoch [1/3])
# [33/801] train loss: [0.6776] (epoch [1/3])
# [34/801] train loss: [0.7356] (epoch [1/3])
# [35/801] train loss: [0.6985] (epoch [1/3])
# [36/801] train loss: [0.6898] (epoch [1/3])
# [37/801] train loss: [0.6921] (epoch [1/3])
# [38/801] train loss: [0.6974] (epoch [1/3])
# [39/801] train loss: [0.7085] (epoch [1/3])
# [40/801] train loss: [0.6699] (epoch [1/3])
# [41/801] train loss: [0.7106] (epoch [1/3])
# [42/801] train loss: [0.7013] (epoch [1/3])
# [43/801] train loss: [0.7008] (epoch [1/3])
# [44/801] train loss: [0.6698] (epoch [1/3])
# [45/801] train loss: [0.6612] (epoch [1/3])
# [46/801] train loss: [0.6668] (epoch [1/3])
# [47/801] train loss: [0.6809] (epoch [1/3])
# [48/801] train loss: [0.7056] (epoch [1/3])
# [49/801] train loss: [0.6703] (epoch [1/3])
# [50/801] train loss: [0.6729] (epoch [1/3])
# [51/801] train loss: [0.6773] (epoch [1/3])
# [52/801] train loss: [0.6709] (epoch [1/3])
# [53/801] train loss: [0.6630] (epoch [1/3])
# [54/801] train loss: [0.6918] (epoch [1/3])
# [55/801] train loss: [0.6568] (epoch [1/3])
# [56/801] train loss: [0.6601] (epoch [1/3])
# [57/801] train loss: [0.6871] (epoch [1/3])
# [58/801] train loss: [0.6437] (epoch [1/3])
# [59/801] train loss: [0.6702] (epoch [1/3])
# [60/801] train loss: [0.7083] (epoch [1/3])
# [61/801] train loss: [0.6913] (epoch [1/3])
# [62/801] train loss: [0.6472] (epoch [1/3])
# [63/801] train loss: [0.6406] (epoch [1/3])
# [64/801] train loss: [0.7098] (epoch [1/3])
# [65/801] train loss: [0.6855] (epoch [1/3])
# [66/801] train loss: [0.6790] (epoch [1/3])
# [67/801] train loss: [0.7100] (epoch [1/3])
# [68/801] train loss: [0.6625] (epoch [1/3])
# [69/801] train loss: [0.6778] (epoch [1/3])
# [70/801] train loss: [0.6853] (epoch [1/3])
# [71/801] train loss: [0.6584] (epoch [1/3])
# [72/801] train loss: [0.6332] (epoch [1/3])
# [73/801] train loss: [0.6182] (epoch [1/3])
# [74/801] train loss: [0.6432] (epoch [1/3])
# [75/801] train loss: [0.6509] (epoch [1/3])
# [76/801] train loss: [0.6865] (epoch [1/3])
# [77/801] train loss: [0.6809] (epoch [1/3])
# [78/801] train loss: [0.6440] (epoch [1/3])
# [79/801] train loss: [0.5775] (epoch [1/3])
# [80/801] train loss: [0.6409] (epoch [1/3])
# [81/801] train loss: [0.7313] (epoch [1/3])
# [82/801] train loss: [0.7110] (epoch [1/3])
# [83/801] train loss: [0.7997] (epoch [1/3])
# [84/801] train loss: [0.6368] (epoch [1/3])
# [85/801] train loss: [0.6219] (epoch [1/3])
# [86/801] train loss: [0.6160] (epoch [1/3])
# [87/801] train loss: [0.6574] (epoch [1/3])
# [88/801] train loss: [0.6955] (epoch [1/3])
# [89/801] train loss: [0.6310] (epoch [1/3])
# [90/801] train loss: [0.6510] (epoch [1/3])
# [91/801] train loss: [0.7287] (epoch [1/3])
# [92/801] train loss: [0.6210] (epoch [1/3])
# [93/801] train loss: [0.5902] (epoch [1/3])
# [94/801] train loss: [0.6491] (epoch [1/3])
# [95/801] train loss: [0.6512] (epoch [1/3])
# [96/801] train loss: [0.6013] (epoch [1/3])
# [97/801] train loss: [0.7110] (epoch [1/3])
# [98/801] train loss: [0.6565] (epoch [1/3])
# [99/801] train loss: [0.6391] (epoch [1/3])
# [100/801] train loss: [0.6757] (epoch [1/3])
# [100/801] validation loss: [0.6299] validation accuracy: [0.6811]
# Early stopping triggered.

# %%
# Test the model
# Define hyperparameter ranges
param_grid = {
    "num_rnn_layer": range(1, 2),  # Integer range for number of RNN layers
    "hidden_dim": [128, 256],  # Integer range for hidden dimension size
    "dropout_rate": [0.1, 0.2],  # Continuous range for dropout rate
    "learning_rate": [1e-4, 1e-3],  # Continuous range for learning rate
    "batch_size": [128, 256],  # Integer range for batch size
    "max_grad_norm": [1.0, 2.0],  # Continuous range for gradient clipping
    "num_train_epochs": [1,2,3]  # Integer range for number of training epochs
}

# Track the best configuration
best_val_loss = float('inf')
best_val_accuracy = 0.0
best_params = None

# Generate all combinations of hyperparameters
for params in itertools.product(
    param_grid["num_rnn_layer"],
    param_grid["hidden_dim"],
    param_grid["dropout_rate"],
    param_grid["learning_rate"],
    param_grid["batch_size"],
    param_grid["max_grad_norm"],
    param_grid["num_train_epochs"]
):
    # Unpack hyperparameters
    num_rnn_layer, hidden_dim, dropout_rate, learning_rate, batch_size, max_grad_norm, num_train_epochs = params

    # Initialize model with current parameters
    cls_model = SentimentRNN(
        embedding=embedding,
        hidden_size=hidden_dim,
        embed_size=EMBED_DIM,
        bidirectional=False,
        num_rnn_layer=num_rnn_layer,
        dropout_rate=dropout_rate,
        layer_norm=True
    ).to(device)

    # Set up optimizer and scheduler
    optimizer = torch.optim.Adam(cls_model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

    # DataLoader for selected batch size
    train_loader = DataLoader(
        dataset=train_ds,
        batch_size=batch_size,
        collate_fn=collate_fn,
        shuffle=True
    )

    # Early stopping and metrics tracking variables
    counter = 0
    step = 0
    train_losses = []
    val_losses = []
    val_accs = []
    should_stop = False
    early_stopped = False  # Flag to indicate early stopping for this trial

    for epoch in range(num_train_epochs):
        # Training loop
        for data in train_loader:
            cls_model.train()
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            label = data["label"].view(-1, 1).float().to(device)

            logits = cls_model(input_ids, attention_mask)

            loss = loss_fn(input=logits, target=label)
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)

            optimizer.step()
            scheduler.step()
            optimizer.zero_grad()

            vis_loss = loss.detach().cpu().item()
            train_losses.append(vis_loss)

            # Validation step every `val_steps`
            if (step + 1) % val_steps == 0 or step == 0:
                cls_model.eval()
                val_loss = compute_loss(val_loader)
                val_acc = compute_accuracy(val_loader)
                val_losses.append(val_loss)
                val_accs.append(val_acc)

                # Early stopping check
                should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.5, tolerance=2, counter=counter)
                if should_stop:
                    print("Early stopping triggered.")
                    early_stopped = True  # Mark this trial as early stopped
                    break

            step += 1

        if should_stop:
            break  # Exit epoch loop if early stopping is triggered

    # Track the best parameters and validation loss
    current_val_loss = val_losses[-1] if val_losses else float('inf')
    current_val_accuracy = val_accs[-1] if val_accs else 0.0
    if current_val_accuracy > best_val_accuracy and early_stopped==False:
        best_val_loss = current_val_loss
        best_val_accuracy = current_val_accuracy
        best_params = params

    # Print the trial's results, including early stopping info
    print(f"Trial with params: {params}")
    print(f"  Validation Loss: {current_val_loss}")
    print(f"  Validation Accuracy: {current_val_accuracy}")
    if early_stopped:
        print("  Early stopped")


# Print the best result
print("Best result:")
print(f"  Validation Loss: {best_val_loss}")
print(f"  Validation Accuracy: {best_val_accuracy}")
print("  Best hyperparameters:", best_params)
# Out:
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.7087391018867493
#   Validation Accuracy: 0.4971857410881801
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.68108731508255
#   Validation Accuracy: 0.5881801125703565
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6902998089790344
#   Validation Accuracy: 0.5412757973733584
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.7024887800216675
#   Validation Accuracy: 0.4793621013133208
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6802033185958862
#   Validation Accuracy: 0.6163227016885553
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.680820107460022
#   Validation Accuracy: 0.600375234521576
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6920332312583923
#   Validation Accuracy: 0.5431519699812383
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6922683119773865
#   Validation Accuracy: 0.5168855534709194
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6674167513847351
#   Validation Accuracy: 0.6350844277673546
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.6881601214408875
#   Validation Accuracy: 0.5281425891181989
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.688442051410675
#   Validation Accuracy: 0.5272045028142589
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6822147965431213
#   Validation Accuracy: 0.5778611632270169
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.7860885858535767
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.5689318776130676
#   Validation Accuracy: 0.7035647279549718
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.611355185508728
#   Validation Accuracy: 0.6669793621013134
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.8452731370925903
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.6420034766197205
#   Validation Accuracy: 0.651031894934334
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.655210554599762
#   Validation Accuracy: 0.6538461538461539
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.7680985331535339
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.6765442490577698
#   Validation Accuracy: 0.5337711069418386
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.5871134996414185
#   Validation Accuracy: 0.700750469043152
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.7491913437843323
#   Validation Accuracy: 0.5056285178236398
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.7349092364311218
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.5868775248527527
#   Validation Accuracy: 0.6894934333958724
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.6993771195411682
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6895718574523926
#   Validation Accuracy: 0.5384615384615384
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.679558277130127
#   Validation Accuracy: 0.5787992495309568
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.6903071403503418
#   Validation Accuracy: 0.5337711069418386
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6880699992179871
#   Validation Accuracy: 0.5666041275797373
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6710297465324402
#   Validation Accuracy: 0.6135084427767354
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6938073635101318
#   Validation Accuracy: 0.5150093808630394
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6916486620903015
#   Validation Accuracy: 0.5150093808630394
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.670964777469635
#   Validation Accuracy: 0.6472795497185742
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.7054151892662048
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6991328001022339
#   Validation Accuracy: 0.4803001876172608
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6882288455963135
#   Validation Accuracy: 0.5412757973733584
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.7613329291343689
#   Validation Accuracy: 0.4971857410881801
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.586452841758728
#   Validation Accuracy: 0.698874296435272
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.5748911499977112
#   Validation Accuracy: 0.699812382739212
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.7178091406822205
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.596515417098999
#   Validation Accuracy: 0.6894934333958724
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6053081154823303
#   Validation Accuracy: 0.6819887429643527
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.707379162311554
#   Validation Accuracy: 0.49437148217636023
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.7415245175361633
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.568149745464325
#   Validation Accuracy: 0.7138836772983115
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.6871256828308105
#   Validation Accuracy: 0.5206378986866792
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.7321911454200745
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6079357266426086
#   Validation Accuracy: 0.6904315196998124
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.7010436058044434
#   Validation Accuracy: 0.4924953095684803
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6394280791282654
#   Validation Accuracy: 0.6894934333958724
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6481631398200989
#   Validation Accuracy: 0.6791744840525328
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.6825036406517029
#   Validation Accuracy: 0.5215759849906192
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6609970927238464
#   Validation Accuracy: 0.6416510318949343
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.659648060798645
#   Validation Accuracy: 0.6679174484052532
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6922977566719055
#   Validation Accuracy: 0.5084427767354597
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.7044100165367126
#   Validation Accuracy: 0.49624765478424016
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.664400041103363
#   Validation Accuracy: 0.6529080675422139
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.7024843096733093
#   Validation Accuracy: 0.4812382739212008
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6782746315002441
#   Validation Accuracy: 0.5984990619136961
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6317943334579468
#   Validation Accuracy: 0.6810506566604128
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.9384951591491699
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.5869860649108887
#   Validation Accuracy: 0.7035647279549718
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.5711679458618164
#   Validation Accuracy: 0.701688555347092
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.8540991544723511
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.5453314185142517
#   Validation Accuracy: 0.726078799249531
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.5597811937332153
#   Validation Accuracy: 0.7148217636022514
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 1)
#   Validation Loss: 1.0323504209518433
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 2)
#   Validation Loss: 1.0092576742172241
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.5569506287574768
#   Validation Accuracy: 0.7195121951219512
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.6851744055747986
#   Validation Accuracy: 0.5272045028142589
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 2)
#   Validation Loss: 1.0707523822784424
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.536591112613678
#   Validation Accuracy: 0.7401500938086304
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.6754867434501648
#   Validation Accuracy: 0.5600375234521576
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6434246897697449
#   Validation Accuracy: 0.6829268292682927
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6500036120414734
#   Validation Accuracy: 0.6763602251407129
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.6881666779518127
#   Validation Accuracy: 0.5581613508442776
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6498633027076721
#   Validation Accuracy: 0.6529080675422139
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6555059552192688
#   Validation Accuracy: 0.6651031894934334
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6962602734565735
#   Validation Accuracy: 0.5196998123827392
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.703042209148407
#   Validation Accuracy: 0.48592870544090055
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6539132595062256
#   Validation Accuracy: 0.6378986866791745
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.6950238347053528
#   Validation Accuracy: 0.5225140712945591
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.7013216018676758
#   Validation Accuracy: 0.49624765478424016
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6473698616027832
#   Validation Accuracy: 0.7054409005628518
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.8802927732467651
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.5563395619392395
#   Validation Accuracy: 0.700750469043152
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.5469996333122253
#   Validation Accuracy: 0.724202626641651
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 1)
#   Validation Loss: 1.043194055557251
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.5449492335319519
#   Validation Accuracy: 0.7279549718574109
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.5458359122276306
#   Validation Accuracy: 0.7279549718574109
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 1)
#   Validation Loss: 1.0686848163604736
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 2)
#   Validation Loss: 1.083633303642273
#   Validation Accuracy: 0.4981238273921201
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.5466419458389282
#   Validation Accuracy: 0.7326454033771107
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.73388671875
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.9133443832397461
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.5381753444671631
#   Validation Accuracy: 0.7335834896810507
# Best result:
#   Validation Loss: 0.536591112613678
#   Validation Accuracy: 0.7401500938086304
#   Best hyperparameters: (1, 256, 0.1, 0.001, 256, 2.0, 3)

# %%
#result of the best parameters ("num_rnn_layer", "hidden_dim", "dropout_rate", "learning_rate", "batch_size", "max_grad_norm", "num_train_epochs")
print({best_val_loss})
print({best_val_accuracy})
print(best_params)
# Out:
# {tensor(0.5366)}
# {0.7401500938086304}
# (1, 256, 0.1, 0.001, 256, 2.0, 3)

# %%
val_steps = 100
batch_size = 128
dropout_rate = 0.1
hidden_dim = 256
learning_rate = 0.001
num_rnn_layer = 1
max_grad_norm = 2.0
num_train_epochs = 3

num_training_steps = num_train_epochs * len(train_loader)
num_warmup_steps = int(num_training_steps * warmup_ratio)
print(f"train:{num_training_steps}, warm up: {num_warmup_steps}")
# Out:
# train:201, warm up: 20

# %%
cls_model = SentimentRNN(
    embedding=embedding,
    hidden_size=hidden_dim,
    embed_size=EMBED_DIM,
    bidirectional=False,  # False for part 2
    num_rnn_layer=num_rnn_layer,
    dropout_rate=dropout_rate,
    layer_norm=True
).to(device)
# Set up optimizer and scheduler
optimizer = torch.optim.Adam(cls_model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

train_loader = DataLoader(
    dataset=train_ds,
    batch_size=batch_size,
    collate_fn=collate_fn,
    shuffle=True
)

optimizer.zero_grad()

step = 0

train_losses = []

val_accs = []

val_losses = []

counter = 0

for epoch in range(num_train_epochs):

    # train loop
    for data in train_loader:
        cls_model.train()
        input_ids = data["input_ids"].to(device)
        attention_mask = data["attention_mask"].to(device)
        label = data["label"].view(-1, 1).float().to(device)

        logits = cls_model.forward(input_ids, attention_mask)


        loss = loss_fn.forward(
            input = logits,
            target = label
        )

        loss.backward()

        # Gradient clip (important for RNN, not necessary for LSTM/GRU/conv1d)
        torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)

        optimizer.step() # update paramater
        scheduler.step()
        optimizer.zero_grad() # clear gradient

        vis_loss = loss.detach().cpu()

        print(f"[{step + 1}/{num_training_steps}] train loss: [{vis_loss:.4f}] (epoch [{epoch + 1}/{num_train_epochs}])")


        train_losses.append(vis_loss)
        i =0

        if (step + 1) % val_steps == 0 or step == 0:
            # compute validation every "val_steps"

            cls_model.eval()
            val_loss = compute_loss(val_loader)
            val_acc = compute_accuracy(val_loader)
            val_accs.append(val_acc)
            val_losses.append(val_loss)

            print(f"[{step + 1}/{num_training_steps}] validation loss: [{val_loss:.4f}] validation accuracy: [{val_acc:.4f}]")
            # Apply early stopping
            should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.5, tolerance=2, counter=counter)
            if should_stop:
                print("Early stopping triggered.")
                break

        step += 1

    if should_stop:
        break  # Exit e
# Out:
# [1/201] train loss: [0.7152] (epoch [1/3])
# [1/201] validation loss: [0.8348] validation accuracy: [0.5000]
# [2/201] train loss: [0.8254] (epoch [1/3])
# [3/201] train loss: [0.6793] (epoch [1/3])
# [4/201] train loss: [0.6721] (epoch [1/3])
# [5/201] train loss: [0.6647] (epoch [1/3])
# [6/201] train loss: [0.6718] (epoch [1/3])
# [7/201] train loss: [0.6620] (epoch [1/3])
# [8/201] train loss: [0.6607] (epoch [1/3])
# [9/201] train loss: [0.6581] (epoch [1/3])
# [10/201] train loss: [0.6355] (epoch [1/3])
# [11/201] train loss: [0.6688] (epoch [1/3])
# [12/201] train loss: [0.6847] (epoch [1/3])
# [13/201] train loss: [0.6461] (epoch [1/3])
# [14/201] train loss: [0.6543] (epoch [1/3])
# [15/201] train loss: [0.6654] (epoch [1/3])
# [16/201] train loss: [0.6437] (epoch [1/3])
# [17/201] train loss: [0.6419] (epoch [1/3])
# [18/201] train loss: [0.6136] (epoch [1/3])
# [19/201] train loss: [0.5907] (epoch [1/3])
# [20/201] train loss: [0.6415] (epoch [1/3])
# [21/201] train loss: [0.6526] (epoch [1/3])
# [22/201] train loss: [0.6435] (epoch [1/3])
# [23/201] train loss: [0.6441] (epoch [1/3])
# [24/201] train loss: [0.6230] (epoch [1/3])
# [25/201] train loss: [0.6107] (epoch [1/3])
# [26/201] train loss: [0.6380] (epoch [1/3])
# [27/201] train loss: [0.5831] (epoch [1/3])
# [28/201] train loss: [0.5742] (epoch [1/3])
# [29/201] train loss: [0.6048] (epoch [1/3])
# [30/201] train loss: [0.6013] (epoch [1/3])
# [31/201] train loss: [0.6094] (epoch [1/3])
# [32/201] train loss: [0.6297] (epoch [1/3])
# [33/201] train loss: [0.5728] (epoch [1/3])
# [34/201] train loss: [0.6640] (epoch [1/3])
# [35/201] train loss: [0.6691] (epoch [1/3])
# [36/201] train loss: [0.5961] (epoch [1/3])
# [37/201] train loss: [0.6113] (epoch [1/3])
# [38/201] train loss: [0.5866] (epoch [1/3])
# [39/201] train loss: [0.6581] (epoch [1/3])
# [40/201] train loss: [0.6026] (epoch [1/3])
# [41/201] train loss: [0.6196] (epoch [1/3])
# [42/201] train loss: [0.6278] (epoch [1/3])
# [43/201] train loss: [0.5578] (epoch [1/3])
# [44/201] train loss: [0.6139] (epoch [1/3])
# [45/201] train loss: [0.6161] (epoch [1/3])
# [46/201] train loss: [0.6138] (epoch [1/3])
# [47/201] train loss: [0.5789] (epoch [1/3])
# [48/201] train loss: [0.5937] (epoch [1/3])
# [49/201] train loss: [0.5862] (epoch [1/3])
# [50/201] train loss: [0.5964] (epoch [1/3])
# [51/201] train loss: [0.6267] (epoch [1/3])
# [52/201] train loss: [0.5755] (epoch [1/3])
# [53/201] train loss: [0.6308] (epoch [1/3])
# [54/201] train loss: [0.5898] (epoch [1/3])
# [55/201] train loss: [0.5744] (epoch [1/3])
# [56/201] train loss: [0.6207] (epoch [1/3])
# [57/201] train loss: [0.5846] (epoch [1/3])
# [58/201] train loss: [0.6025] (epoch [1/3])
# [59/201] train loss: [0.5911] (epoch [1/3])
# [60/201] train loss: [0.6223] (epoch [1/3])
# [61/201] train loss: [0.5914] (epoch [1/3])
# [62/201] train loss: [0.6203] (epoch [1/3])
# [63/201] train loss: [0.5992] (epoch [1/3])
# [64/201] train loss: [0.6341] (epoch [1/3])
# [65/201] train loss: [0.5992] (epoch [1/3])
# [66/201] train loss: [0.5946] (epoch [1/3])
# [67/201] train loss: [0.5938] (epoch [1/3])
# [68/201] train loss: [0.6102] (epoch [2/3])
# [69/201] train loss: [0.5537] (epoch [2/3])
# [70/201] train loss: [0.6009] (epoch [2/3])
# [71/201] train loss: [0.6115] (epoch [2/3])
# [72/201] train loss: [0.6013] (epoch [2/3])
# [73/201] train loss: [0.5929] (epoch [2/3])
# [74/201] train loss: [0.5632] (epoch [2/3])
# [75/201] train loss: [0.6029] (epoch [2/3])
# [76/201] train loss: [0.6087] (epoch [2/3])
# [77/201] train loss: [0.6263] (epoch [2/3])
# [78/201] train loss: [0.5973] (epoch [2/3])
# [79/201] train loss: [0.5878] (epoch [2/3])
# [80/201] train loss: [0.5824] (epoch [2/3])
# [81/201] train loss: [0.6165] (epoch [2/3])
# [82/201] train loss: [0.5919] (epoch [2/3])
# [83/201] train loss: [0.5702] (epoch [2/3])
# [84/201] train loss: [0.6244] (epoch [2/3])
# [85/201] train loss: [0.5695] (epoch [2/3])
# [86/201] train loss: [0.6160] (epoch [2/3])
# [87/201] train loss: [0.5930] (epoch [2/3])
# [88/201] train loss: [0.6095] (epoch [2/3])
# [89/201] train loss: [0.6116] (epoch [2/3])
# [90/201] train loss: [0.6080] (epoch [2/3])
# [91/201] train loss: [0.6148] (epoch [2/3])
# [92/201] train loss: [0.5426] (epoch [2/3])
# [93/201] train loss: [0.5939] (epoch [2/3])
# [94/201] train loss: [0.6093] (epoch [2/3])
# [95/201] train loss: [0.5633] (epoch [2/3])
# [96/201] train loss: [0.6090] (epoch [2/3])
# [97/201] train loss: [0.5484] (epoch [2/3])
# [98/201] train loss: [0.6190] (epoch [2/3])
# [99/201] train loss: [0.6353] (epoch [2/3])
# [100/201] train loss: [0.6525] (epoch [2/3])
# [100/201] validation loss: [0.6085] validation accuracy: [0.6754]
# [101/201] train loss: [0.6224] (epoch [2/3])
# [102/201] train loss: [0.6014] (epoch [2/3])
# [103/201] train loss: [0.6392] (epoch [2/3])
# [104/201] train loss: [0.6166] (epoch [2/3])
# [105/201] train loss: [0.5713] (epoch [2/3])
# [106/201] train loss: [0.5874] (epoch [2/3])
# [107/201] train loss: [0.6137] (epoch [2/3])
# [108/201] train loss: [0.6155] (epoch [2/3])
# [109/201] train loss: [0.6072] (epoch [2/3])
# [110/201] train loss: [0.6108] (epoch [2/3])
# [111/201] train loss: [0.5824] (epoch [2/3])
# [112/201] train loss: [0.6071] (epoch [2/3])
# [113/201] train loss: [0.5909] (epoch [2/3])
# [114/201] train loss: [0.5530] (epoch [2/3])
# [115/201] train loss: [0.6037] (epoch [2/3])
# [116/201] train loss: [0.5673] (epoch [2/3])
# [117/201] train loss: [0.6533] (epoch [2/3])
# [118/201] train loss: [0.5608] (epoch [2/3])
# [119/201] train loss: [0.5992] (epoch [2/3])
# [120/201] train loss: [0.6260] (epoch [2/3])
# [121/201] train loss: [0.6363] (epoch [2/3])
# [122/201] train loss: [0.5672] (epoch [2/3])
# [123/201] train loss: [0.5981] (epoch [2/3])
# [124/201] train loss: [0.6026] (epoch [2/3])
# [125/201] train loss: [0.5839] (epoch [2/3])
# [126/201] train loss: [0.6060] (epoch [2/3])
# [127/201] train loss: [0.5881] (epoch [2/3])
# [128/201] train loss: [0.6299] (epoch [2/3])
# [129/201] train loss: [0.6122] (epoch [2/3])
# [130/201] train loss: [0.6352] (epoch [2/3])
# [131/201] train loss: [0.5926] (epoch [2/3])
# [132/201] train loss: [0.5731] (epoch [2/3])
# [133/201] train loss: [0.5792] (epoch [2/3])
# [134/201] train loss: [0.5750] (epoch [2/3])
# [135/201] train loss: [0.5575] (epoch [3/3])
# [136/201] train loss: [0.5906] (epoch [3/3])
# [137/201] train loss: [0.6132] (epoch [3/3])
# [138/201] train loss: [0.6061] (epoch [3/3])
# [139/201] train loss: [0.5780] (epoch [3/3])
# [140/201] train loss: [0.5805] (epoch [3/3])
# [141/201] train loss: [0.6133] (epoch [3/3])
# [142/201] train loss: [0.5426] (epoch [3/3])
# [143/201] train loss: [0.6240] (epoch [3/3])
# [144/201] train loss: [0.6117] (epoch [3/3])
# [145/201] train loss: [0.6244] (epoch [3/3])
# [146/201] train loss: [0.5923] (epoch [3/3])
# [147/201] train loss: [0.5944] (epoch [3/3])
# [148/201] train loss: [0.5880] (epoch [3/3])
# [149/201] train loss: [0.6036] (epoch [3/3])
# [150/201] train loss: [0.5922] (epoch [3/3])
# [151/201] train loss: [0.5851] (epoch [3/3])
# [152/201] train loss: [0.6087] (epoch [3/3])
# [153/201] train loss: [0.6053] (epoch [3/3])
# [154/201] train loss: [0.6442] (epoch [3/3])
# [155/201] train loss: [0.5852] (epoch [3/3])
# [156/201] train loss: [0.6098] (epoch [3/3])
# [157/201] train loss: [0.5806] (epoch [3/3])
# [158/201] train loss: [0.5961] (epoch [3/3])
# [159/201] train loss: [0.5649] (epoch [3/3])
# [160/201] train loss: [0.6236] (epoch [3/3])
# [161/201] train loss: [0.5955] (epoch [3/3])
# [162/201] train loss: [0.5886] (epoch [3/3])
# [163/201] train loss: [0.5900] (epoch [3/3])
# [164/201] train loss: [0.6010] (epoch [3/3])
# [165/201] train loss: [0.6038] (epoch [3/3])
# [166/201] train loss: [0.6201] (epoch [3/3])
# [167/201] train loss: [0.6406] (epoch [3/3])
# [168/201] train loss: [0.6185] (epoch [3/3])
# [169/201] train loss: [0.6224] (epoch [3/3])
# [170/201] train loss: [0.6134] (epoch [3/3])
# [171/201] train loss: [0.5814] (epoch [3/3])
# [172/201] train loss: [0.5701] (epoch [3/3])
# [173/201] train loss: [0.6226] (epoch [3/3])
# [174/201] train loss: [0.6266] (epoch [3/3])
# [175/201] train loss: [0.5850] (epoch [3/3])
# [176/201] train loss: [0.6319] (epoch [3/3])
# [177/201] train loss: [0.6171] (epoch [3/3])
# [178/201] train loss: [0.5996] (epoch [3/3])
# [179/201] train loss: [0.5716] (epoch [3/3])
# [180/201] train loss: [0.5883] (epoch [3/3])
# [181/201] train loss: [0.6277] (epoch [3/3])
# [182/201] train loss: [0.6047] (epoch [3/3])
# [183/201] train loss: [0.6274] (epoch [3/3])
# [184/201] train loss: [0.6120] (epoch [3/3])
# [185/201] train loss: [0.6213] (epoch [3/3])
# [186/201] train loss: [0.5884] (epoch [3/3])
# [187/201] train loss: [0.6572] (epoch [3/3])
# [188/201] train loss: [0.6078] (epoch [3/3])
# [189/201] train loss: [0.6130] (epoch [3/3])
# [190/201] train loss: [0.5833] (epoch [3/3])
# [191/201] train loss: [0.5887] (epoch [3/3])
# [192/201] train loss: [0.5829] (epoch [3/3])
# [193/201] train loss: [0.6002] (epoch [3/3])
# [194/201] train loss: [0.5879] (epoch [3/3])
# [195/201] train loss: [0.6028] (epoch [3/3])
# [196/201] train loss: [0.5958] (epoch [3/3])
# [197/201] train loss: [0.6032] (epoch [3/3])
# [198/201] train loss: [0.5905] (epoch [3/3])
# [199/201] train loss: [0.5552] (epoch [3/3])
# [200/201] train loss: [0.5964] (epoch [3/3])
# [200/201] validation loss: [0.6085] validation accuracy: [0.6754]
# [201/201] train loss: [0.5726] (epoch [3/3])

# %%
train_loss = compute_loss(train_loader)
train_acc = compute_accuracy(train_loader)
test_loss = compute_loss(test_loader)
test_acc = compute_accuracy(test_loader)
val_loss = compute_loss(val_loader)
test_acc = compute_accuracy(test_loader)

print(f"Train Loss: [{train_loss:.4f}]\nTrain accuracy: [{train_acc:.4f}]")
print(f"Test Loss: [{test_loss:.4f}]\nTest accuracy: [{test_acc:.4f}]")
print(f"Validation Loss: [{val_loss:.4f}]\nValidation accuracy: [{val_acc:.4f}]")
print(val_losses)
# Out:
# Train Loss: [1.1744]
# Train accuracy: [0.6812]
# Test Loss: [0.6046]
# Test accuracy: [0.6698]
# Validation Loss: [0.6085]
# Validation accuracy: [0.6754]
# [tensor(0.8348), tensor(0.6085), tensor(0.6085)]

# %%
# Set validation steps to match the indices in val_losses
val_steps = [i * 100 for i in range(len(val_losses))]

# Subplots for training and vlidation loss & validation accuracy (updated for each epoch)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot Training and Validation Loss subplot
ax1.plot(train_losses, label='Training Loss', marker='x')
ax1.plot(val_steps, val_losses, label='Validation Loss', marker='o')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Training Steps')
ax1.set_ylabel('Loss')
ax1.grid(True)
ax1.legend()

# Plot Validation Accuracy subplot
ax2.plot(val_steps, val_accs, label='Validation Accuracy', marker='x')
ax2.set_title('Validation Accuracy')
ax2.set_xlabel('Training Steps')
ax2.set_ylabel('Accuracy')
ax2.grid(True)
ax2.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# compute predictions and labels for confusion matrix computing
def compute_pedictions_and_labels(
        model : nn.Module,
        test_loader : DataLoader,
        device : torch.device
    ) -> tuple:

    model.to(device)

    model.eval()

    # Lists to store all predictions and actual labels
    all_predictions = []
    all_labels = []

    with torch.no_grad():
        for data in test_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)

            logits = model(input_ids, attention_mask=attention_mask)

            predictions = (logits > 0).long()

            all_predictions.extend(predictions.view(-1).cpu().numpy())
            all_labels.extend(labels.view(-1).cpu().numpy())

    return all_predictions, all_labels

all_predictions, all_labels = compute_pedictions_and_labels(cls_model, test_loader, device)

# %%
def plot_f1_score(
        all_predictions : list,
        all_labels : list
    ) -> None:
    f1 = f1_score(all_labels, all_predictions)
    print("F1 Score: ", f1)

plot_f1_score(all_predictions, all_labels)
# Out:
# F1 Score:  0.6634799235181644

# %%
def accuracyscore(
      all_predictions: list,
      all_labels: list
    ) -> float:
    correct_predicts = sum([1 for pred, label in zip(all_predictions, all_labels) if pred == label])
    accuracy = correct_predicts / len(all_labels)
    return accuracy

print("Accuracy Score: ",accuracyscore(all_predictions, all_labels))
# Out:
# Accuracy Score:  0.6697936210131332

# %%
# visualization 2: confusion matrix

def plot_confusion(
        all_predictions : list,
        all_labels : list
    ) -> None:

    cm = confusion_matrix(all_labels, all_predictions) # from sklearn

    plt.figure(figsize=(6,4))
    sns.heatmap(cm, annot=True, fmt='d', linewidths=0.2, cmap="YlGnBu", cbar=False)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.xticks([0.5, 1.5], ['Negative', 'Positive'])
    plt.yticks([0.5, 1.5], ['Negative', 'Positive'], va='center')
    plt.show()

plot_confusion(all_predictions, all_labels)
