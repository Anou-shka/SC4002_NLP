# %%
GLOVE_PATH = "glove.6B.100d.txt" # change to your path
EMBED_DIM = 100 # No need to change

# %%
# !pip install unidecode
from transformers import get_cosine_schedule_with_warmup
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.utils.data import DataLoader, Dataset
import matplotlib as mpl
import matplotlib.pyplot as plt
from tensorflow import keras
import pandas as pd
import numpy as np
import random
from sklearn.metrics import confusion_matrix, f1_score, f1_score, roc_curve, auc, precision_recall_curve, average_precision_score
import seaborn as sns
from Embeddings import GloveEmbedding, GloveTokenizerNoSub
import itertools
import torch
from torch.utils.data import DataLoader
from typing import Any
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import copy
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.8)

# %%
# set seeds
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(114514)

# %%
# import tokenizer
tokenizer_no_sub = GloveTokenizerNoSub(glove_file_path=GLOVE_PATH)
embedding = GloveEmbedding(
    glove_file_path = GLOVE_PATH,
    trainable = False # False for part 2 to disable the Embedding training
)

# %%
class SentimentRNN(nn.Module):
    def __init__(self, embedding, hidden_size, embed_size, bidirectional, num_rnn_layer, dropout_rate, layer_norm):
        super(SentimentRNN, self).__init__()
        self.embedding = embedding  # pass pretrained embedding in
        self.bidirectional = bidirectional
        self.rnn = nn.RNN(embed_size, hidden_size, batch_first=True, num_layers = num_rnn_layer, bidirectional=bidirectional, dropout = dropout_rate if num_rnn_layer > 1 else 0)

        # if bidirectional, the output hidden size is double
        self.hidden_size = hidden_size * 2 if bidirectional else hidden_size

        # MLP
        if not layer_norm:
            self.output_layer = nn.Sequential(
                nn.Dropout(dropout_rate),
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.GELU(),
                nn.Linear(self.hidden_size, 1),  # output dimension is 1 (sigmoid is in BCELossWithLogits, so no sigmoid here. This will get better result)
            )
        else:
            self.output_layer = nn.Sequential(
                nn.LayerNorm(self.hidden_size),
                nn.Dropout(dropout_rate),
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.LayerNorm(self.hidden_size),
                nn.GELU(),
                nn.Linear(self.hidden_size, 1),
            )

    def forward(self, input_ids, attention_mask):
        '''
        This method is designed for biLSTM/GRU/RNN. For LSTM/GRU/RNN for only one direction, just take hidden as the rnn output.
        RNN - hidden -> MLP --> outcome
        '''
        # embed the input
        embedded = self.embedding(input_ids)  # [batch_size, seq_length, embedding_dim]

        # feed forward
        output, hidden = self.rnn(embedded) # we don't need encoder so we only keep the output

        # make attention mask from [batch_size, seq_length] to [batch_size, seq_length, 1] as the same dimension as rnn
        attention_mask = attention_mask.unsqueeze(-1)  # [batch_size, seq_length, 1]

        # use attention mask to mask the output, ignore the padding embedding vector, only add the valid embedding vector
        masked_output = output * attention_mask

        # sum up all the valid output
        summed_output = masked_output.sum(dim=1)  # [batch_size, hidden_size]

        logits = self.output_layer(summed_output)

        return logits  # The output is [batch_size, 1]

# %%
# import datasets

train_df = pd.read_csv("train.csv").iloc[:,1:]
validation_df = pd.read_csv("validation.csv").iloc[:,1:]
test_df = pd.read_csv("test.csv").iloc[:,1:]

# %%
# try to use tokenizer api
tokenizer_no_sub.encode(["hello world", "how are you"], return_tensors = "pt") # insist to return pytorch
# Out:
# {'input_ids': tensor([[13077,    87,     0],
#          [  199,    34,    83]]),
#  'attention_mask': tensor([[1, 1, 0],
#          [1, 1, 1]])}

# %%
# Hyper paramaters
dropout_rate = 0.1
num_rnn_layer = 1
hidden_dim = 256

val_steps = 100 # compute validation error every n step

num_train_epochs = 3

batch_size = 32
lr = 8e-5
weight_decay = 1e-5


warmup_ratio=0.1
max_grad_norm = 2.0

# %%
# define dataset and data loader
class CustomizeDataset(Dataset):
    def __init__(
            self,
            df : pd.DataFrame
        ) -> None:
        super().__init__()
        self.df = df

    def __len__(self) -> int:
        return len(self.df)

    def __getitem__(
            self,
            index : int
        ) -> dict:

        inputs = self.df.iloc[index,0] # 0 is text
        label = self.df.iloc[index, 1] # 1 is label

        return {
            "input_str" : inputs, # output a string
            "label" : label # output a label
        }

# collater function (used for dynamic padding to save memory)
class Collater:
    def __init__(
            self,
            tokenizer_no_sub : GloveTokenizerNoSub
        ) -> None:
        self.tokenizer_no_sub = tokenizer_no_sub

    def __call__(
            self,
            instances : list # a list of string
        ) -> Any:
        # __call__ is for function-like object
        input_str_list = [instance["input_str"] for instance in instances]
        input_dict = tokenizer_no_sub.encode(input_str_list, return_tensors = "pt") # return pytorch tensor
        input_ids = input_dict["input_ids"]
        attention_mask = input_dict["attention_mask"]
        label = [torch.tensor(instance["label"], dtype = torch.int64) for instance in instances]

        return {
            "input_ids": input_ids,
            "label": torch.tensor(label),
            "attention_mask": attention_mask # mask the pad position
        }

# %%
# create dataset and data loader
collate_fn = Collater(tokenizer_no_sub)



train_ds = CustomizeDataset(
    df = train_df
)

train_loader = DataLoader(
    dataset = train_ds,
    batch_size = batch_size,
    collate_fn = collate_fn,
    shuffle = True
)

val_ds = CustomizeDataset(
    df = validation_df
)

val_loader = DataLoader(
    dataset = val_ds,
    batch_size = batch_size,
    collate_fn = collate_fn
)

test_ds = CustomizeDataset(
    df = test_df
)

test_loader = DataLoader(
    dataset = test_ds,
    batch_size = batch_size,
    collate_fn = collate_fn
)

# %%
# compute warmup status
num_training_steps = num_train_epochs * len(train_loader)
num_warmup_steps = int(num_training_steps * warmup_ratio)
print(f"train:{num_training_steps}, warm up: {num_warmup_steps}")
# Out:
# train:801, warm up: 80

# %%
# Set optimizer, loss_fn and so on

cls_model = SentimentRNN(
    embedding = embedding,
    hidden_size = hidden_dim,
    embed_size = EMBED_DIM,
    bidirectional = False, #  False for part 2
    num_rnn_layer = num_rnn_layer,
    dropout_rate = dropout_rate,
    layer_norm = True # set if you need layer norm
)

loss_fn = nn.BCEWithLogitsLoss()

optimizer = AdamW(
    params = cls_model.parameters(),
    lr = lr,
    weight_decay = weight_decay
)

scheduler  = get_cosine_schedule_with_warmup(
    optimizer = optimizer,
    num_warmup_steps = num_warmup_steps,
    num_training_steps = num_training_steps
)

# %%
# compute accuracy for wach data loader

def compute_accuracy(data_loader: DataLoader) -> float:

    cls_model.eval()

    correct = 0
    total = 0

    with torch.no_grad():
        for data in data_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)

            logits = cls_model(input_ids, attention_mask=attention_mask)

            predictions = (logits > 0).long()

            correct += (predictions == labels).sum().item()
            total += labels.size(0)

    accuracy = correct / total
    return accuracy

def compute_loss(data_loader: DataLoader) -> float:
    total_loss = 0
    cls_model.eval()
    with torch.no_grad():
        for data in data_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)

            logits = cls_model.forward(input_ids, attention_mask)
            loss = loss_fn.forward(
                input = logits,
                target = labels
            )

            total_loss += loss.detach().cpu()

        total_loss /= len(val_loader)

        return total_loss

# %%
def early_stopping(train_loss, validation_loss, min_delta, tolerance, counter):
    positive_diff = abs(validation_loss - train_loss)

    # Increment counter if no significant improvement
    if positive_diff >= min_delta:
        counter += 1
        if counter >= tolerance:
            return True, counter
    # Ensure the function always returns both values
    return False, counter

# %%
# Training loop

cls_model.to(device)

optimizer.zero_grad()

step = 0

train_losses = []

val_accs = []

val_losses = []

counter = 0

for epoch in range(num_train_epochs):

    # train loop
    for data in train_loader:
        cls_model.train()
        input_ids = data["input_ids"].to(device)
        attention_mask = data["attention_mask"].to(device)
        label = data["label"].view(-1, 1).float().to(device)

        logits = cls_model.forward(input_ids, attention_mask)


        loss = loss_fn.forward(
            input = logits,
            target = label
        )

        loss.backward()

        # Gradient clip (important for RNN, not necessary for LSTM/GRU/conv1d)
        torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)

        optimizer.step() # update paramater
        scheduler.step()
        optimizer.zero_grad() # clear gradient

        vis_loss = loss.detach().cpu()

        print(f"[{step + 1}/{num_training_steps}] train loss: [{vis_loss:.4f}] (epoch [{epoch + 1}/{num_train_epochs}])")


        train_losses.append(vis_loss)
        i =0

        if (step + 1) % val_steps == 0 or step == 0:
            # compute validation every "val_steps"

            cls_model.eval()
            val_loss = compute_loss(val_loader)
            val_acc = compute_accuracy(val_loader)
            val_accs.append(val_acc)
            val_losses.append(val_loss)

            print(f"[{step + 1}/{num_training_steps}] validation loss: [{val_loss:.4f}] validation accuracy: [{val_acc:.4f}]")
            # Apply early stopping
            should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.01, tolerance=2, counter=counter)
            if should_stop:
                print("Early stopping triggered.")
                break

        step += 1

    if should_stop:
        break  # Exit e
# Out:
# [1/801] train loss: [0.7338] (epoch [1/3])
# [1/801] validation loss: [0.7005] validation accuracy: [0.4981]
# [2/801] train loss: [0.7374] (epoch [1/3])
# [3/801] train loss: [0.7067] (epoch [1/3])
# [4/801] train loss: [0.7215] (epoch [1/3])
# [5/801] train loss: [0.6869] (epoch [1/3])
# [6/801] train loss: [0.6712] (epoch [1/3])
# [7/801] train loss: [0.6877] (epoch [1/3])
# [8/801] train loss: [0.7124] (epoch [1/3])
# [9/801] train loss: [0.6894] (epoch [1/3])
# [10/801] train loss: [0.6749] (epoch [1/3])
# [11/801] train loss: [0.6922] (epoch [1/3])
# [12/801] train loss: [0.6956] (epoch [1/3])
# [13/801] train loss: [0.7148] (epoch [1/3])
# [14/801] train loss: [0.7148] (epoch [1/3])
# [15/801] train loss: [0.6544] (epoch [1/3])
# [16/801] train loss: [0.7051] (epoch [1/3])
# [17/801] train loss: [0.6750] (epoch [1/3])
# [18/801] train loss: [0.6971] (epoch [1/3])
# [19/801] train loss: [0.7125] (epoch [1/3])
# [20/801] train loss: [0.7115] (epoch [1/3])
# [21/801] train loss: [0.6898] (epoch [1/3])
# [22/801] train loss: [0.6921] (epoch [1/3])
# [23/801] train loss: [0.6986] (epoch [1/3])
# [24/801] train loss: [0.6716] (epoch [1/3])
# [25/801] train loss: [0.6852] (epoch [1/3])
# [26/801] train loss: [0.7297] (epoch [1/3])
# [27/801] train loss: [0.7014] (epoch [1/3])
# [28/801] train loss: [0.6778] (epoch [1/3])
# [29/801] train loss: [0.7082] (epoch [1/3])
# [30/801] train loss: [0.6587] (epoch [1/3])
# [31/801] train loss: [0.6898] (epoch [1/3])
# [32/801] train loss: [0.6917] (epoch [1/3])
# [33/801] train loss: [0.6721] (epoch [1/3])
# [34/801] train loss: [0.7151] (epoch [1/3])
# [35/801] train loss: [0.7015] (epoch [1/3])
# [36/801] train loss: [0.6764] (epoch [1/3])
# [37/801] train loss: [0.7222] (epoch [1/3])
# [38/801] train loss: [0.6700] (epoch [1/3])
# [39/801] train loss: [0.6802] (epoch [1/3])
# [40/801] train loss: [0.7024] (epoch [1/3])
# [41/801] train loss: [0.6910] (epoch [1/3])
# [42/801] train loss: [0.7074] (epoch [1/3])
# [43/801] train loss: [0.6814] (epoch [1/3])
# [44/801] train loss: [0.6590] (epoch [1/3])
# [45/801] train loss: [0.6847] (epoch [1/3])
# [46/801] train loss: [0.6800] (epoch [1/3])
# [47/801] train loss: [0.6884] (epoch [1/3])
# [48/801] train loss: [0.6706] (epoch [1/3])
# [49/801] train loss: [0.6955] (epoch [1/3])
# [50/801] train loss: [0.7229] (epoch [1/3])
# [51/801] train loss: [0.6847] (epoch [1/3])
# [52/801] train loss: [0.6842] (epoch [1/3])
# [53/801] train loss: [0.6864] (epoch [1/3])
# [54/801] train loss: [0.6967] (epoch [1/3])
# [55/801] train loss: [0.6622] (epoch [1/3])
# [56/801] train loss: [0.6342] (epoch [1/3])
# [57/801] train loss: [0.6959] (epoch [1/3])
# [58/801] train loss: [0.6825] (epoch [1/3])
# [59/801] train loss: [0.7048] (epoch [1/3])
# [60/801] train loss: [0.7070] (epoch [1/3])
# [61/801] train loss: [0.6791] (epoch [1/3])
# [62/801] train loss: [0.6601] (epoch [1/3])
# [63/801] train loss: [0.6427] (epoch [1/3])
# [64/801] train loss: [0.6576] (epoch [1/3])
# [65/801] train loss: [0.6440] (epoch [1/3])
# [66/801] train loss: [0.6376] (epoch [1/3])
# [67/801] train loss: [0.6503] (epoch [1/3])
# [68/801] train loss: [0.6895] (epoch [1/3])
# [69/801] train loss: [0.6662] (epoch [1/3])
# [70/801] train loss: [0.6489] (epoch [1/3])
# [71/801] train loss: [0.6232] (epoch [1/3])
# [72/801] train loss: [0.6737] (epoch [1/3])
# [73/801] train loss: [0.6689] (epoch [1/3])
# [74/801] train loss: [0.6176] (epoch [1/3])
# [75/801] train loss: [0.6199] (epoch [1/3])
# [76/801] train loss: [0.6542] (epoch [1/3])
# [77/801] train loss: [0.6351] (epoch [1/3])
# [78/801] train loss: [0.6774] (epoch [1/3])
# [79/801] train loss: [0.6545] (epoch [1/3])
# [80/801] train loss: [0.6467] (epoch [1/3])
# [81/801] train loss: [0.6688] (epoch [1/3])
# [82/801] train loss: [0.6352] (epoch [1/3])
# [83/801] train loss: [0.6422] (epoch [1/3])
# [84/801] train loss: [0.6314] (epoch [1/3])
# [85/801] train loss: [0.6348] (epoch [1/3])
# [86/801] train loss: [0.6678] (epoch [1/3])
# [87/801] train loss: [0.6735] (epoch [1/3])
# [88/801] train loss: [0.6690] (epoch [1/3])
# [89/801] train loss: [0.6599] (epoch [1/3])
# [90/801] train loss: [0.6282] (epoch [1/3])
# [91/801] train loss: [0.6681] (epoch [1/3])
# [92/801] train loss: [0.6117] (epoch [1/3])
# [93/801] train loss: [0.6482] (epoch [1/3])
# [94/801] train loss: [0.6409] (epoch [1/3])
# [95/801] train loss: [0.6409] (epoch [1/3])
# [96/801] train loss: [0.6474] (epoch [1/3])
# [97/801] train loss: [0.6234] (epoch [1/3])
# [98/801] train loss: [0.6417] (epoch [1/3])
# [99/801] train loss: [0.6725] (epoch [1/3])
# [100/801] train loss: [0.6095] (epoch [1/3])
# [100/801] validation loss: [0.6167] validation accuracy: [0.6820]
# [101/801] train loss: [0.6758] (epoch [1/3])
# [102/801] train loss: [0.5831] (epoch [1/3])
# [103/801] train loss: [0.5768] (epoch [1/3])
# [104/801] train loss: [0.6665] (epoch [1/3])
# [105/801] train loss: [0.6987] (epoch [1/3])
# [106/801] train loss: [0.5476] (epoch [1/3])
# [107/801] train loss: [0.6198] (epoch [1/3])
# [108/801] train loss: [0.6618] (epoch [1/3])
# [109/801] train loss: [0.5465] (epoch [1/3])
# [110/801] train loss: [0.6355] (epoch [1/3])
# [111/801] train loss: [0.6520] (epoch [1/3])
# [112/801] train loss: [0.6691] (epoch [1/3])
# [113/801] train loss: [0.6844] (epoch [1/3])
# [114/801] train loss: [0.7804] (epoch [1/3])
# [115/801] train loss: [0.6027] (epoch [1/3])
# [116/801] train loss: [0.6769] (epoch [1/3])
# [117/801] train loss: [0.5308] (epoch [1/3])
# [118/801] train loss: [0.6250] (epoch [1/3])
# [119/801] train loss: [0.5687] (epoch [1/3])
# [120/801] train loss: [0.6620] (epoch [1/3])
# [121/801] train loss: [0.6149] (epoch [1/3])
# [122/801] train loss: [0.6127] (epoch [1/3])
# [123/801] train loss: [0.5662] (epoch [1/3])
# [124/801] train loss: [0.6219] (epoch [1/3])
# [125/801] train loss: [0.5821] (epoch [1/3])
# [126/801] train loss: [0.5196] (epoch [1/3])
# [127/801] train loss: [0.5614] (epoch [1/3])
# [128/801] train loss: [0.5844] (epoch [1/3])
# [129/801] train loss: [0.6994] (epoch [1/3])
# [130/801] train loss: [0.6919] (epoch [1/3])
# [131/801] train loss: [0.5043] (epoch [1/3])
# [132/801] train loss: [0.6136] (epoch [1/3])
# [133/801] train loss: [0.5782] (epoch [1/3])
# [134/801] train loss: [0.6682] (epoch [1/3])
# [135/801] train loss: [0.6204] (epoch [1/3])
# [136/801] train loss: [0.5507] (epoch [1/3])
# [137/801] train loss: [0.5216] (epoch [1/3])
# [138/801] train loss: [0.5391] (epoch [1/3])
# [139/801] train loss: [0.5468] (epoch [1/3])
# [140/801] train loss: [0.5245] (epoch [1/3])
# [141/801] train loss: [0.5869] (epoch [1/3])
# [142/801] train loss: [0.5254] (epoch [1/3])
# [143/801] train loss: [0.6835] (epoch [1/3])
# [144/801] train loss: [0.5581] (epoch [1/3])
# [145/801] train loss: [0.4676] (epoch [1/3])
# [146/801] train loss: [0.5389] (epoch [1/3])
# [147/801] train loss: [0.4707] (epoch [1/3])
# [148/801] train loss: [0.5436] (epoch [1/3])
# [149/801] train loss: [0.7562] (epoch [1/3])
# [150/801] train loss: [0.5929] (epoch [1/3])
# [151/801] train loss: [0.4990] (epoch [1/3])
# [152/801] train loss: [0.7163] (epoch [1/3])
# [153/801] train loss: [0.5085] (epoch [1/3])
# [154/801] train loss: [0.6566] (epoch [1/3])
# [155/801] train loss: [0.5149] (epoch [1/3])
# [156/801] train loss: [0.4400] (epoch [1/3])
# [157/801] train loss: [0.5944] (epoch [1/3])
# [158/801] train loss: [0.4645] (epoch [1/3])
# [159/801] train loss: [0.5764] (epoch [1/3])
# [160/801] train loss: [0.5342] (epoch [1/3])
# [161/801] train loss: [0.6632] (epoch [1/3])
# [162/801] train loss: [0.4933] (epoch [1/3])
# [163/801] train loss: [0.5918] (epoch [1/3])
# [164/801] train loss: [0.6764] (epoch [1/3])
# [165/801] train loss: [0.5414] (epoch [1/3])
# [166/801] train loss: [0.6048] (epoch [1/3])
# [167/801] train loss: [0.6152] (epoch [1/3])
# [168/801] train loss: [0.5492] (epoch [1/3])
# [169/801] train loss: [0.5091] (epoch [1/3])
# [170/801] train loss: [0.6150] (epoch [1/3])
# [171/801] train loss: [0.6115] (epoch [1/3])
# [172/801] train loss: [0.5887] (epoch [1/3])
# [173/801] train loss: [0.5646] (epoch [1/3])
# [174/801] train loss: [0.6354] (epoch [1/3])
# [175/801] train loss: [0.5086] (epoch [1/3])
# [176/801] train loss: [0.5802] (epoch [1/3])
# [177/801] train loss: [0.6359] (epoch [1/3])
# [178/801] train loss: [0.5187] (epoch [1/3])
# [179/801] train loss: [0.7028] (epoch [1/3])
# [180/801] train loss: [0.6484] (epoch [1/3])
# [181/801] train loss: [0.4565] (epoch [1/3])
# [182/801] train loss: [0.5375] (epoch [1/3])
# [183/801] train loss: [0.6874] (epoch [1/3])
# [184/801] train loss: [0.6597] (epoch [1/3])
# [185/801] train loss: [0.5991] (epoch [1/3])
# [186/801] train loss: [0.5444] (epoch [1/3])
# [187/801] train loss: [0.5445] (epoch [1/3])
# [188/801] train loss: [0.5450] (epoch [1/3])
# [189/801] train loss: [0.6373] (epoch [1/3])
# [190/801] train loss: [0.6019] (epoch [1/3])
# [191/801] train loss: [0.4749] (epoch [1/3])
# [192/801] train loss: [0.5011] (epoch [1/3])
# [193/801] train loss: [0.5724] (epoch [1/3])
# [194/801] train loss: [0.5465] (epoch [1/3])
# [195/801] train loss: [0.6707] (epoch [1/3])
# [196/801] train loss: [0.6371] (epoch [1/3])
# [197/801] train loss: [0.5757] (epoch [1/3])
# [198/801] train loss: [0.6734] (epoch [1/3])
# [199/801] train loss: [0.6001] (epoch [1/3])
# [200/801] train loss: [0.7021] (epoch [1/3])
# [200/801] validation loss: [0.6088] validation accuracy: [0.6660]
# Early stopping triggered.

# %%
# Test the model
# Define hyperparameter ranges
param_grid = {
    "num_rnn_layer": range(1, 2),  # Integer range for number of RNN layers
    "hidden_dim": [128, 256],  # Integer range for hidden dimension size
    "dropout_rate": [0.1, 0.2],  # Continuous range for dropout rate
    "learning_rate": [1e-4, 1e-3],  # Continuous range for learning rate
    "batch_size": [128, 256],  # Integer range for batch size
    "max_grad_norm": [1.0, 2.0],  # Continuous range for gradient clipping
    "num_train_epochs": [1,2,3]  # Integer range for number of training epochs
}

# Track the best configuration
best_val_loss = float('inf')
best_val_accuracy = 0.0
best_params = None

# Generate all combinations of hyperparameters
for params in itertools.product(
    param_grid["num_rnn_layer"],
    param_grid["hidden_dim"],
    param_grid["dropout_rate"],
    param_grid["learning_rate"],
    param_grid["batch_size"],
    param_grid["max_grad_norm"],
    param_grid["num_train_epochs"]
):
    # Unpack hyperparameters
    num_rnn_layer, hidden_dim, dropout_rate, learning_rate, batch_size, max_grad_norm, num_train_epochs = params

    # Initialize model with current parameters
    cls_model = SentimentRNN(
        embedding=embedding,
        hidden_size=hidden_dim,
        embed_size=EMBED_DIM,
        bidirectional=False,
        num_rnn_layer=num_rnn_layer,
        dropout_rate=dropout_rate,
        layer_norm=True
    ).to(device)

    # Set up optimizer and scheduler
    optimizer = torch.optim.Adam(cls_model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

    # DataLoader for selected batch size
    train_loader = DataLoader(
        dataset=train_ds,
        batch_size=batch_size,
        collate_fn=collate_fn,
        shuffle=True
    )

    # Early stopping and metrics tracking variables
    counter = 0
    step = 0
    train_losses = []
    val_losses = []
    val_accs = []
    should_stop = False
    early_stopped = False  # Flag to indicate early stopping for this trial

    for epoch in range(num_train_epochs):
        # Training loop
        for data in train_loader:
            cls_model.train()
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            label = data["label"].view(-1, 1).float().to(device)

            logits = cls_model(input_ids, attention_mask)

            loss = loss_fn(input=logits, target=label)
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)

            optimizer.step()
            scheduler.step()
            optimizer.zero_grad()

            vis_loss = loss.detach().cpu().item()
            train_losses.append(vis_loss)

            # Validation step every `val_steps`
            if (step + 1) % val_steps == 0 or step == 0:
                cls_model.eval()
                val_loss = compute_loss(val_loader)
                val_acc = compute_accuracy(val_loader)
                val_losses.append(val_loss)
                val_accs.append(val_acc)

                # Early stopping check
                should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.5, tolerance=2, counter=counter)
                if should_stop:
                    print("Early stopping triggered.")
                    early_stopped = True  # Mark this trial as early stopped
                    break

            step += 1

        if should_stop:
            break  # Exit epoch loop if early stopping is triggered

    # Track the best parameters and validation loss
    current_val_loss = val_losses[-1] if val_losses else float('inf')
    current_val_accuracy = val_accs[-1] if val_accs else 0.0
    if current_val_accuracy > best_val_accuracy and early_stopped==False:
        best_val_loss = current_val_loss
        best_val_accuracy = current_val_accuracy
        best_params = params

    # Print the trial's results, including early stopping info
    print(f"Trial with params: {params}")
    print(f"  Validation Loss: {current_val_loss}")
    print(f"  Validation Accuracy: {current_val_accuracy}")
    if early_stopped:
        print("  Early stopped")


# Print the best result
print("Best result:")
print(f"  Validation Loss: {best_val_loss}")
print(f"  Validation Accuracy: {best_val_accuracy}")
print("  Best hyperparameters:", best_params)
# Out:
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.699918806552887
#   Validation Accuracy: 0.45684803001876173
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.683329164981842
#   Validation Accuracy: 0.5947467166979362
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6836188435554504
#   Validation Accuracy: 0.5684803001876173
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.6964043378829956
#   Validation Accuracy: 0.5131332082551595
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6897128224372864
#   Validation Accuracy: 0.5525328330206379
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.678541898727417
#   Validation Accuracy: 0.5919324577861164
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6927042603492737
#   Validation Accuracy: 0.5215759849906192
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6950530409812927
#   Validation Accuracy: 0.5093808630393997
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6833313703536987
#   Validation Accuracy: 0.5590994371482176
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.7254899144172668
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6895918846130371
#   Validation Accuracy: 0.5187617260787992
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6827622056007385
#   Validation Accuracy: 0.5600375234521576
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.7782064080238342
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6637128591537476
#   Validation Accuracy: 0.6472795497185742
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6618447303771973
#   Validation Accuracy: 0.6735459662288931
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.7757417559623718
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.6314659118652344
#   Validation Accuracy: 0.6435272045028143
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6496176719665527
#   Validation Accuracy: 0.6529080675422139
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.7170251607894897
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.7784656286239624
#   Validation Accuracy: 0.5028142589118199
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6368222236633301
#   Validation Accuracy: 0.6575984990619137
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.7769090533256531
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.6799095869064331
#   Validation Accuracy: 0.5703564727954972
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6408925652503967
#   Validation Accuracy: 0.6566604127579737
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.6916186213493347
#   Validation Accuracy: 0.5384615384615384
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6903137564659119
#   Validation Accuracy: 0.5121951219512195
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6917794346809387
#   Validation Accuracy: 0.525328330206379
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.7301917672157288
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.689975917339325
#   Validation Accuracy: 0.5581613508442776
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6843012571334839
#   Validation Accuracy: 0.5816135084427767
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6963174343109131
#   Validation Accuracy: 0.48592870544090055
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.7122203707695007
#   Validation Accuracy: 0.4971857410881801
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.682903528213501
#   Validation Accuracy: 0.5712945590994372
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.6909768581390381
#   Validation Accuracy: 0.5140712945590994
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6976605653762817
#   Validation Accuracy: 0.4981238273921201
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.689972996711731
#   Validation Accuracy: 0.5262664165103189
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.736881673336029
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6657097339630127
#   Validation Accuracy: 0.6472795497185742
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6728182435035706
#   Validation Accuracy: 0.5872420262664165
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.7108119130134583
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.6623649001121521
#   Validation Accuracy: 0.6444652908067542
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6344977021217346
#   Validation Accuracy: 0.6641651031894934
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.7968491911888123
#   Validation Accuracy: 0.4981238273921201
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.7650420665740967
#   Validation Accuracy: 0.49624765478424016
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6426264047622681
#   Validation Accuracy: 0.651031894934334
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.731223464012146
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.742504894733429
#   Validation Accuracy: 0.49437148217636023
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6614255905151367
#   Validation Accuracy: 0.6435272045028143
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.6873793601989746
#   Validation Accuracy: 0.5525328330206379
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6731163263320923
#   Validation Accuracy: 0.6050656660412758
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6704829335212708
#   Validation Accuracy: 0.6191369606003753
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.7043135762214661
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6634766459465027
#   Validation Accuracy: 0.6463414634146342
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6772215366363525
#   Validation Accuracy: 0.5909943714821764
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6935598254203796
#   Validation Accuracy: 0.5056285178236398
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6964669823646545
#   Validation Accuracy: 0.47842401500938087
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.665800154209137
#   Validation Accuracy: 0.6313320825515948
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.7007243633270264
#   Validation Accuracy: 0.46810506566604126
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6896045804023743
#   Validation Accuracy: 0.5168855534709194
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.66603684425354
#   Validation Accuracy: 0.6463414634146342
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 1)
#   Validation Loss: 1.118338942527771
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6700277924537659
#   Validation Accuracy: 0.649155722326454
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.604423463344574
#   Validation Accuracy: 0.6838649155722326
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.8968330025672913
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.6431703567504883
#   Validation Accuracy: 0.6454033771106942
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6741506457328796
#   Validation Accuracy: 0.6350844277673546
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 1)
#   Validation Loss: 1.2496874332427979
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.8765833973884583
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6171764731407166
#   Validation Accuracy: 0.6697936210131332
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 1)
#   Validation Loss: 1.1807799339294434
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 2)
#   Validation Loss: 1.1820673942565918
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6389611959457397
#   Validation Accuracy: 0.6594746716697936
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.687699019908905
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6711669564247131
#   Validation Accuracy: 0.6088180112570356
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6656671166419983
#   Validation Accuracy: 0.6322701688555347
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.6960154175758362
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6648924946784973
#   Validation Accuracy: 0.6369606003752345
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6731141209602356
#   Validation Accuracy: 0.6031894934333959
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6988641023635864
#   Validation Accuracy: 0.48592870544090055
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.7075183987617493
#   Validation Accuracy: 0.4971857410881801
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6602259278297424
#   Validation Accuracy: 0.6407129455909943
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.692946195602417
#   Validation Accuracy: 0.5347091932457786
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6951368451118469
#   Validation Accuracy: 0.4906191369606004
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6693031787872314
#   Validation Accuracy: 0.6088180112570356
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 1)
#   Validation Loss: 1.1343531608581543
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6412654519081116
#   Validation Accuracy: 0.6594746716697936
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6733196377754211
#   Validation Accuracy: 0.6416510318949343
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 1)
#   Validation Loss: 1.1483895778656006
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.6828227043151855
#   Validation Accuracy: 0.5872420262664165
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6401177644729614
#   Validation Accuracy: 0.6538461538461539
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.9762182831764221
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 2)
#   Validation Loss: 1.1789242029190063
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6416166424751282
#   Validation Accuracy: 0.649155722326454
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 1)
#   Validation Loss: 1.1689887046813965
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 2)
#   Validation Loss: 1.2989987134933472
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6443459987640381
#   Validation Accuracy: 0.6529080675422139
# Best result:
#   Validation Loss: 0.604423463344574
#   Validation Accuracy: 0.6838649155722326
#   Best hyperparameters: (1, 256, 0.1, 0.001, 128, 1.0, 3)

# %%
#result of the best parameters ("num_rnn_layer", "hidden_dim", "dropout_rate", "learning_rate", "batch_size", "max_grad_norm", "num_train_epochs")
print({best_val_loss})
print({best_val_accuracy})
print(best_params)
# Out:
# {tensor(0.6044)}
# {0.6838649155722326}
# (1, 256, 0.1, 0.001, 128, 1.0, 3)

# %%
val_steps = 100
batch_size = 128
dropout_rate = 0.2
hidden_dim = 258
learning_rate = 0.001
num_rnn_layer = 1
max_grad_norm = 2.0
num_train_epochs = 3

num_training_steps = num_train_epochs * len(train_loader)
num_warmup_steps = int(num_training_steps * warmup_ratio)
print(f"train:{num_training_steps}, warm up: {num_warmup_steps}")
# Out:
# train:102, warm up: 10

# %%
cls_model = SentimentRNN(
    embedding=embedding,
    hidden_size=hidden_dim,
    embed_size=EMBED_DIM,
    bidirectional=False,  # False for part 2
    num_rnn_layer=num_rnn_layer,
    dropout_rate=dropout_rate,
    layer_norm=True
).to(device)
# Set up optimizer and scheduler
optimizer = torch.optim.Adam(cls_model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

train_loader = DataLoader(
    dataset=train_ds,
    batch_size=batch_size,
    collate_fn=collate_fn,
    shuffle=True
)

optimizer.zero_grad()

step = 0

train_losses = []

val_accs = []

val_losses = []

counter = 0

for epoch in range(num_train_epochs):

    # train loop
    for data in train_loader:
        cls_model.train()
        input_ids = data["input_ids"].to(device)
        attention_mask = data["attention_mask"].to(device)
        label = data["label"].view(-1, 1).float().to(device)

        logits = cls_model.forward(input_ids, attention_mask)


        loss = loss_fn.forward(
            input = logits,
            target = label
        )

        loss.backward()

        # Gradient clip (important for RNN, not necessary for LSTM/GRU/conv1d)
        torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)

        optimizer.step() # update paramater
        scheduler.step()
        optimizer.zero_grad() # clear gradient

        vis_loss = loss.detach().cpu()

        print(f"[{step + 1}/{num_training_steps}] train loss: [{vis_loss:.4f}] (epoch [{epoch + 1}/{num_train_epochs}])")


        train_losses.append(vis_loss)
        i =0

        if (step + 1) % val_steps == 0 or step == 0:
            # compute validation every "val_steps"

            cls_model.eval()
            val_loss = compute_loss(val_loader)
            val_acc = compute_accuracy(val_loader)
            val_accs.append(val_acc)
            val_losses.append(val_loss)

            print(f"[{step + 1}/{num_training_steps}] validation loss: [{val_loss:.4f}] validation accuracy: [{val_acc:.4f}]")
            # Apply early stopping
            should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.5, tolerance=2, counter=counter)
            if should_stop:
                print("Early stopping triggered.")
                break

        step += 1

    if should_stop:
        break  # Exit e
# Out:
# [1/102] train loss: [0.7050] (epoch [1/3])
# [1/102] validation loss: [1.1062] validation accuracy: [0.5000]
# [2/102] train loss: [1.1902] (epoch [1/3])
# [3/102] train loss: [0.6887] (epoch [1/3])
# [4/102] train loss: [0.7529] (epoch [1/3])
# [5/102] train loss: [0.7401] (epoch [1/3])
# [6/102] train loss: [0.6949] (epoch [1/3])
# [7/102] train loss: [0.6925] (epoch [1/3])
# [8/102] train loss: [0.6882] (epoch [1/3])
# [9/102] train loss: [0.6640] (epoch [1/3])
# [10/102] train loss: [0.6783] (epoch [1/3])
# [11/102] train loss: [0.6798] (epoch [1/3])
# [12/102] train loss: [0.6753] (epoch [1/3])
# [13/102] train loss: [0.6762] (epoch [1/3])
# [14/102] train loss: [0.6718] (epoch [1/3])
# [15/102] train loss: [0.6641] (epoch [1/3])
# [16/102] train loss: [0.6641] (epoch [1/3])
# [17/102] train loss: [0.6987] (epoch [1/3])
# [18/102] train loss: [0.6799] (epoch [1/3])
# [19/102] train loss: [0.6644] (epoch [1/3])
# [20/102] train loss: [0.6811] (epoch [1/3])
# [21/102] train loss: [0.6701] (epoch [1/3])
# [22/102] train loss: [0.6690] (epoch [1/3])
# [23/102] train loss: [0.6589] (epoch [1/3])
# [24/102] train loss: [0.6684] (epoch [1/3])
# [25/102] train loss: [0.6749] (epoch [1/3])
# [26/102] train loss: [0.6693] (epoch [1/3])
# [27/102] train loss: [0.6608] (epoch [1/3])
# [28/102] train loss: [0.6597] (epoch [1/3])
# [29/102] train loss: [0.6448] (epoch [1/3])
# [30/102] train loss: [0.6510] (epoch [1/3])
# [31/102] train loss: [0.6462] (epoch [1/3])
# [32/102] train loss: [0.6676] (epoch [1/3])
# [33/102] train loss: [0.6732] (epoch [1/3])
# [34/102] train loss: [0.6540] (epoch [1/3])
# [35/102] train loss: [0.6690] (epoch [1/3])
# [36/102] train loss: [0.6596] (epoch [1/3])
# [37/102] train loss: [0.6334] (epoch [1/3])
# [38/102] train loss: [0.6565] (epoch [1/3])
# [39/102] train loss: [0.6593] (epoch [1/3])
# [40/102] train loss: [0.6491] (epoch [1/3])
# [41/102] train loss: [0.6471] (epoch [1/3])
# [42/102] train loss: [0.6632] (epoch [1/3])
# [43/102] train loss: [0.6456] (epoch [1/3])
# [44/102] train loss: [0.6660] (epoch [1/3])
# [45/102] train loss: [0.6386] (epoch [1/3])
# [46/102] train loss: [0.6495] (epoch [1/3])
# [47/102] train loss: [0.6453] (epoch [1/3])
# [48/102] train loss: [0.6693] (epoch [1/3])
# [49/102] train loss: [0.6387] (epoch [1/3])
# [50/102] train loss: [0.6538] (epoch [1/3])
# [51/102] train loss: [0.6536] (epoch [1/3])
# [52/102] train loss: [0.6477] (epoch [1/3])
# [53/102] train loss: [0.6417] (epoch [1/3])
# [54/102] train loss: [0.6499] (epoch [1/3])
# [55/102] train loss: [0.6596] (epoch [1/3])
# [56/102] train loss: [0.6349] (epoch [1/3])
# [57/102] train loss: [0.6541] (epoch [1/3])
# [58/102] train loss: [0.6487] (epoch [1/3])
# [59/102] train loss: [0.6611] (epoch [1/3])
# [60/102] train loss: [0.6337] (epoch [1/3])
# [61/102] train loss: [0.6546] (epoch [1/3])
# [62/102] train loss: [0.6664] (epoch [1/3])
# [63/102] train loss: [0.6532] (epoch [1/3])
# [64/102] train loss: [0.6543] (epoch [1/3])
# [65/102] train loss: [0.6536] (epoch [1/3])
# [66/102] train loss: [0.6496] (epoch [1/3])
# [67/102] train loss: [0.6479] (epoch [1/3])
# [68/102] train loss: [0.6494] (epoch [2/3])
# [69/102] train loss: [0.6549] (epoch [2/3])
# [70/102] train loss: [0.6360] (epoch [2/3])
# [71/102] train loss: [0.6447] (epoch [2/3])
# [72/102] train loss: [0.6432] (epoch [2/3])
# [73/102] train loss: [0.6458] (epoch [2/3])
# [74/102] train loss: [0.6431] (epoch [2/3])
# [75/102] train loss: [0.6368] (epoch [2/3])
# [76/102] train loss: [0.6553] (epoch [2/3])
# [77/102] train loss: [0.6436] (epoch [2/3])
# [78/102] train loss: [0.6550] (epoch [2/3])
# [79/102] train loss: [0.6467] (epoch [2/3])
# [80/102] train loss: [0.6590] (epoch [2/3])
# [81/102] train loss: [0.6495] (epoch [2/3])
# [82/102] train loss: [0.6591] (epoch [2/3])
# [83/102] train loss: [0.6642] (epoch [2/3])
# [84/102] train loss: [0.6583] (epoch [2/3])
# [85/102] train loss: [0.6571] (epoch [2/3])
# [86/102] train loss: [0.6282] (epoch [2/3])
# [87/102] train loss: [0.6370] (epoch [2/3])
# [88/102] train loss: [0.6441] (epoch [2/3])
# [89/102] train loss: [0.6477] (epoch [2/3])
# [90/102] train loss: [0.6518] (epoch [2/3])
# [91/102] train loss: [0.6445] (epoch [2/3])
# [92/102] train loss: [0.6459] (epoch [2/3])
# [93/102] train loss: [0.6566] (epoch [2/3])
# [94/102] train loss: [0.6428] (epoch [2/3])
# [95/102] train loss: [0.6695] (epoch [2/3])
# [96/102] train loss: [0.6629] (epoch [2/3])
# [97/102] train loss: [0.6370] (epoch [2/3])
# [98/102] train loss: [0.6530] (epoch [2/3])
# [99/102] train loss: [0.6446] (epoch [2/3])
# [100/102] train loss: [0.6400] (epoch [2/3])
# [100/102] validation loss: [0.6487] validation accuracy: [0.6651]
# [101/102] train loss: [0.6499] (epoch [2/3])
# [102/102] train loss: [0.6271] (epoch [2/3])
# [103/102] train loss: [0.6571] (epoch [2/3])
# [104/102] train loss: [0.6567] (epoch [2/3])
# [105/102] train loss: [0.6574] (epoch [2/3])
# [106/102] train loss: [0.6573] (epoch [2/3])
# [107/102] train loss: [0.6486] (epoch [2/3])
# [108/102] train loss: [0.6484] (epoch [2/3])
# [109/102] train loss: [0.6631] (epoch [2/3])
# [110/102] train loss: [0.6521] (epoch [2/3])
# [111/102] train loss: [0.6449] (epoch [2/3])
# [112/102] train loss: [0.6421] (epoch [2/3])
# [113/102] train loss: [0.6673] (epoch [2/3])
# [114/102] train loss: [0.6231] (epoch [2/3])
# [115/102] train loss: [0.6621] (epoch [2/3])
# [116/102] train loss: [0.6646] (epoch [2/3])
# [117/102] train loss: [0.6404] (epoch [2/3])
# [118/102] train loss: [0.6327] (epoch [2/3])
# [119/102] train loss: [0.6466] (epoch [2/3])
# [120/102] train loss: [0.6434] (epoch [2/3])
# [121/102] train loss: [0.6394] (epoch [2/3])
# [122/102] train loss: [0.6540] (epoch [2/3])
# [123/102] train loss: [0.6300] (epoch [2/3])
# [124/102] train loss: [0.6491] (epoch [2/3])
# [125/102] train loss: [0.6596] (epoch [2/3])
# [126/102] train loss: [0.6439] (epoch [2/3])
# [127/102] train loss: [0.6396] (epoch [2/3])
# [128/102] train loss: [0.6538] (epoch [2/3])
# [129/102] train loss: [0.6630] (epoch [2/3])
# [130/102] train loss: [0.6376] (epoch [2/3])
# [131/102] train loss: [0.6568] (epoch [2/3])
# [132/102] train loss: [0.6697] (epoch [2/3])
# [133/102] train loss: [0.6694] (epoch [2/3])
# [134/102] train loss: [0.6372] (epoch [2/3])
# [135/102] train loss: [0.6648] (epoch [3/3])
# [136/102] train loss: [0.6485] (epoch [3/3])
# [137/102] train loss: [0.6634] (epoch [3/3])
# [138/102] train loss: [0.6694] (epoch [3/3])
# [139/102] train loss: [0.6472] (epoch [3/3])
# [140/102] train loss: [0.6401] (epoch [3/3])
# [141/102] train loss: [0.6521] (epoch [3/3])
# [142/102] train loss: [0.6566] (epoch [3/3])
# [143/102] train loss: [0.6551] (epoch [3/3])
# [144/102] train loss: [0.6474] (epoch [3/3])
# [145/102] train loss: [0.6365] (epoch [3/3])
# [146/102] train loss: [0.6453] (epoch [3/3])
# [147/102] train loss: [0.6511] (epoch [3/3])
# [148/102] train loss: [0.6561] (epoch [3/3])
# [149/102] train loss: [0.6548] (epoch [3/3])
# [150/102] train loss: [0.6311] (epoch [3/3])
# [151/102] train loss: [0.6410] (epoch [3/3])
# [152/102] train loss: [0.6462] (epoch [3/3])
# [153/102] train loss: [0.6483] (epoch [3/3])
# [154/102] train loss: [0.6481] (epoch [3/3])
# [155/102] train loss: [0.6697] (epoch [3/3])
# [156/102] train loss: [0.6639] (epoch [3/3])
# [157/102] train loss: [0.6559] (epoch [3/3])
# [158/102] train loss: [0.6610] (epoch [3/3])
# [159/102] train loss: [0.6483] (epoch [3/3])
# [160/102] train loss: [0.6516] (epoch [3/3])
# [161/102] train loss: [0.6684] (epoch [3/3])
# [162/102] train loss: [0.6541] (epoch [3/3])
# [163/102] train loss: [0.6610] (epoch [3/3])
# [164/102] train loss: [0.6362] (epoch [3/3])
# [165/102] train loss: [0.6408] (epoch [3/3])
# [166/102] train loss: [0.6616] (epoch [3/3])
# [167/102] train loss: [0.6546] (epoch [3/3])
# [168/102] train loss: [0.6509] (epoch [3/3])
# [169/102] train loss: [0.6606] (epoch [3/3])
# [170/102] train loss: [0.6340] (epoch [3/3])
# [171/102] train loss: [0.6550] (epoch [3/3])
# [172/102] train loss: [0.6411] (epoch [3/3])
# [173/102] train loss: [0.6638] (epoch [3/3])
# [174/102] train loss: [0.6595] (epoch [3/3])
# [175/102] train loss: [0.6521] (epoch [3/3])
# [176/102] train loss: [0.6497] (epoch [3/3])
# [177/102] train loss: [0.6571] (epoch [3/3])
# [178/102] train loss: [0.6403] (epoch [3/3])
# [179/102] train loss: [0.6487] (epoch [3/3])
# [180/102] train loss: [0.6446] (epoch [3/3])
# [181/102] train loss: [0.6475] (epoch [3/3])
# [182/102] train loss: [0.6410] (epoch [3/3])
# [183/102] train loss: [0.6561] (epoch [3/3])
# [184/102] train loss: [0.6659] (epoch [3/3])
# [185/102] train loss: [0.6327] (epoch [3/3])
# [186/102] train loss: [0.6495] (epoch [3/3])
# [187/102] train loss: [0.6521] (epoch [3/3])
# [188/102] train loss: [0.6280] (epoch [3/3])
# [189/102] train loss: [0.6462] (epoch [3/3])
# [190/102] train loss: [0.6651] (epoch [3/3])
# [191/102] train loss: [0.6604] (epoch [3/3])
# [192/102] train loss: [0.6515] (epoch [3/3])
# [193/102] train loss: [0.6431] (epoch [3/3])
# [194/102] train loss: [0.6590] (epoch [3/3])
# [195/102] train loss: [0.6535] (epoch [3/3])
# [196/102] train loss: [0.6444] (epoch [3/3])
# [197/102] train loss: [0.6435] (epoch [3/3])
# [198/102] train loss: [0.6410] (epoch [3/3])
# [199/102] train loss: [0.6201] (epoch [3/3])
# [200/102] train loss: [0.6537] (epoch [3/3])
# [200/102] validation loss: [0.6487] validation accuracy: [0.6651]
# [201/102] train loss: [0.6237] (epoch [3/3])

# %%
train_loss = compute_loss(train_loader)
train_acc = compute_accuracy(train_loader)
test_loss = compute_loss(test_loader)
test_acc = compute_accuracy(test_loader)
val_loss = compute_loss(val_loader)
test_acc = compute_accuracy(test_loader)

print(f"Train Loss: [{train_loss:.4f}]\nTrain accuracy: [{train_acc:.4f}]")
print(f"Test Loss: [{test_loss:.4f}]\nTest accuracy: [{test_acc:.4f}]")
print(f"Validation Loss: [{val_loss:.4f}]\nValidation accuracy: [{val_acc:.4f}]")
print(val_steps)
print(val_losses)
# Out:
# Train Loss: [1.2733]
# Train accuracy: [0.6637]
# Test Loss: [0.6508]
# Test accuracy: [0.6492]
# Validation Loss: [0.6487]
# Validation accuracy: [0.6651]
# [0, 10, 20]
# [tensor(1.1062), tensor(0.6487), tensor(0.6487)]

# %%
# Set validation steps to match the indices in val_losses
val_steps = [i * 100 for i in range(len(val_losses))]

# Subplots for training and vlidation loss & validation accuracy (updated for each epoch)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot Training and Validation Loss subplot
ax1.plot(train_losses, label='Training Loss', marker='x')
ax1.plot(val_steps, val_losses, label='Validation Loss', marker='o')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Training Steps')
ax1.set_ylabel('Loss')
ax1.grid(True)
ax1.legend()

# Plot Validation Accuracy subplot
ax2.plot(val_steps, val_accs, label='Validation Accuracy', marker='x')
ax2.set_title('Validation Accuracy')
ax2.set_xlabel('Training Steps')
ax2.set_ylabel('Accuracy')
ax2.grid(True)
ax2.legend()

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# compute predictions and labels for confusion matrix computing
def compute_pedictions_and_labels(
        model : nn.Module,
        test_loader : DataLoader,
        device : torch.device
    ) -> tuple:

    model.to(device)

    model.eval()

    # Lists to store all predictions and actual labels
    all_predictions = []
    all_labels = []

    with torch.no_grad():
        for data in test_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)

            logits = model(input_ids, attention_mask=attention_mask)

            predictions = (logits > 0).long()

            all_predictions.extend(predictions.view(-1).cpu().numpy())
            all_labels.extend(labels.view(-1).cpu().numpy())

    return all_predictions, all_labels

all_predictions, all_labels = compute_pedictions_and_labels(cls_model, test_loader, device)

# %%
def plot_f1_score(
        all_predictions : list,
        all_labels : list
    ) -> None:
    f1 = f1_score(all_labels, all_predictions)
    print("F1 Score: ", f1)

plot_f1_score(all_predictions, all_labels)
# Out:
# F1 Score:  0.6417624521072797

# %%
def accuracyscore(
      all_predictions: list,
      all_labels: list
    ) -> float:
    correct_predicts = sum([1 for pred, label in zip(all_predictions, all_labels) if pred == label])
    accuracy = correct_predicts / len(all_labels)
    return accuracy

print("Accuracy Score: ",accuracyscore(all_predictions, all_labels))
# Out:
# Accuracy Score:  0.649155722326454

# %%
# visualization 2: confusion matrix

def plot_confusion(
        all_predictions : list,
        all_labels : list
    ) -> None:

    cm = confusion_matrix(all_labels, all_predictions) # from sklearn

    plt.figure(figsize=(6,4))
    sns.heatmap(cm, annot=True, fmt='d', linewidths=0.2, cmap="YlGnBu", cbar=False)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.xticks([0.5, 1.5], ['Negative', 'Positive'])
    plt.yticks([0.5, 1.5], ['Negative', 'Positive'], va='center')
    plt.show()

plot_confusion(all_predictions, all_labels)
