# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
GLOVE_PATH = "glove.6B.100d.txt" # change to your path
EMBED_DIM = 100 # No need to change

# %%
# !pip install unidecode
from transformers import get_cosine_schedule_with_warmup
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import AdamW
from torch.utils.data import DataLoader, Dataset
import matplotlib as mpl
import matplotlib.pyplot as plt
from tensorflow import keras
import pandas as pd
import numpy as np
import random
from sklearn.metrics import confusion_matrix, f1_score, f1_score, roc_curve, auc, precision_recall_curve, average_precision_score
import seaborn as sns
from Embeddings import GloveEmbedding, GloveTokenizerNoSub
import itertools
import torch
from torch.utils.data import DataLoader
from typing import Any
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import copy
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.8)

# %%
# set seeds
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(114514)

# %%
# import tokenizer
tokenizer_no_sub = GloveTokenizerNoSub(glove_file_path=GLOVE_PATH)
embedding = GloveEmbedding(
    glove_file_path = GLOVE_PATH,
    trainable = False # False for part 2 to disable the Embedding training
)

# %%
class SentimentRNN(nn.Module):
    def __init__(self, embedding, hidden_size, embed_size, bidirectional, num_rnn_layer, dropout_rate, layer_norm):
        super(SentimentRNN, self).__init__()
        self.embedding = embedding  # pass pretrained embedding in
        self.bidirectional = bidirectional
        self.rnn = nn.RNN(embed_size, hidden_size, batch_first=True, num_layers = num_rnn_layer, bidirectional=bidirectional, dropout = dropout_rate if num_rnn_layer > 1 else 0)

        # if bidirectional, the output hidden size is double
        self.hidden_size = hidden_size * 2 if bidirectional else hidden_size

        # MLP
        if not layer_norm:
            self.output_layer = nn.Sequential(
                nn.Dropout(dropout_rate),
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.GELU(),
                nn.Linear(self.hidden_size, 1),  # output dimension is 1 (sigmoid is in BCELossWithLogits, so no sigmoid here. This will get better result)
            )
        else:
            self.output_layer = nn.Sequential(
                nn.LayerNorm(self.hidden_size),
                nn.Dropout(dropout_rate),
                nn.Linear(self.hidden_size, self.hidden_size),
                nn.LayerNorm(self.hidden_size),
                nn.GELU(),
                nn.Linear(self.hidden_size, 1),
            )

    def forward(self, input_ids, attention_mask):
        '''
        This method is designed for biLSTM/GRU/RNN. For LSTM/GRU/RNN for only one direction, just take hidden as the rnn output.
        RNN - hidden -> MLP --> outcome
        '''
        # embed the input
        embedded = self.embedding(input_ids)  # [batch_size, seq_length, embedding_dim]

        # feed forward
        output, hidden = self.rnn(embedded) # we don't need encoder so we only keep the output

        # make attention mask from [batch_size, seq_length] to [batch_size, seq_length, 1] as the same dimension as rnn
        attention_mask = attention_mask.unsqueeze(-1)  # [batch_size, seq_length, 1]

        # use attention mask to mask the output, ignore the padding embedding vector, only add the valid embedding vector
        masked_output = output * attention_mask

        # sum up all the valid output
        summed_output = masked_output.sum(dim=1)  # [batch_size, hidden_size]

        logits = self.output_layer(summed_output)

        return logits  # The output is [batch_size, 1]

# %%
# import datasets

train_df = pd.read_csv("train.csv").iloc[:,1:]
validation_df = pd.read_csv("validation.csv").iloc[:,1:]
test_df = pd.read_csv("test.csv").iloc[:,1:]

# %%
# try to use tokenizer api
tokenizer_no_sub.encode(["hello world", "how are you"], return_tensors = "pt") # insist to return pytorch
# Out:
# {'input_ids': tensor([[13077,    87,     0],
#          [  199,    34,    83]]),
#  'attention_mask': tensor([[1, 1, 0],
#          [1, 1, 1]])}

# %%
# Hyper paramaters
dropout_rate = 0.1
num_rnn_layer = 1
hidden_dim = 256

val_steps = 100 # compute validation error every n step

num_train_epochs = 3

batch_size = 32
lr = 8e-5
weight_decay = 1e-5


warmup_ratio=0.1
max_grad_norm = 2.0

# %%
# define dataset and data loader
class CustomizeDataset(Dataset):
    def __init__(
            self,
            df : pd.DataFrame
        ) -> None:
        super().__init__()
        self.df = df

    def __len__(self) -> int:
        return len(self.df)

    def __getitem__(
            self,
            index : int
        ) -> dict:

        inputs = self.df.iloc[index,0] # 0 is text
        label = self.df.iloc[index, 1] # 1 is label

        return {
            "input_str" : inputs, # output a string
            "label" : label # output a label
        }

# collater function (used for dynamic padding to save memory)
class Collater:
    def __init__(
            self,
            tokenizer_no_sub : GloveTokenizerNoSub
        ) -> None:
        self.tokenizer_no_sub = tokenizer_no_sub

    def __call__(
            self,
            instances : list # a list of string
        ) -> Any:
        # __call__ is for function-like object
        input_str_list = [instance["input_str"] for instance in instances]
        input_dict = tokenizer_no_sub.encode(input_str_list, return_tensors = "pt") # return pytorch tensor
        input_ids = input_dict["input_ids"]
        attention_mask = input_dict["attention_mask"]
        label = [torch.tensor(instance["label"], dtype = torch.int64) for instance in instances]

        return {
            "input_ids": input_ids,
            "label": torch.tensor(label),
            "attention_mask": attention_mask # mask the pad position
        }

# %%
# create dataset and data loader
collate_fn = Collater(tokenizer_no_sub)



train_ds = CustomizeDataset(
    df = train_df
)

train_loader = DataLoader(
    dataset = train_ds,
    batch_size = batch_size,
    collate_fn = collate_fn,
    shuffle = True
)

val_ds = CustomizeDataset(
    df = validation_df
)

val_loader = DataLoader(
    dataset = val_ds,
    batch_size = batch_size,
    collate_fn = collate_fn
)

test_ds = CustomizeDataset(
    df = test_df
)

test_loader = DataLoader(
    dataset = test_ds,
    batch_size = batch_size,
    collate_fn = collate_fn
)

# %%
# compute warmup status
num_training_steps = num_train_epochs * len(train_loader)
num_warmup_steps = int(num_training_steps * warmup_ratio)
print(f"train:{num_training_steps}, warm up: {num_warmup_steps}")
# Out:
# train:801, warm up: 80

# %%
# Set optimizer, loss_fn and so on

cls_model = SentimentRNN(
    embedding = embedding,
    hidden_size = hidden_dim,
    embed_size = EMBED_DIM,
    bidirectional = False, #  False for part 2
    num_rnn_layer = num_rnn_layer,
    dropout_rate = dropout_rate,
    layer_norm = True # set if you need layer norm
)

loss_fn = nn.BCEWithLogitsLoss()

optimizer = AdamW(
    params = cls_model.parameters(),
    lr = lr,
    weight_decay = weight_decay
)

scheduler  = get_cosine_schedule_with_warmup(
    optimizer = optimizer,
    num_warmup_steps = num_warmup_steps,
    num_training_steps = num_training_steps
)

# %%
# compute accuracy for wach data loader

def compute_accuracy(data_loader: DataLoader) -> float:

    cls_model.eval()

    correct = 0
    total = 0

    with torch.no_grad():
        for data in data_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)

            logits = cls_model(input_ids, attention_mask=attention_mask)

            predictions = (logits > 0).long()

            correct += (predictions == labels).sum().item()
            total += labels.size(0)

    accuracy = correct / total
    return accuracy

def compute_loss(data_loader: DataLoader) -> float:
    total_loss = 0
    cls_model.eval()
    with torch.no_grad():
        for data in data_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)

            logits = cls_model.forward(input_ids, attention_mask)
            loss = loss_fn.forward(
                input = logits,
                target = labels
            )

            total_loss += loss.detach().cpu()

        total_loss /= len(val_loader)

        return total_loss

# %%
def early_stopping(train_loss, validation_loss, min_delta, tolerance, counter):
    positive_diff = abs(validation_loss - train_loss)

    # Increment counter if no significant improvement
    if positive_diff >= min_delta:
        counter += 1
        if counter >= tolerance:
            return True, counter
    # Ensure the function always returns both values
    return False, counter

# %%
# Training loop

cls_model.to(device)

optimizer.zero_grad()

step = 0

train_losses = []

val_accs = []

val_losses = []

counter = 0

for epoch in range(num_train_epochs):

    # train loop
    for data in train_loader:
        cls_model.train()
        input_ids = data["input_ids"].to(device)
        attention_mask = data["attention_mask"].to(device)
        label = data["label"].view(-1, 1).float().to(device)

        logits = cls_model.forward(input_ids, attention_mask)


        loss = loss_fn.forward(
            input = logits,
            target = label
        )

        loss.backward()

        # Gradient clip (important for RNN, not necessary for LSTM/GRU/conv1d)
        torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)

        optimizer.step() # update paramater
        scheduler.step()
        optimizer.zero_grad() # clear gradient

        vis_loss = loss.detach().cpu()

        print(f"[{step + 1}/{num_training_steps}] train loss: [{vis_loss:.4f}] (epoch [{epoch + 1}/{num_train_epochs}])")


        train_losses.append(vis_loss)
        i =0

        if (step + 1) % val_steps == 0 or step == 0:
            # compute validation every "val_steps"

            cls_model.eval()
            val_loss = compute_loss(val_loader)
            val_acc = compute_accuracy(val_loader)
            val_accs.append(val_acc)
            val_losses.append(val_loss)

            print(f"[{step + 1}/{num_training_steps}] validation loss: [{val_loss:.4f}] validation accuracy: [{val_acc:.4f}]")
            # Apply early stopping
            should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.01, tolerance=2, counter=counter)
            if should_stop:
                print("Early stopping triggered.")
                break

        step += 1

    if should_stop:
        break  # Exit e
# Out:
# [1/801] train loss: [0.8409] (epoch [1/3])
# [1/801] validation loss: [0.7249] validation accuracy: [0.5000]
# [2/801] train loss: [0.6892] (epoch [1/3])
# [3/801] train loss: [0.7727] (epoch [1/3])
# [4/801] train loss: [0.8164] (epoch [1/3])
# [5/801] train loss: [0.8146] (epoch [1/3])
# [6/801] train loss: [0.7653] (epoch [1/3])
# [7/801] train loss: [0.6871] (epoch [1/3])
# [8/801] train loss: [0.8005] (epoch [1/3])
# [9/801] train loss: [0.7287] (epoch [1/3])
# [10/801] train loss: [0.7970] (epoch [1/3])
# [11/801] train loss: [0.7032] (epoch [1/3])
# [12/801] train loss: [0.7424] (epoch [1/3])
# [13/801] train loss: [0.6991] (epoch [1/3])
# [14/801] train loss: [0.6962] (epoch [1/3])
# [15/801] train loss: [0.6881] (epoch [1/3])
# [16/801] train loss: [0.6994] (epoch [1/3])
# [17/801] train loss: [0.7134] (epoch [1/3])
# [18/801] train loss: [0.7115] (epoch [1/3])
# [19/801] train loss: [0.6941] (epoch [1/3])
# [20/801] train loss: [0.7028] (epoch [1/3])
# [21/801] train loss: [0.7041] (epoch [1/3])
# [22/801] train loss: [0.6826] (epoch [1/3])
# [23/801] train loss: [0.6567] (epoch [1/3])
# [24/801] train loss: [0.7080] (epoch [1/3])
# [25/801] train loss: [0.7124] (epoch [1/3])
# [26/801] train loss: [0.7017] (epoch [1/3])
# [27/801] train loss: [0.7029] (epoch [1/3])
# [28/801] train loss: [0.6660] (epoch [1/3])
# [29/801] train loss: [0.7122] (epoch [1/3])
# [30/801] train loss: [0.6683] (epoch [1/3])
# [31/801] train loss: [0.6823] (epoch [1/3])
# [32/801] train loss: [0.7039] (epoch [1/3])
# [33/801] train loss: [0.7186] (epoch [1/3])
# [34/801] train loss: [0.6809] (epoch [1/3])
# [35/801] train loss: [0.7076] (epoch [1/3])
# [36/801] train loss: [0.7166] (epoch [1/3])
# [37/801] train loss: [0.6977] (epoch [1/3])
# [38/801] train loss: [0.6853] (epoch [1/3])
# [39/801] train loss: [0.7339] (epoch [1/3])
# [40/801] train loss: [0.6941] (epoch [1/3])
# [41/801] train loss: [0.6960] (epoch [1/3])
# [42/801] train loss: [0.7048] (epoch [1/3])
# [43/801] train loss: [0.6778] (epoch [1/3])
# [44/801] train loss: [0.6836] (epoch [1/3])
# [45/801] train loss: [0.6917] (epoch [1/3])
# [46/801] train loss: [0.6736] (epoch [1/3])
# [47/801] train loss: [0.6828] (epoch [1/3])
# [48/801] train loss: [0.6772] (epoch [1/3])
# [49/801] train loss: [0.7095] (epoch [1/3])
# [50/801] train loss: [0.6743] (epoch [1/3])
# [51/801] train loss: [0.6859] (epoch [1/3])
# [52/801] train loss: [0.6799] (epoch [1/3])
# [53/801] train loss: [0.7205] (epoch [1/3])
# [54/801] train loss: [0.6530] (epoch [1/3])
# [55/801] train loss: [0.6900] (epoch [1/3])
# [56/801] train loss: [0.6875] (epoch [1/3])
# [57/801] train loss: [0.6637] (epoch [1/3])
# [58/801] train loss: [0.6643] (epoch [1/3])
# [59/801] train loss: [0.6803] (epoch [1/3])
# [60/801] train loss: [0.6895] (epoch [1/3])
# [61/801] train loss: [0.6637] (epoch [1/3])
# [62/801] train loss: [0.6690] (epoch [1/3])
# [63/801] train loss: [0.6486] (epoch [1/3])
# [64/801] train loss: [0.7247] (epoch [1/3])
# [65/801] train loss: [0.6464] (epoch [1/3])
# [66/801] train loss: [0.6725] (epoch [1/3])
# [67/801] train loss: [0.7389] (epoch [1/3])
# [68/801] train loss: [0.6829] (epoch [1/3])
# [69/801] train loss: [0.6885] (epoch [1/3])
# [70/801] train loss: [0.6631] (epoch [1/3])
# [71/801] train loss: [0.6686] (epoch [1/3])
# [72/801] train loss: [0.6517] (epoch [1/3])
# [73/801] train loss: [0.6717] (epoch [1/3])
# [74/801] train loss: [0.6584] (epoch [1/3])
# [75/801] train loss: [0.6421] (epoch [1/3])
# [76/801] train loss: [0.6461] (epoch [1/3])
# [77/801] train loss: [0.6501] (epoch [1/3])
# [78/801] train loss: [0.6447] (epoch [1/3])
# [79/801] train loss: [0.6639] (epoch [1/3])
# [80/801] train loss: [0.6683] (epoch [1/3])
# [81/801] train loss: [0.6717] (epoch [1/3])
# [82/801] train loss: [0.6547] (epoch [1/3])
# [83/801] train loss: [0.6995] (epoch [1/3])
# [84/801] train loss: [0.6795] (epoch [1/3])
# [85/801] train loss: [0.5807] (epoch [1/3])
# [86/801] train loss: [0.6957] (epoch [1/3])
# [87/801] train loss: [0.7062] (epoch [1/3])
# [88/801] train loss: [0.6673] (epoch [1/3])
# [89/801] train loss: [0.5990] (epoch [1/3])
# [90/801] train loss: [0.6541] (epoch [1/3])
# [91/801] train loss: [0.6531] (epoch [1/3])
# [92/801] train loss: [0.6143] (epoch [1/3])
# [93/801] train loss: [0.6508] (epoch [1/3])
# [94/801] train loss: [0.6587] (epoch [1/3])
# [95/801] train loss: [0.6589] (epoch [1/3])
# [96/801] train loss: [0.6915] (epoch [1/3])
# [97/801] train loss: [0.6773] (epoch [1/3])
# [98/801] train loss: [0.5643] (epoch [1/3])
# [99/801] train loss: [0.6249] (epoch [1/3])
# [100/801] train loss: [0.5897] (epoch [1/3])
# [100/801] validation loss: [0.6532] validation accuracy: [0.5938]
# Early stopping triggered.

# %%
# Test the model
# Define hyperparameter ranges
param_grid = {
    "num_rnn_layer": range(1, 2),  # Integer range for number of RNN layers
    "hidden_dim": [128, 256],  # Integer range for hidden dimension size
    "dropout_rate": [0.1, 0.2],  # Continuous range for dropout rate
    "learning_rate": [1e-4, 1e-3],  # Continuous range for learning rate
    "batch_size": [128, 256],  # Integer range for batch size
    "max_grad_norm": [1.0, 2.0],  # Continuous range for gradient clipping
    "num_train_epochs": [1,2,3]  # Integer range for number of training epochs
}

# Track the best configuration
best_val_loss = float('inf')
best_val_accuracy = 0.0
best_params = None

# Generate all combinations of hyperparameters
for params in itertools.product(
    param_grid["num_rnn_layer"],
    param_grid["hidden_dim"],
    param_grid["dropout_rate"],
    param_grid["learning_rate"],
    param_grid["batch_size"],
    param_grid["max_grad_norm"],
    param_grid["num_train_epochs"]
):
    # Unpack hyperparameters
    num_rnn_layer, hidden_dim, dropout_rate, learning_rate, batch_size, max_grad_norm, num_train_epochs = params

    # Initialize model with current parameters
    cls_model = SentimentRNN(
        embedding=embedding,
        hidden_size=hidden_dim,
        embed_size=EMBED_DIM,
        bidirectional=False,
        num_rnn_layer=num_rnn_layer,
        dropout_rate=dropout_rate,
        layer_norm=True
    ).to(device)

    # Set up optimizer and scheduler
    optimizer = torch.optim.Adam(cls_model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

    # DataLoader for selected batch size
    train_loader = DataLoader(
        dataset=train_ds,
        batch_size=batch_size,
        collate_fn=collate_fn,
        shuffle=True
    )

    # Early stopping and metrics tracking variables
    counter = 0
    step = 0
    train_losses = []
    val_losses = []
    val_accs = []
    should_stop = False
    early_stopped = False  # Flag to indicate early stopping for this trial

    for epoch in range(num_train_epochs):
        # Training loop
        for data in train_loader:
            cls_model.train()
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            label = data["label"].view(-1, 1).float().to(device)

            logits = cls_model(input_ids, attention_mask)

            loss = loss_fn(input=logits, target=label)
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)

            optimizer.step()
            scheduler.step()
            optimizer.zero_grad()

            vis_loss = loss.detach().cpu().item()
            train_losses.append(vis_loss)

            # Validation step every `val_steps`
            if (step + 1) % val_steps == 0 or step == 0:
                cls_model.eval()
                val_loss = compute_loss(val_loader)
                val_acc = compute_accuracy(val_loader)
                val_losses.append(val_loss)
                val_accs.append(val_acc)

                # Early stopping check
                should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.5, tolerance=2, counter=counter)
                if should_stop:
                    print("Early stopping triggered.")
                    early_stopped = True  # Mark this trial as early stopped
                    break

            step += 1

        if should_stop:
            break  # Exit epoch loop if early stopping is triggered

    # Track the best parameters and validation loss
    current_val_loss = val_losses[-1] if val_losses else float('inf')
    current_val_accuracy = val_accs[-1] if val_accs else 0.0
    if current_val_accuracy > best_val_accuracy and early_stopped==False:
        best_val_loss = current_val_loss
        best_val_accuracy = current_val_accuracy
        best_params = params

    # Print the trial's results, including early stopping info
    print(f"Trial with params: {params}")
    print(f"  Validation Loss: {current_val_loss}")
    print(f"  Validation Accuracy: {current_val_accuracy}")
    if early_stopped:
        print("  Early stopped")


# Print the best result
print("Best result:")
print(f"  Validation Loss: {best_val_loss}")
print(f"  Validation Accuracy: {best_val_accuracy}")
print("  Best hyperparameters:", best_params)
# Out:
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.7029529809951782
#   Validation Accuracy: 0.474671669793621
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6799853444099426
#   Validation Accuracy: 0.5816135084427767
# Trial with params: (1, 128, 0.1, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6759373545646667
#   Validation Accuracy: 0.6022514071294559
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.6928160190582275
#   Validation Accuracy: 0.5065666041275797
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6778026223182678
#   Validation Accuracy: 0.6041275797373359
# Trial with params: (1, 128, 0.1, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6896387338638306
#   Validation Accuracy: 0.5422138836772983
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6949459910392761
#   Validation Accuracy: 0.5037523452157598
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.7011867761611938
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.1, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.690355658531189
#   Validation Accuracy: 0.5234521575984991
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.7325150966644287
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6934377551078796
#   Validation Accuracy: 0.5234521575984991
# Trial with params: (1, 128, 0.1, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6924594640731812
#   Validation Accuracy: 0.5206378986866792
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.7006068229675293
#   Validation Accuracy: 0.49624765478424016
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.657425045967102
#   Validation Accuracy: 0.6641651031894934
# Trial with params: (1, 128, 0.1, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6527680158615112
#   Validation Accuracy: 0.6735459662288931
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.7607618570327759
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.6640726327896118
#   Validation Accuracy: 0.6641651031894934
# Trial with params: (1, 128, 0.1, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6554719805717468
#   Validation Accuracy: 0.6613508442776735
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.7855073809623718
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.7641682624816895
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.1, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6491637825965881
#   Validation Accuracy: 0.6547842401500938
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.7729601860046387
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.7032891511917114
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.1, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6544268131256104
#   Validation Accuracy: 0.6575984990619137
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.7035568356513977
#   Validation Accuracy: 0.47842401500938087
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6944825053215027
#   Validation Accuracy: 0.5290806754221389
# Trial with params: (1, 128, 0.2, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.677442729473114
#   Validation Accuracy: 0.6050656660412758
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.693332314491272
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6885514259338379
#   Validation Accuracy: 0.5412757973733584
# Trial with params: (1, 128, 0.2, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6996174454689026
#   Validation Accuracy: 0.48592870544090055
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.7027459144592285
#   Validation Accuracy: 0.45590994371482174
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.683903694152832
#   Validation Accuracy: 0.573170731707317
# Trial with params: (1, 128, 0.2, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.690733790397644
#   Validation Accuracy: 0.5131332082551595
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.6986342072486877
#   Validation Accuracy: 0.4793621013133208
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.701367974281311
#   Validation Accuracy: 0.4906191369606004
# Trial with params: (1, 128, 0.2, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6924639344215393
#   Validation Accuracy: 0.5140712945590994
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.7501592040061951
#   Validation Accuracy: 0.5056285178236398
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6780903339385986
#   Validation Accuracy: 0.6069418386491557
# Trial with params: (1, 128, 0.2, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6391891241073608
#   Validation Accuracy: 0.6801125703564728
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 1)
#   Validation Loss: 0.7770254611968994
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.6694176197052002
#   Validation Accuracy: 0.6613508442776735
# Trial with params: (1, 128, 0.2, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6477931141853333
#   Validation Accuracy: 0.6313320825515948
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 1)
#   Validation Loss: 0.7417466640472412
#   Validation Accuracy: 0.5
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.8007053136825562
#   Validation Accuracy: 0.4981238273921201
# Trial with params: (1, 128, 0.2, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6662794351577759
#   Validation Accuracy: 0.6622889305816135
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.770755410194397
#   Validation Accuracy: 0.4981238273921201
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.7513331770896912
#   Validation Accuracy: 0.5065666041275797
# Trial with params: (1, 128, 0.2, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6454527974128723
#   Validation Accuracy: 0.6754221388367729
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.6980336904525757
#   Validation Accuracy: 0.4878048780487805
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6749701499938965
#   Validation Accuracy: 0.6294559099437148
# Trial with params: (1, 256, 0.1, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6797477006912231
#   Validation Accuracy: 0.6144465290806754
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.6966720819473267
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6755000352859497
#   Validation Accuracy: 0.600375234521576
# Trial with params: (1, 256, 0.1, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6708762645721436
#   Validation Accuracy: 0.6153846153846154
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.6955781579017639
#   Validation Accuracy: 0.5046904315196998
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6943630576133728
#   Validation Accuracy: 0.4924953095684803
# Trial with params: (1, 256, 0.1, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6700530052185059
#   Validation Accuracy: 0.6191369606003753
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.6915259957313538
#   Validation Accuracy: 0.5234521575984991
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.6895724534988403
#   Validation Accuracy: 0.5478424015009381
# Trial with params: (1, 256, 0.1, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6821827292442322
#   Validation Accuracy: 0.5900562851782364
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 1)
#   Validation Loss: 0.9686866998672485
#   Validation Accuracy: 0.4981238273921201
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6307839751243591
#   Validation Accuracy: 0.6660412757973734
# Trial with params: (1, 256, 0.1, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6361953616142273
#   Validation Accuracy: 0.6632270168855535
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 1)
#   Validation Loss: 1.0540472269058228
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.655855119228363
#   Validation Accuracy: 0.6651031894934334
# Trial with params: (1, 256, 0.1, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.6765328049659729
#   Validation Accuracy: 0.6641651031894934
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 1)
#   Validation Loss: 1.0890371799468994
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 2)
#   Validation Loss: 1.122857928276062
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.1, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6704756617546082
#   Validation Accuracy: 0.6679174484052532
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 1)
#   Validation Loss: 1.236138939857483
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 2)
#   Validation Loss: 1.0673860311508179
#   Validation Accuracy: 0.5
# Trial with params: (1, 256, 0.1, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.5978401899337769
#   Validation Accuracy: 0.6857410881801126
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 1)
#   Validation Loss: 0.699648380279541
#   Validation Accuracy: 0.45590994371482174
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 2)
#   Validation Loss: 0.6728062629699707
#   Validation Accuracy: 0.6163227016885553
# Trial with params: (1, 256, 0.2, 0.0001, 128, 1.0, 3)
#   Validation Loss: 0.6692392826080322
#   Validation Accuracy: 0.6078799249530957
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 1)
#   Validation Loss: 0.6933319568634033
#   Validation Accuracy: 0.5159474671669794
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 2)
#   Validation Loss: 0.6765865087509155
#   Validation Accuracy: 0.6303939962476548
# Trial with params: (1, 256, 0.2, 0.0001, 128, 2.0, 3)
#   Validation Loss: 0.6753926277160645
#   Validation Accuracy: 0.6031894934333959
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 1)
#   Validation Loss: 0.7002547383308411
#   Validation Accuracy: 0.48874296435272047
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 2)
#   Validation Loss: 0.6871272921562195
#   Validation Accuracy: 0.5422138836772983
# Trial with params: (1, 256, 0.2, 0.0001, 256, 1.0, 3)
#   Validation Loss: 0.6791607141494751
#   Validation Accuracy: 0.6106941838649156
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 1)
#   Validation Loss: 0.6975131034851074
#   Validation Accuracy: 0.5056285178236398
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 2)
#   Validation Loss: 0.682253897190094
#   Validation Accuracy: 0.5684803001876173
# Trial with params: (1, 256, 0.2, 0.0001, 256, 2.0, 3)
#   Validation Loss: 0.6771695613861084
#   Validation Accuracy: 0.6078799249530957
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 1)
#   Validation Loss: 1.15986168384552
#   Validation Accuracy: 0.50187617260788
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 2)
#   Validation Loss: 0.6108760237693787
#   Validation Accuracy: 0.6707317073170732
# Trial with params: (1, 256, 0.2, 0.001, 128, 1.0, 3)
#   Validation Loss: 0.6625842452049255
#   Validation Accuracy: 0.6669793621013134
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 1)
#   Validation Loss: 1.0910439491271973
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 2)
#   Validation Loss: 0.6819567084312439
#   Validation Accuracy: 0.6388367729831145
# Trial with params: (1, 256, 0.2, 0.001, 128, 2.0, 3)
#   Validation Loss: 0.5993115901947021
#   Validation Accuracy: 0.6782363977485929
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 1)
#   Validation Loss: 1.1386895179748535
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 2)
#   Validation Loss: 0.8165480494499207
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.2, 0.001, 256, 1.0, 3)
#   Validation Loss: 0.6722712516784668
#   Validation Accuracy: 0.6651031894934334
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 1)
#   Validation Loss: 0.7822756767272949
#   Validation Accuracy: 0.49906191369606
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 2)
#   Validation Loss: 0.8968912363052368
#   Validation Accuracy: 0.50093808630394
# Trial with params: (1, 256, 0.2, 0.001, 256, 2.0, 3)
#   Validation Loss: 0.6802905797958374
#   Validation Accuracy: 0.6557223264540337
# Best result:
#   Validation Loss: 0.5978401899337769
#   Validation Accuracy: 0.6857410881801126
#   Best hyperparameters: (1, 256, 0.1, 0.001, 256, 2.0, 3)

# %%
#result of the best parameters ("num_rnn_layer", "hidden_dim", "dropout_rate", "learning_rate", "batch_size", "max_grad_norm", "num_train_epochs")
print(best_params)
# Out:
# (1, 256, 0.1, 0.001, 256, 2.0, 3)

# %%
val_steps = 100
batch_size = 128
dropout_rate = 0.2
hidden_dim = 258
learning_rate = 0.001
num_rnn_layer = 1
max_grad_norm = 2.0
num_train_epochs = 3

num_training_steps = num_train_epochs * len(train_loader)
num_warmup_steps = int(num_training_steps * warmup_ratio)
print(f"train:{num_training_steps}, warm up: {num_warmup_steps}")
# Out:
# train:102, warm up: 10

# %%
cls_model = SentimentRNN(
    embedding=embedding,
    hidden_size=hidden_dim,
    embed_size=EMBED_DIM,
    bidirectional=False,  # False for part 2
    num_rnn_layer=num_rnn_layer,
    dropout_rate=dropout_rate,
    layer_norm=True
).to(device)
# Set up optimizer and scheduler
optimizer = torch.optim.Adam(cls_model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.9)

train_loader = DataLoader(
    dataset=train_ds,
    batch_size=batch_size,
    collate_fn=collate_fn,
    shuffle=True
)

optimizer.zero_grad()

step = 0

train_losses = []

val_accs = []

val_losses = []

counter = 0

for epoch in range(num_train_epochs):

    # train loop
    for data in train_loader:
        cls_model.train()
        input_ids = data["input_ids"].to(device)
        attention_mask = data["attention_mask"].to(device)
        label = data["label"].view(-1, 1).float().to(device)

        logits = cls_model.forward(input_ids, attention_mask)


        loss = loss_fn.forward(
            input = logits,
            target = label
        )

        loss.backward()

        # Gradient clip (important for RNN, not necessary for LSTM/GRU/conv1d)
        torch.nn.utils.clip_grad_norm_(cls_model.parameters(), max_norm=max_grad_norm)

        optimizer.step() # update paramater
        scheduler.step()
        optimizer.zero_grad() # clear gradient

        vis_loss = loss.detach().cpu()

        print(f"[{step + 1}/{num_training_steps}] train loss: [{vis_loss:.4f}] (epoch [{epoch + 1}/{num_train_epochs}])")


        train_losses.append(vis_loss)
        i =0

        if (step + 1) % val_steps == 0 or step == 0:
            # compute validation every "val_steps"

            cls_model.eval()
            val_loss = compute_loss(val_loader)
            val_acc = compute_accuracy(val_loader)
            val_accs.append(val_acc)
            val_losses.append(val_loss)

            print(f"[{step + 1}/{num_training_steps}] validation loss: [{val_loss:.4f}] validation accuracy: [{val_acc:.4f}]")
            # Apply early stopping
            should_stop, counter = early_stopping(vis_loss, val_loss, min_delta=0.5, tolerance=2, counter=counter)
            if should_stop:
                print("Early stopping triggered.")
                break

        step += 1

    if should_stop:
        break  # Exit e
# Out:
# [1/102] train loss: [0.7049] (epoch [1/3])
# [1/102] validation loss: [1.0936] validation accuracy: [0.5000]
# [2/102] train loss: [0.9701] (epoch [1/3])
# [3/102] train loss: [0.7565] (epoch [1/3])
# [4/102] train loss: [0.6727] (epoch [1/3])
# [5/102] train loss: [0.7413] (epoch [1/3])
# [6/102] train loss: [0.7161] (epoch [1/3])
# [7/102] train loss: [0.6832] (epoch [1/3])
# [8/102] train loss: [0.6856] (epoch [1/3])
# [9/102] train loss: [0.6943] (epoch [1/3])
# [10/102] train loss: [0.7184] (epoch [1/3])
# [11/102] train loss: [0.6832] (epoch [1/3])
# [12/102] train loss: [0.6903] (epoch [1/3])
# [13/102] train loss: [0.6711] (epoch [1/3])
# [14/102] train loss: [0.6744] (epoch [1/3])
# [15/102] train loss: [0.6738] (epoch [1/3])
# [16/102] train loss: [0.6736] (epoch [1/3])
# [17/102] train loss: [0.6899] (epoch [1/3])
# [18/102] train loss: [0.6816] (epoch [1/3])
# [19/102] train loss: [0.6734] (epoch [1/3])
# [20/102] train loss: [0.6703] (epoch [1/3])
# [21/102] train loss: [0.6806] (epoch [1/3])
# [22/102] train loss: [0.6776] (epoch [1/3])
# [23/102] train loss: [0.6821] (epoch [1/3])
# [24/102] train loss: [0.6707] (epoch [1/3])
# [25/102] train loss: [0.6783] (epoch [1/3])
# [26/102] train loss: [0.6768] (epoch [1/3])
# [27/102] train loss: [0.6715] (epoch [1/3])
# [28/102] train loss: [0.6768] (epoch [1/3])
# [29/102] train loss: [0.6602] (epoch [1/3])
# [30/102] train loss: [0.6716] (epoch [1/3])
# [31/102] train loss: [0.6805] (epoch [1/3])
# [32/102] train loss: [0.6810] (epoch [1/3])
# [33/102] train loss: [0.6681] (epoch [1/3])
# [34/102] train loss: [0.6582] (epoch [1/3])
# [35/102] train loss: [0.6592] (epoch [1/3])
# [36/102] train loss: [0.6713] (epoch [1/3])
# [37/102] train loss: [0.6734] (epoch [1/3])
# [38/102] train loss: [0.6623] (epoch [1/3])
# [39/102] train loss: [0.6536] (epoch [1/3])
# [40/102] train loss: [0.6618] (epoch [1/3])
# [41/102] train loss: [0.6609] (epoch [1/3])
# [42/102] train loss: [0.6693] (epoch [1/3])
# [43/102] train loss: [0.6719] (epoch [1/3])
# [44/102] train loss: [0.6748] (epoch [1/3])
# [45/102] train loss: [0.6806] (epoch [1/3])
# [46/102] train loss: [0.6712] (epoch [1/3])
# [47/102] train loss: [0.6584] (epoch [1/3])
# [48/102] train loss: [0.6511] (epoch [1/3])
# [49/102] train loss: [0.6660] (epoch [1/3])
# [50/102] train loss: [0.6722] (epoch [1/3])
# [51/102] train loss: [0.6607] (epoch [1/3])
# [52/102] train loss: [0.6516] (epoch [1/3])
# [53/102] train loss: [0.6647] (epoch [1/3])
# [54/102] train loss: [0.6686] (epoch [1/3])
# [55/102] train loss: [0.6792] (epoch [1/3])
# [56/102] train loss: [0.6553] (epoch [1/3])
# [57/102] train loss: [0.6626] (epoch [1/3])
# [58/102] train loss: [0.6595] (epoch [1/3])
# [59/102] train loss: [0.6767] (epoch [1/3])
# [60/102] train loss: [0.6657] (epoch [1/3])
# [61/102] train loss: [0.6761] (epoch [1/3])
# [62/102] train loss: [0.6773] (epoch [1/3])
# [63/102] train loss: [0.6557] (epoch [1/3])
# [64/102] train loss: [0.6661] (epoch [1/3])
# [65/102] train loss: [0.6691] (epoch [1/3])
# [66/102] train loss: [0.6669] (epoch [1/3])
# [67/102] train loss: [0.6767] (epoch [1/3])
# [68/102] train loss: [0.6629] (epoch [2/3])
# [69/102] train loss: [0.6606] (epoch [2/3])
# [70/102] train loss: [0.6780] (epoch [2/3])
# [71/102] train loss: [0.6686] (epoch [2/3])
# [72/102] train loss: [0.6536] (epoch [2/3])
# [73/102] train loss: [0.6653] (epoch [2/3])
# [74/102] train loss: [0.6686] (epoch [2/3])
# [75/102] train loss: [0.6667] (epoch [2/3])
# [76/102] train loss: [0.6826] (epoch [2/3])
# [77/102] train loss: [0.6582] (epoch [2/3])
# [78/102] train loss: [0.6669] (epoch [2/3])
# [79/102] train loss: [0.6585] (epoch [2/3])
# [80/102] train loss: [0.6740] (epoch [2/3])
# [81/102] train loss: [0.6545] (epoch [2/3])
# [82/102] train loss: [0.6619] (epoch [2/3])
# [83/102] train loss: [0.6818] (epoch [2/3])
# [84/102] train loss: [0.6734] (epoch [2/3])
# [85/102] train loss: [0.6649] (epoch [2/3])
# [86/102] train loss: [0.6613] (epoch [2/3])
# [87/102] train loss: [0.6769] (epoch [2/3])
# [88/102] train loss: [0.6822] (epoch [2/3])
# [89/102] train loss: [0.6585] (epoch [2/3])
# [90/102] train loss: [0.6674] (epoch [2/3])
# [91/102] train loss: [0.6704] (epoch [2/3])
# [92/102] train loss: [0.6620] (epoch [2/3])
# [93/102] train loss: [0.6604] (epoch [2/3])
# [94/102] train loss: [0.6599] (epoch [2/3])
# [95/102] train loss: [0.6534] (epoch [2/3])
# [96/102] train loss: [0.6692] (epoch [2/3])
# [97/102] train loss: [0.6540] (epoch [2/3])
# [98/102] train loss: [0.6713] (epoch [2/3])
# [99/102] train loss: [0.6529] (epoch [2/3])
# [100/102] train loss: [0.6673] (epoch [2/3])
# [100/102] validation loss: [0.6672] validation accuracy: [0.6557]
# [101/102] train loss: [0.6652] (epoch [2/3])
# [102/102] train loss: [0.6559] (epoch [2/3])
# [103/102] train loss: [0.6695] (epoch [2/3])
# [104/102] train loss: [0.6662] (epoch [2/3])
# [105/102] train loss: [0.6760] (epoch [2/3])
# [106/102] train loss: [0.6644] (epoch [2/3])
# [107/102] train loss: [0.6608] (epoch [2/3])
# [108/102] train loss: [0.6615] (epoch [2/3])
# [109/102] train loss: [0.6705] (epoch [2/3])
# [110/102] train loss: [0.6575] (epoch [2/3])
# [111/102] train loss: [0.6681] (epoch [2/3])
# [112/102] train loss: [0.6681] (epoch [2/3])
# [113/102] train loss: [0.6783] (epoch [2/3])
# [114/102] train loss: [0.6706] (epoch [2/3])
# [115/102] train loss: [0.6571] (epoch [2/3])
# [116/102] train loss: [0.6692] (epoch [2/3])
# [117/102] train loss: [0.6684] (epoch [2/3])
# [118/102] train loss: [0.6776] (epoch [2/3])
# [119/102] train loss: [0.6562] (epoch [2/3])
# [120/102] train loss: [0.6627] (epoch [2/3])
# [121/102] train loss: [0.6689] (epoch [2/3])
# [122/102] train loss: [0.6590] (epoch [2/3])
# [123/102] train loss: [0.6704] (epoch [2/3])
# [124/102] train loss: [0.6666] (epoch [2/3])
# [125/102] train loss: [0.6710] (epoch [2/3])
# [126/102] train loss: [0.6639] (epoch [2/3])
# [127/102] train loss: [0.6719] (epoch [2/3])
# [128/102] train loss: [0.6686] (epoch [2/3])
# [129/102] train loss: [0.6688] (epoch [2/3])
# [130/102] train loss: [0.6683] (epoch [2/3])
# [131/102] train loss: [0.6616] (epoch [2/3])
# [132/102] train loss: [0.6603] (epoch [2/3])
# [133/102] train loss: [0.6630] (epoch [2/3])
# [134/102] train loss: [0.6723] (epoch [2/3])
# [135/102] train loss: [0.6600] (epoch [3/3])
# [136/102] train loss: [0.6485] (epoch [3/3])
# [137/102] train loss: [0.6621] (epoch [3/3])
# [138/102] train loss: [0.6665] (epoch [3/3])
# [139/102] train loss: [0.6492] (epoch [3/3])
# [140/102] train loss: [0.6722] (epoch [3/3])
# [141/102] train loss: [0.6614] (epoch [3/3])
# [142/102] train loss: [0.6807] (epoch [3/3])
# [143/102] train loss: [0.6650] (epoch [3/3])
# [144/102] train loss: [0.6704] (epoch [3/3])
# [145/102] train loss: [0.6845] (epoch [3/3])
# [146/102] train loss: [0.6687] (epoch [3/3])
# [147/102] train loss: [0.6806] (epoch [3/3])
# [148/102] train loss: [0.6673] (epoch [3/3])
# [149/102] train loss: [0.6728] (epoch [3/3])
# [150/102] train loss: [0.6737] (epoch [3/3])
# [151/102] train loss: [0.6665] (epoch [3/3])
# [152/102] train loss: [0.6558] (epoch [3/3])
# [153/102] train loss: [0.6674] (epoch [3/3])
# [154/102] train loss: [0.6545] (epoch [3/3])
# [155/102] train loss: [0.6746] (epoch [3/3])
# [156/102] train loss: [0.6694] (epoch [3/3])
# [157/102] train loss: [0.6690] (epoch [3/3])
# [158/102] train loss: [0.6593] (epoch [3/3])
# [159/102] train loss: [0.6756] (epoch [3/3])
# [160/102] train loss: [0.6704] (epoch [3/3])
# [161/102] train loss: [0.6739] (epoch [3/3])
# [162/102] train loss: [0.6744] (epoch [3/3])
# [163/102] train loss: [0.6625] (epoch [3/3])
# [164/102] train loss: [0.6617] (epoch [3/3])
# [165/102] train loss: [0.6872] (epoch [3/3])
# [166/102] train loss: [0.6768] (epoch [3/3])
# [167/102] train loss: [0.6571] (epoch [3/3])
# [168/102] train loss: [0.6657] (epoch [3/3])
# [169/102] train loss: [0.6707] (epoch [3/3])
# [170/102] train loss: [0.6759] (epoch [3/3])
# [171/102] train loss: [0.6746] (epoch [3/3])
# [172/102] train loss: [0.6584] (epoch [3/3])
# [173/102] train loss: [0.6555] (epoch [3/3])
# [174/102] train loss: [0.6623] (epoch [3/3])
# [175/102] train loss: [0.6593] (epoch [3/3])
# [176/102] train loss: [0.6644] (epoch [3/3])
# [177/102] train loss: [0.6573] (epoch [3/3])
# [178/102] train loss: [0.6531] (epoch [3/3])
# [179/102] train loss: [0.6703] (epoch [3/3])
# [180/102] train loss: [0.6592] (epoch [3/3])
# [181/102] train loss: [0.6586] (epoch [3/3])
# [182/102] train loss: [0.6600] (epoch [3/3])
# [183/102] train loss: [0.6766] (epoch [3/3])
# [184/102] train loss: [0.6553] (epoch [3/3])
# [185/102] train loss: [0.6628] (epoch [3/3])
# [186/102] train loss: [0.6623] (epoch [3/3])
# [187/102] train loss: [0.6584] (epoch [3/3])
# [188/102] train loss: [0.6718] (epoch [3/3])
# [189/102] train loss: [0.6592] (epoch [3/3])
# [190/102] train loss: [0.6714] (epoch [3/3])
# [191/102] train loss: [0.6752] (epoch [3/3])
# [192/102] train loss: [0.6761] (epoch [3/3])
# [193/102] train loss: [0.6712] (epoch [3/3])
# [194/102] train loss: [0.6640] (epoch [3/3])
# [195/102] train loss: [0.6660] (epoch [3/3])
# [196/102] train loss: [0.6625] (epoch [3/3])
# [197/102] train loss: [0.6618] (epoch [3/3])
# [198/102] train loss: [0.6841] (epoch [3/3])
# [199/102] train loss: [0.6669] (epoch [3/3])
# [200/102] train loss: [0.6598] (epoch [3/3])
# [200/102] validation loss: [0.6672] validation accuracy: [0.6557]
# [201/102] train loss: [0.6547] (epoch [3/3])

# %%
train_loss = compute_loss(train_loader)
train_acc = compute_accuracy(train_loader)
test_loss = compute_loss(test_loader)
test_acc = compute_accuracy(test_loader)
val_loss = compute_loss(val_loader)
test_acc = compute_accuracy(test_loader)

print(f"Train Loss: [{train_loss:.4f}]\nTrain accuracy: [{train_acc:.4f}]")
print(f"Test Loss: [{test_loss:.4f}]\nTest accuracy: [{test_acc:.4f}]")
print(f"Validation Loss: [{val_loss:.4f}]\nValidation accuracy: [{val_acc:.4f}]")
# Out:
# Train Loss: [1.3074]
# Train accuracy: [0.6637]
# Test Loss: [0.6642]
# Test accuracy: [0.6407]
# Validation Loss: [0.6672]
# Validation accuracy: [0.6557]

# %%
# compute predictions and labels for confusion matrix computing
def compute_pedictions_and_labels(
        model : nn.Module,
        test_loader : DataLoader,
        device : torch.device
    ) -> tuple:

    model.to(device)

    model.eval()

    # Lists to store all predictions and actual labels
    all_predictions = []
    all_labels = []

    with torch.no_grad():
        for data in test_loader:
            input_ids = data["input_ids"].to(device)
            attention_mask = data["attention_mask"].to(device)
            labels = data["label"].view(-1, 1).float().to(device)

            logits = model(input_ids, attention_mask=attention_mask)

            predictions = (logits > 0).long()

            all_predictions.extend(predictions.view(-1).cpu().numpy())
            all_labels.extend(labels.view(-1).cpu().numpy())

    return all_predictions, all_labels

all_predictions, all_labels = compute_pedictions_and_labels(cls_model, test_loader, device)

# %%
# visualization 2: confusion matrix

def plot_confusion(
        all_predictions : list,
        all_labels : list
    ) -> None:

    cm = confusion_matrix(all_labels, all_predictions) # from sklearn

    plt.figure(figsize=(6,4))
    sns.heatmap(cm, annot=True, fmt='d', linewidths=0.2, cmap="YlGnBu", cbar=False)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.xticks([0.5, 1.5], ['Negative', 'Positive'])
    plt.yticks([0.5, 1.5], ['Negative', 'Positive'], va='center')
    plt.show()

plot_confusion(all_predictions, all_labels)
